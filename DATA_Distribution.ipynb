# %%
import os
import sys
sys.path.append("numpy_path")
import numpy as np
from matplotlib import pyplot as plt
from math import cos, sin, pi
import math
from statistics import mean
import os.path
import random

shape_size = 48

# %%
data_size = 0
dummy1 = [0]*200
dummy2 = [0]*6
SP = np.array(np.reshape(dummy1, (1, 200)))
SH = np.array(np.reshape(dummy2, (1, 6)))
for i in range(2, 65):
    path = 'meep_code/data/DATA'+str(i)
    if not os.path.exists(path):
        #miss.append(i)
        print('Missing batch:' + str(i))
        continue
        
    files = next(os.walk(path))[2] #dir is your directory path as string]
    num_data = len(files)
    data_size += num_data
    skip = []
    
    coordinates = np.genfromtxt('meep_code/data/DATA'+str(i)+'_sh.txt')
    xc, yc = coordinates[:, 0], coordinates[:, 1]
    xc = np.reshape(xc, (num_data, shape_size))
    yc = np.reshape(yc, (num_data, shape_size))
    
    for j in range(num_data):
        tmp = np.genfromtxt(path+'/'+'DATA'+str(i)+'_sp'+str(j)+'.txt')
        valid = True
        for q in range(200):       
            if tmp[q] > 3:
                print('Batch '+str(i)+'\tsample '+str(j)+' has extreme value')
                valid = False
                break
        if not valid:
            #skip.append(j)
            continue
        SP = np.concatenate((SP, np.reshape(tmp, (1, 200))))
        tmp = []
        for q in range(6):
            tmp.append(math.sqrt(xc[j][q]**2 + yc[j][q]**2))
        SH = np.concatenate((SH, np.reshape(np.array(tmp), (1, 6))))
    print('Batch '+str(i)+' has \t'+str(num_data))
# Out:
# Batch 2 has 	7
# Batch 3 has 	6
# Batch 4 has 	17
# Batch 5 has 	5
# Batch 6 has 	14
# Batch 7 has 	14
# Batch 8 has 	40
# Batch 9 has 	5
# Batch 10 has 	14
# Batch 11 has 	14
# Batch 12 has 	40
# Batch 13 has 	13
# Batch 14 has 	37
# Batch 15 has 	37
# Batch 16 has 	106
# Batch 17 has 	5
# Batch 18 has 	14
# Batch 19 has 	14
# Batch 20 has 	40
# Batch 21 has 	13
# Batch 22 has 	37
# Batch 23 has 	37
# Batch 24 has 	106
# Batch 25 has 	13
# Batch 26 has 	37
# Batch 27 has 	37
# Batch 28 has 	106
# Batch 29 has 	35
# Batch 30 has 	100
# Batch 31 has 	100
# Batch 32 has 	287
# Batch 33 has 	5
# Batch 34 has 	14
# Batch 35 has 	14
# Batch 36 has 	40
# Batch 37 has 	13
# Batch 38 has 	37
# Batch 39 has 	37
# Batch 40 has 	106
# Batch 41 has 	13
# Batch 42 has 	37
# Batch 43 has 	37
# Batch 44 has 	106
# Batch 45 has 	35
# Batch 46 has 	100
# Batch 47 has 	100
# Batch 48 has 	287
# Batch 49 has 	13
# Batch 50 has 	37
# Batch 51 has 	37
# Batch 52 has 	106
# Batch 53 has 	35
# Batch 54 has 	100
# Batch 55 has 	100
# Batch 56 has 	287
# Batch 57 has 	35
# Batch 58 has 	100
# Batch 59 has 	100
# Batch 60 has 	287
# Batch 61 has 	95
# Batch 62 has 	272
# Batch 63 has 	272
# Batch 64 has 	781

# %%
distribution = []
print('Total # of data: ' + str(len(SP)))
x = np.genfromtxt('meep_code/data/SP_xaxis.txt')
SP_F, SH_F = np.reshape(SP[1], (1, 200)),np.reshape(SH[1], (1, 6))

for i in range(1, len(SP)):
    p_u, p_d = 0, 0
    p_u_pos, p_d_pos = [], []
    for j in range(1, 200):
        if SP[i][j - 1] >= 0.6 >=SP[i][j]:
            p_d += 1
            p_d_pos.append(j / 2 + 200)
        if SP[i][j - 1] <= 0.6 <=SP[i][j]:
            p_u += 1
            p_u_pos.append(j / 2 + 200)
    if p_d == p_u and p_d == 2:
        distribution.append(p_d_pos)
        distribution.append(p_u_pos)
        SP_F = np.concatenate((SP_F, np.reshape(SP[i], (1, 200))))
        SH_F = np.concatenate((SH_F, np.reshape(SH[i], (1, 6))))
#         plt.ylim(0, 1.1)
#         plt.plot(x, SP[i])
#         plt.show()
#         print(p_d_pos)
#         print(p_u_pos)
SP_F = SP_F[1:,:]
SH_F = SH_F[1:,:]
# Out:
# Total # of data: 4989

# %%
len(distribution)
# Out:
# 1676

# %% [markdown]
# # Distribution of Two peak

# %% [markdown]
# ## Distribution of the first of Two peak

# %%
dis_first = []
for i in range(0, len(distribution) - 1, 2):
    peak = (distribution[i][0] + distribution[i + 1][0]) / 2
    dis_first.append([random.random(), peak])
#     plt.ylim(0, 1.1)
#     plt.plot(x, SP_F[i//2])
#     plt.show()
dis_first = np.array(dis_first)
plt.xlim(200, 300)
plt.scatter(dis_first[:,1],dis_first[:,0])

# %% [markdown]
# ## Distribution of the second of Two peak

# %%
dis_first = []
for i in range(0, len(distribution) - 1, 2):
    peak = (distribution[i][1] + distribution[i + 1][1]) / 2
    dis_first.append([random.random(), peak])
#     plt.ylim(0, 1.1)
#     plt.plot(x, SP_F[i//2])
#     plt.show()
dis_first = np.array(dis_first)
plt.xlim(200, 300)
plt.scatter(dis_first[:,1],dis_first[:,0])

# %% [markdown]
# ## Distribution of the second peak where the first peak is in [200, 220)

# %%
def dis_sec_p(begin, end):
    dis_sec = []
    for i in range(0, len(distribution) - 1, 2):
        first_peak = (distribution[i][0] + distribution[i + 1][0]) / 2
        if begin <= first_peak < end:
            second_peak = (distribution[i][1] + distribution[i + 1][1]) / 2
            dis_sec.append([random.random(), second_peak])
#         plt.ylim(0, 1.1)
#         plt.plot(x, SP_F[i//2])
#         plt.show()
    dis_sec = np.array(dis_sec)
    print()
    plt.title('Second peak distribution where First peak in [' + str(begin)+', '+str(end)+')')
    plt.xlim(200, 300)
    plt.scatter(dis_sec[:,1],dis_sec[:,0])
    print("{0:.4f}".format(len(dis_sec)/len(SP_F)*100)
        +'% ('+str(len(dis_sec))+' out of '+str(len(SP_F))
          +') spectrum with two peaks, its first peak lies in ['+str(begin)+', '+str(end)+')')

# %%
dis_sec_p(200, 220)
# Out:
# 2.5060% (21 out of 838) spectrum with two peaks, its first peak lies in [200, 220)

# %%
dis_sec_p(220, 240)
# Out:
# 28.4010% (238 out of 838) spectrum with two peaks, its first peak lies in [220, 240)

# %%
dis_sec_p(240, 260)
# Out:
# 55.0119% (461 out of 838) spectrum with two peaks, its first peak lies in [240, 260)

# %%
dis_sec_p(260, 280)
# Out:
# 13.8425% (116 out of 838) spectrum with two peaks, its first peak lies in [260, 280)

# %%
dis_sec_p(280, 300)
# Out:
# 0.2387% (2 out of 838) spectrum with two peaks, its first peak lies in [280, 300)

# %% [markdown]
# # Distribution of One peak

# %% [markdown]
# ![image.png](attachment:image.png)
