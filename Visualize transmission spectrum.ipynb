# %%
from matplotlib import pyplot as plt
import numpy as np
coordinates = np.genfromtxt('C:/Users/jeffe/Desktop/Summer_research/S4_code/data/700.txt')
x, y = coordinates[:, 0], coordinates[:, 1]
plt.plot(x, y)
plt.axis('equal')
plt.fill(x, y)
plt.show()

# %%
# extract x axis
#x_axis = raw_data[:,1][0:50]
#plt.plot(x_axis, train_x[14])
data = np.genfromtxt('C:/Users/jeffe/Desktop/Summer_research/S4_code/data/700_spectrum.txt')
size = len(data)
x = data[:,0][0:size]
y = np.zeros((size, 1))
for i in range(size):
    y[i, 0] = data[i, 1]**2 + data[i, 2]**2
plt.plot(x, y)
plt.show()
