# %%
# %matplotlib notebook
import os
import sys
sys.path.append("numpy_path")
import numpy as np
import struct
from matplotlib import pyplot as plt
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation
from keras.optimizers import RMSprop
import keras.callbacks as cb
from keras.callbacks import EarlyStopping, ModelCheckpoint
from math import cos, sin, pi
from statistics import mean
import os.path
import math
shape_size = 48

# define loss history
class LossHistory(cb.Callback):
    def on_train_begin(self, logs={}):
        self.losses = []
    def on_batch_end(self, batch, logs={}):
        batch_loss = logs.get('loss')
        self.losses.append(batch_loss)

#plot losses
def plot_losses(losses):
    plt.plot(losses)
    plt.title('Loss per batch')
    plt.show()

def feature_scaling(X):
    X = X.T
    for i in range(7):
        mean = X[i].mean()
        std = X[i].std()
        X[i] = [(x - mean)/std for x in X[i]]
    return X.T

# input dimension
in_dim = 6
out_dim = 200
def init_model():
    model = Sequential()
    model.add(Dense(20, input_dim=in_dim))
    model.add(Dropout(0.2))
    model.add(Activation('relu'))
    model.add(Dense(500))
    model.add(Dropout(0.2))
    model.add(Activation('relu'))
    model.add(Dense(200))
    model.add(Dropout(0.2))
    model.add(Activation('relu'))
    model.add(Dense(200))
    model.add(Activation('relu'))
    model.add(Dense(200))
    model.add(Dropout(0.2))
    model.add(Activation('relu'))
#     model.add(Dense(70))
#     model.add(Dropout(0.2))
#     model.add(Activation('relu'))
#     model.add(Dense(100))
#     model.add(Activation('relu'))
    model.add(Dense(out_dim))
    model.add(Activation('sigmoid'))
    # use mean squared error to measure the looses
    model.compile(loss=keras.losses.mean_squared_error,
              optimizer=keras.optimizers.Adam(lr = 0.001),
              metrics=['accuracy'])
    return model
# Out:
# Using TensorFlow backend.

# %%
data_size = 0
dummy1 = [0]*200
dummy2 = [0]*6
SP = np.array(np.reshape(dummy1, (1, 200)))
SH = np.array(np.reshape(dummy2, (1, 6)))
for i in range(2, 42):
    path = 'meep_code/data/DATA'+str(i)
    if not os.path.exists(path):
        #miss.append(i)
        print('Missing batch:' + str(i))
        continue
        
    files = next(os.walk(path))[2] #dir is your directory path as string]
    num_data = len(files)
    data_size += num_data
    skip = []
    
    coordinates = np.genfromtxt('meep_code/data/DATA'+str(i)+'_sh.txt')
    xc, yc = coordinates[:, 0], coordinates[:, 1]
    xc = np.reshape(xc, (num_data, shape_size))
    yc = np.reshape(yc, (num_data, shape_size))
    
    for j in range(num_data):
        tmp = np.genfromtxt(path+'/'+'DATA'+str(i)+'_sp'+str(j)+'.txt')
        valid = True
        for q in range(200): 
            
            if math.isnan(float(tmp[q])):
                print('Batch '+str(i)+'\tsample '+str(j)+' has NAN value')
                valid = False
                break
            if tmp[q] > 3:
                print('Batch '+str(i)+'\tsample '+str(j)+' has extreme value')
                valid = False
                break
        if not valid:
            #skip.append(j)
            continue
        SP = np.concatenate((SP, np.reshape(tmp, (1, 200))))
        tmp = []
        for q in range(6):
            tmp.append(math.sqrt(xc[j][q]**2 + yc[j][q]**2))
        SH = np.concatenate((SH, np.reshape(np.array(tmp), (1, 6))))
        #print(SP.shape)
    #print(files)
#     coordinates = np.genfromtxt('meep_code/data/DATA'+str(i)+'_sh.txt')
#     xc, yc = coordinates[:, 0], coordinates[:, 1]
#     xc = np.reshape(xc, (num_data, shape_size))
#     yc = np.reshape(yc, (num_data, shape_size))
#     for j in range(num_data):
#         if j in skip:
#             continue
#         tmp = []
#         for q in range(6):
#             tmp.append(math.sqrt(xc[j][q]**2 + yc[j][q]**2))
#         SH = np.concatenate((SH, np.reshape(np.array(tmp), (1, 6))))
    print('Batch '+str(i)+' has \t'+str(num_data)) 
#     freq = np.genfromtxt('meep_code/data/freq.txt')   
#     for j in range(num_data):
#         print(j)
#         plt.ylim(0, 1.1)
#         plt.plot(freq, SP[data_size - num_data + j + 1])
#         plt.show()
#         plt.axis('equal')
#         plt.ylim(-0.5, 0.5)
#         plt.xlim(-0.5, 0.5)
#         plt.plot(xc[j], yc[j])
#         plt.fill(xc[j], yc[j])
#         plt.show()
# Out:
# Batch 2 has 	7
# Batch 3 has 	6
# Batch 4 has 	17
# Batch 5 has 	5
# Batch 6 has 	14
# Batch 7 has 	14
# Batch 8 has 	40
# Batch 9 has 	5
# Batch 10 has 	14
# Batch 11 has 	14
# Batch 12 has 	40
# Batch 13 has 	13
# Batch 14 has 	37
# Batch 15 has 	37
# Missing batch:16
# Batch 17 has 	5
# Batch 18 has 	14
# Batch 19 has 	14
# Batch 20 has 	40
# Batch 21 has 	13
# Batch 22 has 	37
# Batch 23 has 	37
# Batch 24 has 	106
# Batch 25 has 	13
# Batch 26 has 	37
# Batch 27 has 	37
# Batch 28 has 	106
# Batch 29 has 	35
# Batch 30 has 	100
# Batch 31 has 	100
# Batch 32 has 	287
# Batch 33 has 	5
# Batch 34 has 	14
# Batch 35 has 	14
# Batch 36 has 	40
# Batch 37 has 	13
# Batch 38 has 	37
# Batch 39 has 	37
# Batch 40 has 	106
# Batch 41 has 	13

# %%
DATA = np.append(SP, SH, axis = 1)
np.random.shuffle(DATA)

Y = DATA[:, :200]
X = DATA[:,200:]

train_size = int(len(DATA) * 0.8)

train_X = X[0:train_size, :]
train_Y = Y[0:train_size, :]
test_X = X[train_size:, :]
test_Y = Y[train_size:, :]

# %%
model = init_model()
history = LossHistory()
# when training, using minibatch seems to be pretty good
model.fit(train_X, train_Y, epochs=1000, batch_size=10,
                callbacks=[history],
                validation_data=(test_X, test_Y), verbose=2)
score = model.evaluate(test_X, test_Y, batch_size=10)
print(score)
plot_losses(history.losses)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0726 15:39:43.332967 139638701143872 deprecation_wrapper.py:119] From /home/shengnan/anaconda3/envs/mp/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0726 15:39:43.394692 139638701143872 deprecation_wrapper.py:119] From /home/shengnan/anaconda3/envs/mp/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0726 15:39:43.406083 139638701143872 deprecation_wrapper.py:119] From /home/shengnan/anaconda3/envs/mp/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0726 15:39:43.460803 139638701143872 deprecation_wrapper.py:119] From /home/shengnan/anaconda3/envs/mp/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# W0726 15:39:43.483079 139638701143872 deprecation.py:506] From /home/shengnan/anaconda3/envs/mp/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# W0726 15:39:43.851825 139638701143872 deprecation_wrapper.py:119] From /home/shengnan/anaconda3/envs/mp/lib/python3.6/site-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0726 15:39:44.828859 139638701143872 deprecation_wrapper.py:119] From /home/shengnan/anaconda3/envs/mp/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
# Train on 1219 samples, validate on 305 samples
# Epoch 1/1000
#  - 5s - loss: 0.0856 - acc: 0.0090 - val_loss: 0.0576 - val_acc: 0.0098
# Epoch 2/1000
#  - 2s - loss: 0.0623 - acc: 0.0066 - val_loss: 0.0604 - val_acc: 0.0000e+00
# Epoch 3/1000
#  - 2s - loss: 0.0598 - acc: 0.0090 - val_loss: 0.0546 - val_acc: 0.0066
# Epoch 4/1000
#  - 2s - loss: 0.0587 - acc: 0.0066 - val_loss: 0.0537 - val_acc: 0.0000e+00
# Epoch 5/1000
#  - 2s - loss: 0.0575 - acc: 0.0066 - val_loss: 0.0602 - val_acc: 0.0066
# Epoch 6/1000
#  - 2s - loss: 0.0568 - acc: 0.0074 - val_loss: 0.0559 - val_acc: 0.0066
# Epoch 7/1000
#  - 2s - loss: 0.0555 - acc: 0.0049 - val_loss: 0.0561 - val_acc: 0.0033
# Epoch 8/1000
#  - 3s - loss: 0.0555 - acc: 0.0066 - val_loss: 0.0532 - val_acc: 0.0098
# Epoch 9/1000
#  - 2s - loss: 0.0549 - acc: 0.0025 - val_loss: 0.0601 - val_acc: 0.0066
# Epoch 10/1000
#  - 2s - loss: 0.0535 - acc: 0.0115 - val_loss: 0.0560 - val_acc: 0.0033
# Epoch 11/1000
#  - 2s - loss: 0.0530 - acc: 0.0066 - val_loss: 0.0545 - val_acc: 0.0066
# Epoch 12/1000
#  - 2s - loss: 0.0524 - acc: 0.0156 - val_loss: 0.0559 - val_acc: 0.0000e+00
# Epoch 13/1000
#  - 2s - loss: 0.0510 - acc: 0.0123 - val_loss: 0.0587 - val_acc: 0.0098
# Epoch 14/1000
#  - 2s - loss: 0.0499 - acc: 0.0123 - val_loss: 0.0633 - val_acc: 0.0033
# Epoch 15/1000
#  - 2s - loss: 0.0492 - acc: 0.0082 - val_loss: 0.0670 - val_acc: 0.0033
# Epoch 16/1000
#  - 2s - loss: 0.0478 - acc: 0.0107 - val_loss: 0.0617 - val_acc: 0.0066
# Epoch 17/1000
#  - 2s - loss: 0.0478 - acc: 0.0098 - val_loss: 0.0688 - val_acc: 0.0033
# Epoch 18/1000
#  - 2s - loss: 0.0467 - acc: 0.0197 - val_loss: 0.0668 - val_acc: 0.0066
# Epoch 19/1000
#  - 2s - loss: 0.0458 - acc: 0.0148 - val_loss: 0.0704 - val_acc: 0.0033
# Epoch 20/1000
#  - 2s - loss: 0.0465 - acc: 0.0156 - val_loss: 0.0638 - val_acc: 0.0098
# Epoch 21/1000
#  - 2s - loss: 0.0454 - acc: 0.0164 - val_loss: 0.0629 - val_acc: 0.0033
# Epoch 22/1000
#  - 2s - loss: 0.0447 - acc: 0.0131 - val_loss: 0.0642 - val_acc: 0.0033
# Epoch 23/1000
#  - 2s - loss: 0.0439 - acc: 0.0197 - val_loss: 0.0676 - val_acc: 0.0066
# Epoch 24/1000
#  - 2s - loss: 0.0437 - acc: 0.0205 - val_loss: 0.0693 - val_acc: 0.0033
# Epoch 25/1000
#  - 2s - loss: 0.0435 - acc: 0.0189 - val_loss: 0.0680 - val_acc: 0.0066
# Epoch 26/1000
#  - 2s - loss: 0.0429 - acc: 0.0123 - val_loss: 0.0598 - val_acc: 0.0066
# Epoch 27/1000
#  - 2s - loss: 0.0428 - acc: 0.0156 - val_loss: 0.0650 - val_acc: 0.0098
# Epoch 28/1000
#  - 2s - loss: 0.0427 - acc: 0.0164 - val_loss: 0.0704 - val_acc: 0.0066
# Epoch 29/1000
#  - 3s - loss: 0.0421 - acc: 0.0189 - val_loss: 0.0697 - val_acc: 0.0066
# Epoch 30/1000
#  - 2s - loss: 0.0420 - acc: 0.0139 - val_loss: 0.0681 - val_acc: 0.0098
# Epoch 31/1000
#  - 2s - loss: 0.0419 - acc: 0.0172 - val_loss: 0.0711 - val_acc: 0.0131
# Epoch 32/1000
#  - 2s - loss: 0.0419 - acc: 0.0254 - val_loss: 0.0730 - val_acc: 0.0098
# Epoch 33/1000
#  - 2s - loss: 0.0423 - acc: 0.0156 - val_loss: 0.0734 - val_acc: 0.0131
# Epoch 34/1000
#  - 2s - loss: 0.0409 - acc: 0.0156 - val_loss: 0.0675 - val_acc: 0.0098
# Epoch 35/1000
#  - 2s - loss: 0.0410 - acc: 0.0123 - val_loss: 0.0650 - val_acc: 0.0131
# Epoch 36/1000
#  - 2s - loss: 0.0402 - acc: 0.0115 - val_loss: 0.0656 - val_acc: 0.0164
# Epoch 37/1000
#  - 2s - loss: 0.0400 - acc: 0.0115 - val_loss: 0.0684 - val_acc: 0.0131
# Epoch 38/1000
#  - 2s - loss: 0.0397 - acc: 0.0156 - val_loss: 0.0701 - val_acc: 0.0098
# Epoch 39/1000
#  - 3s - loss: 0.0396 - acc: 0.0172 - val_loss: 0.0703 - val_acc: 0.0033
# Epoch 40/1000
#  - 2s - loss: 0.0396 - acc: 0.0139 - val_loss: 0.0713 - val_acc: 0.0098
# Epoch 41/1000
#  - 2s - loss: 0.0397 - acc: 0.0090 - val_loss: 0.0596 - val_acc: 0.0033
# Epoch 42/1000
#  - 2s - loss: 0.0392 - acc: 0.0148 - val_loss: 0.0722 - val_acc: 0.0033
# Epoch 43/1000
#  - 2s - loss: 0.0392 - acc: 0.0148 - val_loss: 0.0789 - val_acc: 0.0033
# Epoch 44/1000
#  - 2s - loss: 0.0391 - acc: 0.0139 - val_loss: 0.0685 - val_acc: 0.0066
# Epoch 45/1000
#  - 2s - loss: 0.0393 - acc: 0.0189 - val_loss: 0.0692 - val_acc: 0.0033
# Epoch 46/1000
#  - 2s - loss: 0.0392 - acc: 0.0205 - val_loss: 0.0685 - val_acc: 0.0000e+00
# Epoch 47/1000
#  - 2s - loss: 0.0389 - acc: 0.0074 - val_loss: 0.0699 - val_acc: 0.0098
# Epoch 48/1000
#  - 2s - loss: 0.0382 - acc: 0.0131 - val_loss: 0.0711 - val_acc: 0.0066
# Epoch 49/1000
#  - 2s - loss: 0.0385 - acc: 0.0090 - val_loss: 0.0700 - val_acc: 0.0066
# Epoch 50/1000
#  - 2s - loss: 0.0386 - acc: 0.0098 - val_loss: 0.0725 - val_acc: 0.0033
# Epoch 51/1000
#  - 2s - loss: 0.0381 - acc: 0.0107 - val_loss: 0.0697 - val_acc: 0.0098
# Epoch 52/1000
#  - 2s - loss: 0.0379 - acc: 0.0090 - val_loss: 0.0675 - val_acc: 0.0066
# Epoch 53/1000
#  - 2s - loss: 0.0381 - acc: 0.0139 - val_loss: 0.0694 - val_acc: 0.0131
# Epoch 54/1000
#  - 2s - loss: 0.0374 - acc: 0.0197 - val_loss: 0.0679 - val_acc: 0.0066
# Epoch 55/1000
#  - 2s - loss: 0.0368 - acc: 0.0131 - val_loss: 0.0678 - val_acc: 0.0033
# Epoch 56/1000
#  - 2s - loss: 0.0372 - acc: 0.0156 - val_loss: 0.0656 - val_acc: 0.0131
# Epoch 57/1000
#  - 2s - loss: 0.0382 - acc: 0.0172 - val_loss: 0.0708 - val_acc: 0.0131
# Epoch 58/1000
#  - 2s - loss: 0.0367 - acc: 0.0139 - val_loss: 0.0765 - val_acc: 0.0131
# Epoch 59/1000
#  - 2s - loss: 0.0369 - acc: 0.0197 - val_loss: 0.0742 - val_acc: 0.0098
# Epoch 60/1000
#  - 2s - loss: 0.0369 - acc: 0.0180 - val_loss: 0.0622 - val_acc: 0.0131
# Epoch 61/1000
#  - 2s - loss: 0.0365 - acc: 0.0131 - val_loss: 0.0657 - val_acc: 0.0033
# Epoch 62/1000
#  - 2s - loss: 0.0364 - acc: 0.0205 - val_loss: 0.0672 - val_acc: 0.0033
# Epoch 63/1000
#  - 2s - loss: 0.0370 - acc: 0.0164 - val_loss: 0.0670 - val_acc: 0.0066
# Epoch 64/1000
#  - 2s - loss: 0.0365 - acc: 0.0172 - val_loss: 0.0681 - val_acc: 0.0131
# Epoch 65/1000
#  - 2s - loss: 0.0359 - acc: 0.0156 - val_loss: 0.0637 - val_acc: 0.0000e+00
# Epoch 66/1000
#  - 2s - loss: 0.0364 - acc: 0.0156 - val_loss: 0.0602 - val_acc: 0.0033
# Epoch 67/1000
#  - 2s - loss: 0.0364 - acc: 0.0197 - val_loss: 0.0660 - val_acc: 0.0033
# Epoch 68/1000
#  - 2s - loss: 0.0353 - acc: 0.0197 - val_loss: 0.0619 - val_acc: 0.0033
# Epoch 69/1000
#  - 2s - loss: 0.0359 - acc: 0.0205 - val_loss: 0.0689 - val_acc: 0.0131
# Epoch 70/1000
#  - 2s - loss: 0.0360 - acc: 0.0107 - val_loss: 0.0686 - val_acc: 0.0066
# Epoch 71/1000
#  - 2s - loss: 0.0349 - acc: 0.0164 - val_loss: 0.0675 - val_acc: 0.0066
# Epoch 72/1000
#  - 2s - loss: 0.0358 - acc: 0.0156 - val_loss: 0.0664 - val_acc: 0.0033
# Epoch 73/1000
#  - 2s - loss: 0.0358 - acc: 0.0180 - val_loss: 0.0679 - val_acc: 0.0066
# Epoch 74/1000
#  - 2s - loss: 0.0351 - acc: 0.0148 - val_loss: 0.0684 - val_acc: 0.0033
# Epoch 75/1000
#  - 2s - loss: 0.0351 - acc: 0.0156 - val_loss: 0.0662 - val_acc: 0.0033
# Epoch 76/1000
#  - 2s - loss: 0.0348 - acc: 0.0164 - val_loss: 0.0674 - val_acc: 0.0033
# Epoch 77/1000
#  - 2s - loss: 0.0351 - acc: 0.0172 - val_loss: 0.0626 - val_acc: 0.0066
# Epoch 78/1000
#  - 2s - loss: 0.0347 - acc: 0.0205 - val_loss: 0.0669 - val_acc: 0.0066
# Epoch 79/1000
#  - 2s - loss: 0.0359 - acc: 0.0197 - val_loss: 0.0655 - val_acc: 0.0066
# Epoch 80/1000
#  - 2s - loss: 0.0351 - acc: 0.0271 - val_loss: 0.0599 - val_acc: 0.0098
# Epoch 81/1000
#  - 2s - loss: 0.0347 - acc: 0.0304 - val_loss: 0.0665 - val_acc: 0.0066
# Epoch 82/1000
#  - 2s - loss: 0.0341 - acc: 0.0254 - val_loss: 0.0692 - val_acc: 0.0098
# Epoch 83/1000
#  - 2s - loss: 0.0351 - acc: 0.0197 - val_loss: 0.0747 - val_acc: 0.0131
# Epoch 84/1000
#  - 2s - loss: 0.0348 - acc: 0.0164 - val_loss: 0.0662 - val_acc: 0.0000e+00
# Epoch 85/1000
#  - 2s - loss: 0.0348 - acc: 0.0213 - val_loss: 0.0680 - val_acc: 0.0098
# Epoch 86/1000
#  - 2s - loss: 0.0337 - acc: 0.0230 - val_loss: 0.0643 - val_acc: 0.0033
# Epoch 87/1000
#  - 2s - loss: 0.0345 - acc: 0.0238 - val_loss: 0.0658 - val_acc: 0.0033
# Epoch 88/1000
#  - 2s - loss: 0.0341 - acc: 0.0148 - val_loss: 0.0630 - val_acc: 0.0066
# Epoch 89/1000
#  - 2s - loss: 0.0344 - acc: 0.0287 - val_loss: 0.0666 - val_acc: 0.0066
# Epoch 90/1000
#  - 2s - loss: 0.0340 - acc: 0.0189 - val_loss: 0.0645 - val_acc: 0.0000e+00
# Epoch 91/1000
#  - 2s - loss: 0.0332 - acc: 0.0221 - val_loss: 0.0673 - val_acc: 0.0131
# Epoch 92/1000
#  - 2s - loss: 0.0332 - acc: 0.0189 - val_loss: 0.0718 - val_acc: 0.0098
# Epoch 93/1000
#  - 2s - loss: 0.0339 - acc: 0.0221 - val_loss: 0.0656 - val_acc: 0.0066
# Epoch 94/1000
#  - 2s - loss: 0.0334 - acc: 0.0230 - val_loss: 0.0672 - val_acc: 0.0066
# Epoch 95/1000
#  - 2s - loss: 0.0329 - acc: 0.0254 - val_loss: 0.0670 - val_acc: 0.0066
# Epoch 96/1000
#  - 2s - loss: 0.0333 - acc: 0.0221 - val_loss: 0.0680 - val_acc: 0.0098
# Epoch 97/1000
#  - 2s - loss: 0.0335 - acc: 0.0263 - val_loss: 0.0618 - val_acc: 0.0066
# Epoch 98/1000
#  - 2s - loss: 0.0338 - acc: 0.0213 - val_loss: 0.0680 - val_acc: 0.0033
# Epoch 99/1000
#  - 2s - loss: 0.0334 - acc: 0.0180 - val_loss: 0.0637 - val_acc: 0.0033
# Epoch 100/1000
#  - 2s - loss: 0.0333 - acc: 0.0263 - val_loss: 0.0582 - val_acc: 0.0066
# Epoch 101/1000
#  - 2s - loss: 0.0340 - acc: 0.0221 - val_loss: 0.0683 - val_acc: 0.0033
# Epoch 102/1000
#  - 2s - loss: 0.0334 - acc: 0.0246 - val_loss: 0.0641 - val_acc: 0.0066
# Epoch 103/1000
#  - 2s - loss: 0.0327 - acc: 0.0197 - val_loss: 0.0654 - val_acc: 0.0033
# Epoch 104/1000
#  - 2s - loss: 0.0326 - acc: 0.0279 - val_loss: 0.0666 - val_acc: 0.0033
# Epoch 105/1000
#  - 2s - loss: 0.0332 - acc: 0.0246 - val_loss: 0.0630 - val_acc: 0.0066
# Epoch 106/1000
#  - 2s - loss: 0.0336 - acc: 0.0213 - val_loss: 0.0653 - val_acc: 0.0033
# Epoch 107/1000
#  - 2s - loss: 0.0338 - acc: 0.0221 - val_loss: 0.0618 - val_acc: 0.0066
# Epoch 108/1000
#  - 2s - loss: 0.0326 - acc: 0.0156 - val_loss: 0.0647 - val_acc: 0.0066
# Epoch 109/1000
#  - 2s - loss: 0.0337 - acc: 0.0238 - val_loss: 0.0635 - val_acc: 0.0098
# Epoch 110/1000
#  - 2s - loss: 0.0324 - acc: 0.0238 - val_loss: 0.0679 - val_acc: 0.0033
# Epoch 111/1000
#  - 2s - loss: 0.0328 - acc: 0.0221 - val_loss: 0.0606 - val_acc: 0.0098
# Epoch 112/1000
#  - 2s - loss: 0.0324 - acc: 0.0271 - val_loss: 0.0626 - val_acc: 0.0131
# Epoch 113/1000
#  - 2s - loss: 0.0326 - acc: 0.0180 - val_loss: 0.0646 - val_acc: 0.0131
# Epoch 114/1000
#  - 3s - loss: 0.0323 - acc: 0.0246 - val_loss: 0.0621 - val_acc: 0.0098
# Epoch 115/1000
#  - 2s - loss: 0.0325 - acc: 0.0295 - val_loss: 0.0685 - val_acc: 0.0131
# Epoch 116/1000
#  - 2s - loss: 0.0322 - acc: 0.0279 - val_loss: 0.0672 - val_acc: 0.0098
# Epoch 117/1000
#  - 2s - loss: 0.0324 - acc: 0.0295 - val_loss: 0.0679 - val_acc: 0.0033
# Epoch 118/1000
#  - 2s - loss: 0.0316 - acc: 0.0213 - val_loss: 0.0648 - val_acc: 0.0098
# Epoch 119/1000
#  - 2s - loss: 0.0327 - acc: 0.0221 - val_loss: 0.0635 - val_acc: 0.0066
# Epoch 120/1000
#  - 2s - loss: 0.0313 - acc: 0.0312 - val_loss: 0.0666 - val_acc: 0.0098
# Epoch 121/1000
#  - 2s - loss: 0.0324 - acc: 0.0295 - val_loss: 0.0670 - val_acc: 0.0066
# Epoch 122/1000
#  - 2s - loss: 0.0323 - acc: 0.0205 - val_loss: 0.0644 - val_acc: 0.0098
# Epoch 123/1000
#  - 3s - loss: 0.0321 - acc: 0.0213 - val_loss: 0.0669 - val_acc: 0.0066
# Epoch 124/1000
#  - 2s - loss: 0.0316 - acc: 0.0230 - val_loss: 0.0608 - val_acc: 0.0066
# Epoch 125/1000
#  - 2s - loss: 0.0322 - acc: 0.0279 - val_loss: 0.0623 - val_acc: 0.0066
# Epoch 126/1000
#  - 2s - loss: 0.0327 - acc: 0.0320 - val_loss: 0.0653 - val_acc: 0.0066
# Epoch 127/1000
#  - 2s - loss: 0.0318 - acc: 0.0238 - val_loss: 0.0672 - val_acc: 0.0131
# Epoch 128/1000
#  - 2s - loss: 0.0313 - acc: 0.0279 - val_loss: 0.0666 - val_acc: 0.0098
# Epoch 129/1000
#  - 2s - loss: 0.0320 - acc: 0.0295 - val_loss: 0.0655 - val_acc: 0.0164
# Epoch 130/1000
#  - 2s - loss: 0.0320 - acc: 0.0279 - val_loss: 0.0694 - val_acc: 0.0098
# Epoch 131/1000
#  - 2s - loss: 0.0319 - acc: 0.0287 - val_loss: 0.0678 - val_acc: 0.0066
# Epoch 132/1000
#  - 2s - loss: 0.0323 - acc: 0.0304 - val_loss: 0.0631 - val_acc: 0.0066
# Epoch 133/1000
#  - 2s - loss: 0.0321 - acc: 0.0205 - val_loss: 0.0682 - val_acc: 0.0131
# Epoch 134/1000
#  - 2s - loss: 0.0308 - acc: 0.0238 - val_loss: 0.0634 - val_acc: 0.0098
# Epoch 135/1000
#  - 2s - loss: 0.0305 - acc: 0.0320 - val_loss: 0.0635 - val_acc: 0.0066
# Epoch 136/1000
#  - 2s - loss: 0.0320 - acc: 0.0271 - val_loss: 0.0652 - val_acc: 0.0066
# Epoch 137/1000
#  - 3s - loss: 0.0320 - acc: 0.0279 - val_loss: 0.0664 - val_acc: 0.0066
# Epoch 138/1000
#  - 2s - loss: 0.0313 - acc: 0.0279 - val_loss: 0.0626 - val_acc: 0.0066
# Epoch 139/1000
#  - 2s - loss: 0.0311 - acc: 0.0295 - val_loss: 0.0673 - val_acc: 0.0131
# Epoch 140/1000
#  - 2s - loss: 0.0311 - acc: 0.0271 - val_loss: 0.0610 - val_acc: 0.0033
# Epoch 141/1000
#  - 2s - loss: 0.0304 - acc: 0.0254 - val_loss: 0.0669 - val_acc: 0.0066
# Epoch 142/1000
#  - 2s - loss: 0.0323 - acc: 0.0254 - val_loss: 0.0619 - val_acc: 0.0098
# Epoch 143/1000
#  - 2s - loss: 0.0318 - acc: 0.0246 - val_loss: 0.0602 - val_acc: 0.0098
# Epoch 144/1000
#  - 2s - loss: 0.0315 - acc: 0.0295 - val_loss: 0.0634 - val_acc: 0.0066
# Epoch 145/1000
#  - 2s - loss: 0.0318 - acc: 0.0271 - val_loss: 0.0632 - val_acc: 0.0066
# Epoch 146/1000
#  - 2s - loss: 0.0316 - acc: 0.0205 - val_loss: 0.0630 - val_acc: 0.0098
# Epoch 147/1000
#  - 2s - loss: 0.0309 - acc: 0.0279 - val_loss: 0.0641 - val_acc: 0.0098
# Epoch 148/1000
#  - 2s - loss: 0.0315 - acc: 0.0230 - val_loss: 0.0613 - val_acc: 0.0098
# Epoch 149/1000
#  - 2s - loss: 0.0306 - acc: 0.0221 - val_loss: 0.0626 - val_acc: 0.0066
# Epoch 150/1000
#  - 2s - loss: 0.0307 - acc: 0.0213 - val_loss: 0.0655 - val_acc: 0.0098
# Epoch 151/1000
#  - 2s - loss: 0.0309 - acc: 0.0254 - val_loss: 0.0652 - val_acc: 0.0098
# Epoch 152/1000
#  - 2s - loss: 0.0308 - acc: 0.0238 - val_loss: 0.0626 - val_acc: 0.0066
# Epoch 153/1000
#  - 2s - loss: 0.0305 - acc: 0.0271 - val_loss: 0.0635 - val_acc: 0.0066
# Epoch 154/1000
#  - 2s - loss: 0.0299 - acc: 0.0295 - val_loss: 0.0613 - val_acc: 0.0164
# Epoch 155/1000
#  - 2s - loss: 0.0314 - acc: 0.0304 - val_loss: 0.0618 - val_acc: 0.0131
# Epoch 156/1000
#  - 2s - loss: 0.0304 - acc: 0.0295 - val_loss: 0.0615 - val_acc: 0.0164
# Epoch 157/1000
#  - 2s - loss: 0.0305 - acc: 0.0263 - val_loss: 0.0663 - val_acc: 0.0066
# Epoch 158/1000
#  - 2s - loss: 0.0312 - acc: 0.0328 - val_loss: 0.0644 - val_acc: 0.0098
# Epoch 159/1000
#  - 2s - loss: 0.0300 - acc: 0.0279 - val_loss: 0.0619 - val_acc: 0.0033
# Epoch 160/1000
#  - 2s - loss: 0.0304 - acc: 0.0221 - val_loss: 0.0605 - val_acc: 0.0098
# Epoch 161/1000
#  - 3s - loss: 0.0305 - acc: 0.0271 - val_loss: 0.0621 - val_acc: 0.0098
# Epoch 162/1000
#  - 3s - loss: 0.0305 - acc: 0.0246 - val_loss: 0.0645 - val_acc: 0.0164
# Epoch 163/1000
#  - 2s - loss: 0.0310 - acc: 0.0271 - val_loss: 0.0630 - val_acc: 0.0230
# Epoch 164/1000
#  - 2s - loss: 0.0302 - acc: 0.0295 - val_loss: 0.0651 - val_acc: 0.0164
# Epoch 165/1000
#  - 2s - loss: 0.0306 - acc: 0.0295 - val_loss: 0.0614 - val_acc: 0.0066
# Epoch 166/1000
#  - 2s - loss: 0.0304 - acc: 0.0279 - val_loss: 0.0645 - val_acc: 0.0098
# Epoch 167/1000
#  - 3s - loss: 0.0299 - acc: 0.0254 - val_loss: 0.0677 - val_acc: 0.0164
# Epoch 168/1000
#  - 2s - loss: 0.0301 - acc: 0.0336 - val_loss: 0.0632 - val_acc: 0.0131
# Epoch 169/1000
#  - 2s - loss: 0.0311 - acc: 0.0213 - val_loss: 0.0658 - val_acc: 0.0131
# Epoch 170/1000
#  - 2s - loss: 0.0303 - acc: 0.0320 - val_loss: 0.0607 - val_acc: 0.0197
# Epoch 171/1000
#  - 2s - loss: 0.0300 - acc: 0.0336 - val_loss: 0.0613 - val_acc: 0.0164
# Epoch 172/1000
#  - 2s - loss: 0.0304 - acc: 0.0263 - val_loss: 0.0640 - val_acc: 0.0098
# Epoch 173/1000
#  - 2s - loss: 0.0297 - acc: 0.0361 - val_loss: 0.0618 - val_acc: 0.0197
# Epoch 174/1000
#  - 2s - loss: 0.0315 - acc: 0.0320 - val_loss: 0.0643 - val_acc: 0.0164
# Epoch 175/1000
#  - 3s - loss: 0.0312 - acc: 0.0254 - val_loss: 0.0649 - val_acc: 0.0131
# Epoch 176/1000
#  - 2s - loss: 0.0300 - acc: 0.0164 - val_loss: 0.0618 - val_acc: 0.0164
# Epoch 177/1000
#  - 3s - loss: 0.0295 - acc: 0.0213 - val_loss: 0.0622 - val_acc: 0.0164
# Epoch 178/1000
#  - 2s - loss: 0.0301 - acc: 0.0279 - val_loss: 0.0657 - val_acc: 0.0131
# Epoch 179/1000
#  - 2s - loss: 0.0298 - acc: 0.0345 - val_loss: 0.0644 - val_acc: 0.0197
# Epoch 180/1000
#  - 2s - loss: 0.0300 - acc: 0.0287 - val_loss: 0.0631 - val_acc: 0.0164
# Epoch 181/1000
#  - 2s - loss: 0.0298 - acc: 0.0238 - val_loss: 0.0668 - val_acc: 0.0230
# Epoch 182/1000
#  - 2s - loss: 0.0298 - acc: 0.0205 - val_loss: 0.0659 - val_acc: 0.0098
# Epoch 183/1000
#  - 2s - loss: 0.0297 - acc: 0.0304 - val_loss: 0.0643 - val_acc: 0.0197
# Epoch 184/1000
#  - 2s - loss: 0.0306 - acc: 0.0221 - val_loss: 0.0546 - val_acc: 0.0164
# Epoch 185/1000
#  - 2s - loss: 0.0301 - acc: 0.0246 - val_loss: 0.0632 - val_acc: 0.0164
# Epoch 186/1000
#  - 2s - loss: 0.0297 - acc: 0.0295 - val_loss: 0.0611 - val_acc: 0.0164
# Epoch 187/1000
#  - 2s - loss: 0.0287 - acc: 0.0304 - val_loss: 0.0640 - val_acc: 0.0164
# Epoch 188/1000
#  - 2s - loss: 0.0296 - acc: 0.0246 - val_loss: 0.0655 - val_acc: 0.0131
# Epoch 189/1000
#  - 1s - loss: 0.0292 - acc: 0.0271 - val_loss: 0.0616 - val_acc: 0.0262
# Epoch 190/1000
#  - 3s - loss: 0.0293 - acc: 0.0263 - val_loss: 0.0601 - val_acc: 0.0131
# Epoch 191/1000
#  - 2s - loss: 0.0299 - acc: 0.0287 - val_loss: 0.0595 - val_acc: 0.0131
# Epoch 192/1000
#  - 2s - loss: 0.0294 - acc: 0.0304 - val_loss: 0.0648 - val_acc: 0.0164
# Epoch 193/1000
#  - 2s - loss: 0.0295 - acc: 0.0336 - val_loss: 0.0623 - val_acc: 0.0230
# Epoch 194/1000
#  - 2s - loss: 0.0292 - acc: 0.0295 - val_loss: 0.0663 - val_acc: 0.0098
# Epoch 195/1000
#  - 2s - loss: 0.0299 - acc: 0.0238 - val_loss: 0.0691 - val_acc: 0.0230
# Epoch 196/1000
#  - 2s - loss: 0.0293 - acc: 0.0263 - val_loss: 0.0601 - val_acc: 0.0131
# Epoch 197/1000
#  - 2s - loss: 0.0293 - acc: 0.0386 - val_loss: 0.0667 - val_acc: 0.0098
# Epoch 198/1000
#  - 3s - loss: 0.0292 - acc: 0.0263 - val_loss: 0.0653 - val_acc: 0.0066
# Epoch 199/1000
#  - 2s - loss: 0.0297 - acc: 0.0345 - val_loss: 0.0632 - val_acc: 0.0098
# Epoch 200/1000
#  - 2s - loss: 0.0291 - acc: 0.0180 - val_loss: 0.0661 - val_acc: 0.0066
# Epoch 201/1000
#  - 2s - loss: 0.0294 - acc: 0.0271 - val_loss: 0.0620 - val_acc: 0.0033
# Epoch 202/1000
#  - 2s - loss: 0.0297 - acc: 0.0304 - val_loss: 0.0675 - val_acc: 0.0000e+00
# Epoch 203/1000
#  - 2s - loss: 0.0290 - acc: 0.0238 - val_loss: 0.0615 - val_acc: 0.0066
# Epoch 204/1000
#  - 3s - loss: 0.0298 - acc: 0.0164 - val_loss: 0.0610 - val_acc: 0.0098
# Epoch 205/1000
#  - 3s - loss: 0.0295 - acc: 0.0238 - val_loss: 0.0645 - val_acc: 0.0033
# Epoch 206/1000
#  - 2s - loss: 0.0298 - acc: 0.0238 - val_loss: 0.0617 - val_acc: 0.0131
# Epoch 207/1000
#  - 2s - loss: 0.0291 - acc: 0.0254 - val_loss: 0.0641 - val_acc: 0.0066
# Epoch 208/1000
#  - 2s - loss: 0.0294 - acc: 0.0238 - val_loss: 0.0650 - val_acc: 0.0066
# Epoch 209/1000
#  - 2s - loss: 0.0293 - acc: 0.0238 - val_loss: 0.0652 - val_acc: 0.0033
# Epoch 210/1000
#  - 2s - loss: 0.0296 - acc: 0.0246 - val_loss: 0.0639 - val_acc: 0.0066
# Epoch 211/1000
#  - 2s - loss: 0.0285 - acc: 0.0238 - val_loss: 0.0679 - val_acc: 0.0098
# Epoch 212/1000
#  - 2s - loss: 0.0296 - acc: 0.0263 - val_loss: 0.0655 - val_acc: 0.0131
# Epoch 213/1000
#  - 3s - loss: 0.0295 - acc: 0.0271 - val_loss: 0.0651 - val_acc: 0.0197
# Epoch 214/1000
#  - 2s - loss: 0.0291 - acc: 0.0279 - val_loss: 0.0625 - val_acc: 0.0098
# Epoch 215/1000
#  - 2s - loss: 0.0287 - acc: 0.0246 - val_loss: 0.0676 - val_acc: 0.0164
# Epoch 216/1000
#  - 2s - loss: 0.0289 - acc: 0.0287 - val_loss: 0.0623 - val_acc: 0.0098
# Epoch 217/1000
#  - 2s - loss: 0.0292 - acc: 0.0287 - val_loss: 0.0637 - val_acc: 0.0197
# Epoch 218/1000
#  - 2s - loss: 0.0285 - acc: 0.0254 - val_loss: 0.0630 - val_acc: 0.0131
# Epoch 219/1000
#  - 2s - loss: 0.0294 - acc: 0.0377 - val_loss: 0.0648 - val_acc: 0.0131
# Epoch 220/1000
#  - 2s - loss: 0.0287 - acc: 0.0246 - val_loss: 0.0668 - val_acc: 0.0098
# Epoch 221/1000
#  - 2s - loss: 0.0285 - acc: 0.0287 - val_loss: 0.0648 - val_acc: 0.0164
# Epoch 222/1000
#  - 2s - loss: 0.0298 - acc: 0.0238 - val_loss: 0.0633 - val_acc: 0.0131
# Epoch 223/1000
#  - 2s - loss: 0.0289 - acc: 0.0304 - val_loss: 0.0665 - val_acc: 0.0098
# Epoch 224/1000
#  - 2s - loss: 0.0289 - acc: 0.0246 - val_loss: 0.0636 - val_acc: 0.0131
# Epoch 225/1000
#  - 2s - loss: 0.0285 - acc: 0.0328 - val_loss: 0.0657 - val_acc: 0.0066
# Epoch 226/1000
#  - 2s - loss: 0.0286 - acc: 0.0271 - val_loss: 0.0625 - val_acc: 0.0164
# Epoch 227/1000
#  - 2s - loss: 0.0289 - acc: 0.0221 - val_loss: 0.0651 - val_acc: 0.0164
# Epoch 228/1000
#  - 2s - loss: 0.0283 - acc: 0.0312 - val_loss: 0.0626 - val_acc: 0.0131
# Epoch 229/1000
#  - 2s - loss: 0.0291 - acc: 0.0197 - val_loss: 0.0610 - val_acc: 0.0164
# Epoch 230/1000

# %%
nan = np.genfromtxt('meep_code/data/EXTREME/DATA44_sp81.txt')

# %%
math.isnan(float(nan[0]))
# Out:
# True

# %%
a = [[],[]]

a[0][0]
a[0, 0]
