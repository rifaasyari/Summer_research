# %%
from matplotlib import pyplot as plt
import numpy as np
import math
#DIM=248
DIM=200

# %%
coordinates = np.genfromtxt('C:/Users/jeffe/Desktop/Summer_research/S4_code/data/DATA10_6_sh2.txt')
x, y = coordinates[:, 0], coordinates[:, 1]
plt.plot(x, y)
plt.axis('equal')
plt.fill(x, y)
plt.show()

# %%
# extract x axis
#x_axis = raw_data[:,1][0:50]
#plt.plot(x_axis, train_x[14])
data = np.genfromtxt('C:/Users/jeffe/Desktop/Summer_research/S4_code/data/DATA2-3_#13_sp.txt')
size = len(data)
c = 300
p = 0.6
x = np.multiply(data[:,0][0:size], c/p)
y = np.zeros((size, 1))
for i in range(size):
    y[i, 0] = math.sqrt(data[i, 1]**2 + data[i, 2]**2)
plt.ylim(0, 1.1)
plt.plot(x, y)
plt.show()

# %%
size
# Out:
# 200

# %% [markdown]
# ![image.png](attachment:image.png)size

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 150 太大 100 可能差不多 50太小

# %%
data = np.genfromtxt('C:/Users/jeffe/Desktop/Summer_research/DATA/DATA5/DATA5_4.txt')
size = len(data)

# %%
x = data[:,0]

# %%
y = data[:,1]
plt.ylim(0, 1.1)
plt.plot(x, y)
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
size = len(data)
c = 300
p = 0.6
x = np.multiply(data[:,0][0:size], c/p)
y = np.zeros((size, 1))
for i in range(size):
    y[i, 0] = math.sqrt(data[i, 1]**2 + data[i, 2]**2)
plt.ylim(0, 1.1)
plt.plot(x, y)
plt.show()

# %%
c = 300
p = 0.6
# get data from the source
raw_data = np.genfromtxt('C:/Users/jeffe/Desktop/Summer_research/S4_code/data/DATA2_#7_sp.txt')
raw_data_size = len(raw_data)
size = raw_data_size // DIM
print(size)
# we only need two type of data transmission and its according transmission
# initialize a 2D array (len(raw_data), 2) with all zeros
flat_Y = np.zeros((raw_data_size, 1))
# calculate transmission
# formula: a**2 + b**2
for i in range(raw_data_size):
    flat_Y[i, 0] = math.sqrt(raw_data[i, 1]**2 + raw_data[i, 2]**2)
# learn from 83 equally seperated points from spectrum
Y = np.reshape(flat_Y[:, -1], (size, DIM))
#x = raw_data[:,0][0:DIM]
x = np.multiply(raw_data[:,0][0:DIM], c/p)

shape_size = 48
coordinates = np.genfromtxt('C:/Users/jeffe/Desktop/Summer_research/S4_code/data/DATA2_#7_sh.txt')
xc, yc = coordinates[:, 0], coordinates[:, 1]
xc = np.reshape(xc, (size, shape_size))
yc = np.reshape(yc, (size, shape_size))


for i in range(size):
    print(i)
    plt.ylim(0, 1.1)
    plt.plot(x, Y[i])
    plt.show()
    plt.axis('equal')
    plt.ylim(-0.5, 0.5)
    plt.xlim(-0.5, 0.5)
    plt.plot(xc[i], yc[i])
    plt.fill(xc[i], yc[i])
    plt.show()
# Out:
# 7
# 0
# 1
# 2
# 3
# 4
# 5
# 6

# %%
i = 5
plt.axis('equal')
plt.ylim(-0.5, 0.5)
plt.xlim(-0.5, 0.5)
plt.plot(xc[i], yc[i])
plt.fill(xc[i], yc[i])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-106-0b4facaa3947> in <module>
#       3 plt.ylim(-0.5, 0.5)
#       4 plt.xlim(-0.5, 0.5)
# ----> 5 plt.plot(xc[i], yc[i])
#       6 plt.fill(xc[i], yc[i])
#       7 plt.show()
#
# IndexError: index 5 is out of bounds for axis 0 with size 5

# %%
plt.plot(x, Y[i])
plt.show()

# %%
for j in range(len(xc[i])):
    print(xc[i, j], yc[i, j])
# Out:
# 0.28531695488855 0.0
# 0.28531695488855 0.045189766215123
# 0.28531695488855 0.092705098312484
# 0.22321047902219 0.11373141965565
# 0.17773052549399 0.12912878529612
# 0.14142135623731 0.14142135623731
# 0.14142135623731 0.14142135623731
# 0.12912878529612 0.17773052549399
# 0.11373141965565 0.22321047902219
# 0.092705098312484 0.28531695488855
# 0.045189766215123 0.28531695488855
# 0.0 0.28531695488855
# -0.0 0.28531695488855
# -0.045189766215123 0.28531695488855
# -0.092705098312484 0.28531695488855
# -0.11373141965565 0.22321047902219
# -0.12912878529612 0.17773052549399
# -0.14142135623731 0.14142135623731
# -0.14142135623731 0.14142135623731
# -0.17773052549399 0.12912878529612
# -0.22321047902219 0.11373141965565
# -0.28531695488855 0.092705098312484
# -0.28531695488855 0.045189766215123
# -0.28531695488855 0.0
# -0.28531695488855 -0.0
# -0.28531695488855 -0.045189766215123
# -0.28531695488855 -0.092705098312484
# -0.22321047902219 -0.11373141965565
# -0.17773052549399 -0.12912878529612
# -0.14142135623731 -0.14142135623731
# -0.14142135623731 -0.14142135623731
# -0.12912878529612 -0.17773052549399
# -0.11373141965565 -0.22321047902219
# -0.092705098312484 -0.28531695488855
# -0.045189766215123 -0.28531695488855
# -0.0 -0.28531695488855
# 0.0 -0.28531695488855
# 0.045189766215123 -0.28531695488855
# 0.092705098312484 -0.28531695488855
# 0.11373141965565 -0.22321047902219
# 0.12912878529612 -0.17773052549399
# 0.14142135623731 -0.14142135623731
# 0.14142135623731 -0.14142135623731
# 0.17773052549399 -0.12912878529612
# 0.22321047902219 -0.11373141965565
# 0.28531695488855 -0.092705098312484
# 0.28531695488855 -0.045189766215123
# 0.28531695488855 -0.0

# %%
filt = [2, 4]
saveSP = np.array(np.reshape(Y[0], (1, 200)))
for i in range(1, size):
    if i in filt:
        continue
    saveSP = np.concatenate((saveSP, np.reshape(Y[i], (1, 200))))

# %%
supply = np.genfromtxt('C:/Users/jeffe/Desktop/Summer_research/DATA/DATA5/DATA5_4.txt')
origin_s = supply[:,1]
shrink_s = []

# %%
for i in range(0, len(origin_s)-1, 5):
    shrink_s.append(origin_s[i])

# %%
len(shrink_s)
# Out:
# 200

# %%
saveSP = np.concatenate((saveSP, np.reshape(np.array(shrink_s), (1, 200))))

# %%
len(saveSP)
# Out:
# 5

# %%
np.savetxt('DATA/DATA5X.txt', saveSP)

# %%
read = np.genfromtxt('C:/Users/jeffe/Desktop/Summer_research/DATA/DATA5X.txt')

# %%
read.shape
# Out:
# (5, 200)

# %%
for i in range(size - 1):
    print(i)
    plt.ylim(0, 1.1)
    plt.plot(x, saveSP[i])
    plt.show()
# Out:
# 0
# 1
# 2
# 3
