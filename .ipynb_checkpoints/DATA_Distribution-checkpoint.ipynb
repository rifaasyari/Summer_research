# %%
import os
import sys
sys.path.append("numpy_path")
import numpy as np
from matplotlib import pyplot as plt
from math import cos, sin, pi
import math
from statistics import mean
import os.path
import random

def dis_sec_p(begin = 200, end = 300, show_pic = False, peak = [k for k in range(1, num_peak + 1)]):
    dis = []
    for i in range(num_peak):
        dis.append([])
    for i in range(0, len(distribution) - 1, 2):
        first_peak = (distribution[i][0] + distribution[i + 1][0]) / 2
        if begin <= first_peak < end:
            for j in range(num_peak):
                dis[j].append([random.random(), (distribution[i][j] + distribution[i + 1][j]) / 2])
            if show_pic:
                plt.ylim(0, 1.1)
                plt.plot(x, SP_F[i//2])
                plt.show()
    dis = np.array(dis)
    if len(dis[0]) == 0:
        print('No first peak in ['+str(begin)+', '+str(end)+')')
        return 
    print(dis.shape)
    plt.xlim(200, 300)
    for p in peak:
        plt.scatter(dis[p - 1,:,1],dis[p - 1,:,0])

    print("{0:.4f}".format(len(dis[0])/len(SP_F)*100)
        +'% ('+str(len(dis[0]))+' out of '+str(len(SP_F))
          +') spectrum with ' + str(num_peak) + ' peaks, its first peak lies in ['+str(begin)+', '+str(end)+')')

shape_size = 48

# %%
data_size = 0
dummy1 = [0]*200
dummy2 = [0]*6
SP = np.array(np.reshape(dummy1, (1, 200)))
SH = np.array(np.reshape(dummy2, (1, 6)))
for i in range(2, 65):
    path = 'meep_code/data/DATA'+str(i)
    if not os.path.exists(path):
        #miss.append(i)
        print('Missing batch:' + str(i))
        continue
        
    files = next(os.walk(path))[2] #dir is your directory path as string]
    num_data = len(files)
    data_size += num_data
    skip = []
    
    coordinates = np.genfromtxt('meep_code/data/DATA'+str(i)+'_sh.txt')
    xc, yc = coordinates[:, 0], coordinates[:, 1]
    xc = np.reshape(xc, (num_data, shape_size))
    yc = np.reshape(yc, (num_data, shape_size))
    
    for j in range(num_data):
        tmp = np.genfromtxt(path+'/'+'DATA'+str(i)+'_sp'+str(j)+'.txt')
        valid = True
        for q in range(200):       
            if tmp[q] > 3:
                print('Batch '+str(i)+'\tsample '+str(j)+' has extreme value')
                valid = False
                break
        if not valid:
            #skip.append(j)
            continue
        SP = np.concatenate((SP, np.reshape(tmp, (1, 200))))
        tmp = []
        for q in range(6):
            tmp.append(math.sqrt(xc[j][q]**2 + yc[j][q]**2))
        SH = np.concatenate((SH, np.reshape(np.array(tmp), (1, 6))))
    print('Batch '+str(i)+' has \t'+str(num_data))
# Out:
# Batch 2 has 	7
# Batch 3 has 	6
# Batch 4 has 	17
# Batch 5 has 	5
# Batch 6 has 	14
# Batch 7 has 	14
# Batch 8 has 	40
# Batch 9 has 	5
# Batch 10 has 	14
# Batch 11 has 	14
# Batch 12 has 	40
# Batch 13 has 	13
# Batch 14 has 	37
# Batch 15 has 	37
# Batch 16 has 	106
# Batch 17 has 	5
# Batch 18 has 	14
# Batch 19 has 	14
# Batch 20 has 	40
# Batch 21 has 	13
# Batch 22 has 	37
# Batch 23 has 	37
# Batch 24 has 	106
# Batch 25 has 	13
# Batch 26 has 	37
# Batch 27 has 	37
# Batch 28 has 	106
# Batch 29 has 	35
# Batch 30 has 	100
# Batch 31 has 	100
# Batch 32 has 	287
# Batch 33 has 	5
# Batch 34 has 	14
# Batch 35 has 	14
# Batch 36 has 	40
# Batch 37 has 	13
# Batch 38 has 	37
# Batch 39 has 	37
# Batch 40 has 	106
# Batch 41 has 	13
# Batch 42 has 	37
# Batch 43 has 	37
# Batch 44 has 	106
# Batch 45 has 	35
# Batch 46 has 	100
# Batch 47 has 	100
# Batch 48 has 	287
# Batch 49 has 	13
# Batch 50 has 	37
# Batch 51 has 	37
# Batch 52 has 	106
# Batch 53 has 	35
# Batch 54 has 	100
# Batch 55 has 	100
# Batch 56 has 	287
# Batch 57 has 	35
# Batch 58 has 	100
# Batch 59 has 	100
# Batch 60 has 	287
# Batch 61 has 	95
# Batch 62 has 	272
# Batch 63 has 	272
# Batch 64 has 	781

# %%
num_peak = 4
distribution = []
print('Total # of data: ' + str(len(SP)))
x = np.genfromtxt('meep_code/data/SP_xaxis.txt')
SP_F, SH_F = np.reshape(SP[1], (1, 200)),np.reshape(SH[1], (1, 6))

for i in range(1, len(SP)):
    p_u, p_d = 0, 0
    p_u_pos, p_d_pos = [], []
    for j in range(1, 200):
        if SP[i][j - 1] >= 0.6 >=SP[i][j]:
            p_d += 1
            p_d_pos.append(j / 2 + 200)
        if SP[i][j - 1] <= 0.6 <=SP[i][j]:
            p_u += 1
            p_u_pos.append(j / 2 + 200)
    if p_d == p_u and p_d == num_peak:
        distribution.append(p_d_pos)
        distribution.append(p_u_pos)
        SP_F = np.concatenate((SP_F, np.reshape(SP[i], (1, 200))))
        SH_F = np.concatenate((SH_F, np.reshape(SH[i], (1, 6))))
#         plt.ylim(0, 1.1)
#         plt.plot(x, SP[i])
#         plt.show()
#         print(p_d_pos)
#         print(p_u_pos)
SP_F = SP_F[1:,:]
SH_F = SH_F[1:,:]
# Out:
# Total # of data: 4989

# %%
len(distribution)
# Out:
# 1676

# %%
dis_sec_p()
# Out:
# (1, 413, 2)
# 100.0000% (413 out of 413) spectrum with 1peaks, its first peak lies in [200, 300)

# %% [markdown]
# # Distribution of fourth peak

# %%
dis_sec_p()
# Out:
# (4, 470, 2)
# 100.0000% (470 out of 470) spectrum with 4 peaks, its first peak lies in [200, 300)

# %% [markdown]
# ### First peak distribution

# %%
dis_sec_p(peak = [1])
# Out:
# (4, 470, 2)
# 100.0000% (470 out of 470) spectrum with 4 peaks, its first peak lies in [200, 300)

# %% [markdown]
# ### Second peak distribution

# %%
dis_sec_p(peak = [2])
# Out:
# (4, 470, 2)
# 100.0000% (470 out of 470) spectrum with 4 peaks, its first peak lies in [200, 300)

# %% [markdown]
# ### Third peak distribution

# %%
dis_sec_p(peak = [3])
# Out:
# (4, 470, 2)
# 100.0000% (470 out of 470) spectrum with 4 peaks, its first peak lies in [200, 300)

# %% [markdown]
# ### fourth peak distribution

# %%
dis_sec_p(peak = [4])
# Out:
# (4, 470, 2)
# 100.0000% (470 out of 470) spectrum with 4 peaks, its first peak lies in [200, 300)

# %%
dis_sec_p(200,220)
# Out:
# (4, 233, 2)
# 49.5745% (233 out of 470) spectrum with 4 peaks, its first peak lies in [200, 220)

# %%
dis_sec_p(220,240)
# Out:
# (4, 219, 2)
# 46.5957% (219 out of 470) spectrum with 4 peaks, its first peak lies in [220, 240)

# %%
dis_sec_p(240,260)
# Out:
# (4, 18, 2)
# 3.8298% (18 out of 470) spectrum with 4 peaks, its first peak lies in [240, 260)

# %%
dis_sec_p(260,280)
# Out:
# No first peak in [260, 280)

# %%
dis_sec_p(280,300)
# Out:
# No first peak in [280, 300)

# %% [markdown]
# # Distribution of Three peak

# %%
dis_sec_p()
# Out:
# (3, 349, 2)
# 100.0000% (349 out of 349) spectrum with 3peaks, its first peak lies in [200, 300)

# %% [markdown]
# ### First peak distribution

# %%
dis_sec_p(peak = [1])
# Out:
# (3, 349, 2)
# 100.0000% (349 out of 349) spectrum with 3 peaks, its first peak lies in [200, 300)

# %% [markdown]
# ### Second peak distribution

# %%
dis_sec_p(peak = [2])
# Out:
# (3, 349, 2)
# 100.0000% (349 out of 349) spectrum with 3 peaks, its first peak lies in [200, 300)

# %% [markdown]
# ### Third peak distribution

# %%
dis_sec_p(peak = [3])
# Out:
# (3, 349, 2)
# 100.0000% (349 out of 349) spectrum with 3 peaks, its first peak lies in [200, 300)

# %%
dis_sec_p(200,220)
# Out:
# (3, 76, 2)
# 21.7765% (76 out of 349) spectrum with 3 peaks, its first peak lies in [200, 220)

# %%
dis_sec_p(220,240)
# Out:
# (3, 254, 2)
# 72.7794% (254 out of 349) spectrum with 3 peaks, its first peak lies in [220, 240)

# %%
dis_sec_p(240,260)
# Out:
# (3, 19, 2)
# 5.4441% (19 out of 349) spectrum with 3 peaks, its first peak lies in [240, 260)

# %%
dis_sec_p(260,280)
# Out:
# No first peak in [260, 280)

# %%
dis_sec_p(280,300)
# Out:
# No first peak in [280, 300)

# %% [markdown]
# # Distribution of Two peak

# %% [markdown]
# ## Distribution of the first of Two peak

# %%
dis_sec_p(peak = [1])
# Out:
# (2, 838, 2)
# 100.0000% (838 out of 838) spectrum with 2 peaks, its first peak lies in [200, 300)

# %% [markdown]
# ## Distribution of the second of Two peak

# %%
dis_sec_p(peak=[2])
# Out:
# (2, 838, 2)
# 100.0000% (838 out of 838) spectrum with 2 peaks, its first peak lies in [200, 300)

# %%
dis_sec_p()
# Out:
# (2, 838, 2)
# 100.0000% (838 out of 838) spectrum with 2 peaks, its first peak lies in [200, 300)

# %% [markdown]
# ## Distribution of the second peak where the first peak is in [200, 220)

# %%
dis_sec_p(200, 220)
# Out:
# 2.5060% (21 out of 838) spectrum with two peaks, its first peak lies in [200, 220)

# %%
dis_sec_p(220, 230)
# Out:
# 4.8926% (41 out of 838) spectrum with two peaks, its first peak lies in [220, 230)

# %%
dis_sec_p(230, 240)
# Out:
# 23.5084% (197 out of 838) spectrum with two peaks, its first peak lies in [230, 240)

# %%
dis_sec_p(240, 250, True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-57-aba482f218c3> in <module>
# ----> 1 dis_sec_p(240, 250, True)
#
# <ipython-input-40-ce66d2a80edc> in dis_sec_p(begin, end, show_pic)
#      22                 plt.ylim(0, 1.1)
#      23                 plt.plot(x, SP_F[i//2])
# ---> 24                 plt.show()
#      25     dis_fir = np.array(dis_fir)
#      26     dis_sec = np.array(dis_sec)
#
# ~/anaconda3/envs/mp/lib/python3.6/site-packages/matplotlib/pyplot.py in show(*args, **kw)
#     261     """
#     262     global _show
# --> 263     return _show(*args, **kw)
#     264
#     265
#
# ~/anaconda3/envs/mp/lib/python3.6/site-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      37             display(
#      38                 figure_manager.canvas.figure,
# ---> 39                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      40             )
#      41     finally:
#
# ~/anaconda3/envs/mp/lib/python3.6/site-packages/ipykernel/pylab/backend_inline.py in _fetch_figure_metadata(fig)
#     175         # the background is transparent
#     176         ticksLight = _is_light([label.get_color()
# --> 177                                 for axes in fig.axes
#     178                                 for axis in (axes.xaxis, axes.yaxis)
#     179                                 for label in axis.get_ticklabels()])
#
# ~/anaconda3/envs/mp/lib/python3.6/site-packages/ipykernel/pylab/backend_inline.py in <listcomp>(.0)
#     177                                 for axes in fig.axes
#     178                                 for axis in (axes.xaxis, axes.yaxis)
# --> 179                                 for label in axis.get_ticklabels()])
#     180         if ticksLight.size and (ticksLight == ticksLight[0]).all():
#     181             # there are one or more tick labels, all with the same lightness
#
# ~/anaconda3/envs/mp/lib/python3.6/site-packages/matplotlib/axis.py in get_ticklabels(self, minor, which)
#    1295         if minor:
#    1296             return self.get_minorticklabels()
# -> 1297         return self.get_majorticklabels()
#    1298
#    1299     def get_majorticklines(self):
#
# ~/anaconda3/envs/mp/lib/python3.6/site-packages/matplotlib/axis.py in get_majorticklabels(self)
#    1251     def get_majorticklabels(self):
#    1252         'Return a list of Text instances for the major ticklabels.'
# -> 1253         ticks = self.get_major_ticks()
#    1254         labels1 = [tick.label1 for tick in ticks if tick.label1.get_visible()]
#    1255         labels2 = [tick.label2 for tick in ticks if tick.label2.get_visible()]
#
# ~/anaconda3/envs/mp/lib/python3.6/site-packages/matplotlib/axis.py in get_major_ticks(self, numticks)
#    1410         while len(self.majorTicks) < numticks:
#    1411             # Update the new tick label properties from the old.
# -> 1412             tick = self._get_tick(major=True)
#    1413             self.majorTicks.append(tick)
#    1414             tick.gridline.set_visible(self._gridOnMajor)
#
# ~/anaconda3/envs/mp/lib/python3.6/site-packages/matplotlib/axis.py in _get_tick(self, major)
#    1904         else:
#    1905             tick_kw = self._minor_tick_kw
# -> 1906         return XTick(self.axes, 0, '', major=major, **tick_kw)
#    1907
#    1908     def _get_label(self):
#
# ~/anaconda3/envs/mp/lib/python3.6/site-packages/matplotlib/axis.py in __init__(self, axes, loc, label, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major, labelrotation, grid_color, grid_linestyle, grid_linewidth, grid_alpha, **kw)
#     157
#     158         self.tick1line = self._get_tick1line()
# --> 159         self.tick2line = self._get_tick2line()
#     160         self.gridline = self._get_gridline()
#     161         self.label1 = self._get_text1()
#
# ~/anaconda3/envs/mp/lib/python3.6/site-packages/matplotlib/axis.py in _get_tick2line(self)
#     476                           markersize=self._size,
#     477                           markeredgewidth=self._width,
# --> 478                           zorder=self._zorder)
#     479
#     480         l.set_transform(self.axes.get_xaxis_transform(which='tick2'))
#
# ~/anaconda3/envs/mp/lib/python3.6/site-packages/matplotlib/lines.py in __init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     380         self._color = None
#     381         self.set_color(color)
# --> 382         self._marker = MarkerStyle(marker, fillstyle)
#     383
#     384         self._markevery = None
#
# ~/anaconda3/envs/mp/lib/python3.6/site-packages/matplotlib/markers.py in __init__(self, marker, fillstyle)
#     241         self._marker_function = None
#     242         self.set_fillstyle(fillstyle)
# --> 243         self.set_marker(marker)
#     244
#     245     def _recache(self):
#
# ~/anaconda3/envs/mp/lib/python3.6/site-packages/matplotlib/markers.py in set_marker(self, marker)
#     314
#     315         self._marker = marker
# --> 316         self._recache()
#     317
#     318     def get_path(self):
#
# ~/anaconda3/envs/mp/lib/python3.6/site-packages/matplotlib/markers.py in _recache(self)
#     254         self._capstyle = 'butt'
#     255         self._filled = True
# --> 256         self._marker_function()
#     257
#     258     def __bool__(self):
#
# ~/anaconda3/envs/mp/lib/python3.6/site-packages/matplotlib/markers.py in _set_tickup(self)
#     761
#     762     def _set_tickup(self):
# --> 763         self._transform = Affine2D().scale(1.0, 1.0)
#     764         self._snap_threshold = 1.0
#     765         self._filled = False
#
# ~/anaconda3/envs/mp/lib/python3.6/site-packages/matplotlib/transforms.py in scale(self, sx, sy)
#    1988             sy = sx
#    1989         scale_mtx = np.array(
# -> 1990             [[sx, 0.0, 0.0], [0.0, sy, 0.0], [0.0, 0.0, 1.0]], float)
#    1991         self._mtx = np.dot(scale_mtx, self._mtx)
#    1992         self.invalidate()
#
# KeyboardInterrupt:

# %%
dis_sec_p(250, 260, False)
# Out:
# 27.3270% (229 out of 838) spectrum with two peaks, its first peak lies in [250, 260)

# %%
dis_sec_p(260, 270)
# Out:
# 11.9332% (100 out of 838) spectrum with two peaks, its first peak lies in [260, 270)

# %%
dis_sec_p(270, 280)
# Out:
# 1.9093% (16 out of 838) spectrum with two peaks, its first peak lies in [270, 280)

# %%
dis_sec_p(280, 290)
# Out:
# 0.2387% (2 out of 838) spectrum with two peaks, its first peak lies in [280, 290)

# %% [markdown]
# # Distribution of One peak

# %%
dis_sec_p()
# Out:
# (1, 413, 2)
# 100.0000% (413 out of 413) spectrum with 1peaks, its first peak lies in [200, 300)
