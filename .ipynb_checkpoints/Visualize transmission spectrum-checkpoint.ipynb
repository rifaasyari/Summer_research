# %%
from matplotlib import pyplot as plt
import numpy as np
import math
DIM = 83

# %%
coordinates = np.genfromtxt('C:/Users/jeffe/Desktop/Summer_research/S4_code/data/test_shape10.txt')
x, y = coordinates[:, 0], coordinates[:, 1]
plt.plot(x, y)
plt.axis('equal')
plt.fill(x, y)
plt.show()

# %%
len(x)
# Out:
# 48

# %%
# extract x axis
#x_axis = raw_data[:,1][0:50]
#plt.plot(x_axis, train_x[14])
data = np.genfromtxt('C:/Users/jeffe/Desktop/Summer_research/S4_code/data/poly_test_multi_point_no_overlap.txt')
size = len(data)
c = 300
p = 0.6
x = np.multiply(data[:,0][0:size], c/p)
y = np.zeros((size, 1))
for i in range(size):
    y[i, 0] = math.sqrt(data[i, 1]**2 + data[i, 2]**2)
plt.ylim(0, 1.1)
plt.plot(x, y)
plt.show()

# %%
# extract x axis
#x_axis = raw_data[:,1][0:50]
#plt.plot(x_axis, train_x[14])
data = np.genfromtxt('C:/Users/jeffe/Desktop/Summer_research/S4_code/data/poly_test_multi_point_no_overlap.txt')
size = len(data)
x = np.multiply(data[:,0][0:size], c/p)
y = data[:,1][0:size]
plt.ylim(0, 1.1)
plt.plot(x, y)
plt.show()

# %%
# get data from the source
raw_data = np.genfromtxt('C:/Users/jeffe/Desktop/Summer_research/S4_code/data/DATA3-5_#17_spectrum.txt')
raw_data_size = len(raw_data)
size = raw_data_size // DIM
# we only need two type of data transmission and its according transmission
# initialize a 2D array (len(raw_data), 2) with all zeros
flat_Y = np.zeros((raw_data_size, 1))
# calculate transmission
# formula: a**2 + b**2
for i in range(raw_data_size):
    flat_Y[i, 0] = raw_data[i, 1]**2 + raw_data[i, 2]**2
# learn from 83 equally seperated points from spectrum
Y = np.reshape(flat_X[:, -1], (size, DIM))
x = raw_data[:,0][0:DIM]

shape_size = 48
coordinates = np.genfromtxt('C:/Users/jeffe/Desktop/Summer_research/S4_code/data/DATA3-5_#17_shape.txt')
xc, yc = coordinates[:, 0], coordinates[:, 1]
xc = np.reshape(xc, (size, shape_size))
yc = np.reshape(yc, (size, shape_size))


for i in range(size):
    plt.ylim(0, 1.1)
    plt.plot(x, Y[i])
    plt.show()
    plt.axis('equal')
    plt.ylim(-0.5, 0.5)
    plt.xlim(-0.5, 0.5)
    plt.plot(xc[i], yc[i])
    plt.fill(xc[i], yc[i])
    plt.show()D

# %%
i = 6
plt.axis('equal')
plt.ylim(-0.5, 0.5)
plt.xlim(-0.5, 0.5)
plt.plot(xc[i], yc[i])
plt.fill(xc[i], yc[i])
plt.show()

# %%
for j in range(len(xc[i])):
    print(xc[i, j], yc[i, j])
# Out:
# 0.24270509831248 0.0
# 0.24270509831248 0.038440711160134
# 0.24270509831248 0.07885966681787
# 0.24270509831248 0.12366442431226
# 0.24270509831248 0.17633557568774
# 0.21213203435596 0.21213203435596
# 0.21213203435596 0.21213203435596
# 0.17633557568774 0.24270509831248
# 0.12366442431226 0.24270509831248
# 0.07885966681787 0.24270509831248
# 0.038440711160134 0.24270509831248
# 0.0 0.24270509831248
# -0.0 0.24270509831248
# -0.038440711160134 0.24270509831248
# -0.07885966681787 0.24270509831248
# -0.12366442431226 0.24270509831248
# -0.17633557568774 0.24270509831248
# -0.21213203435596 0.21213203435596
# -0.21213203435596 0.21213203435596
# -0.24270509831248 0.17633557568774
# -0.24270509831248 0.12366442431226
# -0.24270509831248 0.07885966681787
# -0.24270509831248 0.038440711160134
# -0.24270509831248 0.0
# -0.24270509831248 -0.0
# -0.24270509831248 -0.038440711160134
# -0.24270509831248 -0.07885966681787
# -0.24270509831248 -0.12366442431226
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
shape_size = 48
coordinates = np.genfromtxt('C:/Users/jeffe/Desktop/Summer_research/S4_code/data/DATA15_#41_shape.txt')
xc, yc = coordinates[:, 0], coordinates[:, 1]
size = len(xc) // shape_size
xc = np.reshape(xc, (size, shape_size))
yc = np.reshape(yc, (size, shape_size))
for i in range(size):
    plt.axis('equal')
    plt.ylim(-0.5, 0.5)
    plt.xlim(-0.5, 0.5)
    plt.plot(xc[i], yc[i])
    plt.fill(xc[i], yc[i])
    plt.show()
