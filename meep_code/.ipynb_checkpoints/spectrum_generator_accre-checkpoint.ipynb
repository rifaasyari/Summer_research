# %%
import numpy as np
import math
import meep as mp
import cmath

shape_size = 48

sx, sy, sz = 1, 1, 4
h = 1.25
dpml = 0.5
b_m, c_m = 1.4, 3.54
res = 15
echo = 1000
cell_size = mp.Vector3(sx,sy,sz)
fcen = 0.5
df = 0.2
theta = math.radians(0)
nfreq = 200

# k with correct length (plane of incidence: XZ) 
k = mp.Vector3(math.sin(theta),0,math.cos(theta)).scale(fcen)
def pw_amp(k, x0):
    def _pw_amp(x):
        return cmath.exp(1j * 2 * math.pi * k.dot(x + x0))
    return _pw_amp

def get_trans(vertices):
    geometry = [mp.Block(size = cell_size, material=mp.Medium(index=b_m)),
                mp.Prism(vertices, 
                         height=h, 
                         material=mp.Medium(index=c_m),
                         center=mp.Vector3()
                        )]
    pml_layers = [mp.PML(thickness=1, direction = mp.Z, side=mp.High),
                  mp.Absorber(thickness=1,direction = mp.Z, side=mp.Low)]
    src_pos = -(sz/2 - dpml - 0.5)
    src = [mp.Source(src = mp.GaussianSource(fcen, fwidth=df),
                     component = mp.Ey,
                     center = mp.Vector3(0,0,src_pos),
                     size = mp.Vector3(sx,sy,0),
                     amp_func=pw_amp(k,mp.Vector3(0,0,src_pos)))]
    sim = mp.Simulation(resolution=res,
                        cell_size=cell_size,
                        boundary_layers=pml_layers,
                        sources=src,
                        geometry=geometry,
                        k_point=k)
    freg = mp.FluxRegion(center=mp.Vector3(0,0,-src_pos),
                         size = mp.Vector3(sx,sy,0))
    trans = sim.add_flux(fcen, df, nfreq, freg)
    sim.run(until = echo)
    bend = mp.get_fluxes(trans)
    
    #get straight
    sim.reset_meep()
    geometry = [mp.Block(size = cell_size, material=mp.Medium(index=b_m))]
    pml_layers = [mp.PML(thickness= 1, direction = mp.Z, side=mp.High),
                  mp.Absorber(thickness=1,direction = mp.Z, side=mp.Low)]
    src = [mp.Source(src = mp.GaussianSource(fcen, fwidth=df),
                     component = mp.Ey,
                     center = mp.Vector3(0,0,src_pos),
                     size = mp.Vector3(sx,sy,0),
                     amp_func=pw_amp(k,mp.Vector3(0,0,src_pos)))]
    sim = mp.Simulation(resolution=res,
                        cell_size=cell_size,
                        boundary_layers=pml_layers,
                        sources=src,
                        geometry=geometry,
                        k_point=k)
    freg = mp.FluxRegion(center=mp.Vector3(0,0,-src_pos),
                         size = mp.Vector3(sx,sy,0))
    trans = sim.add_flux(fcen, df, nfreq, freg)
    sim.run(until = echo)
    straight = mp.get_fluxes(trans)
    flux_freqs = mp.get_flux_freqs(trans)
    
    c = 300
    p = 0.6
    Ts = []
    for i in range(nfreq):
        Ts = np.append(Ts, bend[i]/straight[i])
    return np.multiply(flux_freqs, c/p),Ts

# %%
def data_generator(batch):
    data = []
    # get shape from 'data/DATAX_sh.txt'
    coordinates = np.genfromtxt('data/DATA'+str(batch)+'_sh.txt')
    xc, yc = coordinates[:, 0], coordinates[:, 1]
    size = len(xc) // shape_size
    xc = np.reshape(xc, (size, shape_size))
    yc = np.reshape(yc, (size, shape_size))

    for i in range(size):
        # form shape
        vertices = [mp.Vector3(xc[i][0],yc[i][0])]
        for j in range(1, len(xc[i]) - 1):
            # eliminate duplicate point
            if xc[i][j] == xc[i][j - 1] and yc[i][j] == yc[i][j - 1]:
                continue
            vertices.append(mp.Vector3(xc[i][j], yc[i][j]))
        # calculate transmission
        _, Ts = get_trans(vertices)
        data.append(Ts)
    # save the spectrum to 'data/DATAX_sp.txt'
    np.savetxt('data/DATA'+str(batch)+'_sp.txt', data)
#     x = np.genfromtxt('data/SP_xaxis.txt')
#     y = np.genfromtxt('data/DATA'+str(batch)+'_sp.txt')
#     for i in range(size):
#         print('The '+str(i)+'th shape:')
#         plt.axis('equal')
#         plt.ylim(-0.5, 0.5)
#         plt.xlim(-0.5, 0.5)
#         plt.plot(xc[i], yc[i])
#         plt.fill(xc[i], yc[i])
#         plt.show()
#         plt.ylim(0, 1.1)
#         plt.plot(x, y[i])
#         plt.show()

# %%
start, end = 5, 6
for i in range(start, end):
    data_generator(i)
# Out:
# -----------
# Initializing structure...
# Meep: using complex fields.
# Meep progress: 17.933333333333334/1000.0 = 1.8% done in 4.0s, 219.2s to go
# Meep progress: 36.666666666666664/1000.0 = 3.7% done in 8.0s, 210.4s to go
# Meep progress: 55.3/1000.0 = 5.5% done in 12.0s, 205.2s to go
# Meep progress: 73.56666666666666/1000.0 = 7.4% done in 16.0s, 201.7s to go
# Meep progress: 92.53333333333333/1000.0 = 9.3% done in 20.0s, 196.4s to go
# Meep progress: 111.56666666666666/1000.0 = 11.2% done in 24.0s, 191.3s to go
# Meep progress: 130.3/1000.0 = 13.0% done in 28.0s, 187.1s to go
# Meep progress: 148.43333333333334/1000.0 = 14.8% done in 32.0s, 183.8s to go
# Meep progress: 166.96666666666667/1000.0 = 16.7% done in 36.0s, 179.8s to go
# Meep progress: 185.7/1000.0 = 18.6% done in 40.0s, 175.6s to go
# Meep progress: 204.43333333333334/1000.0 = 20.4% done in 44.0s, 171.4s to go
# Meep progress: 222.4/1000.0 = 22.2% done in 48.0s, 168.0s to go
# Meep progress: 240.63333333333333/1000.0 = 24.1% done in 52.1s, 164.3s to go
# Meep progress: 258.93333333333334/1000.0 = 25.9% done in 56.1s, 160.4s to go
# Meep progress: 277.3333333333333/1000.0 = 27.7% done in 60.1s, 156.5s to go
# Meep progress: 294.5/1000.0 = 29.4% done in 64.1s, 153.5s to go
# Meep progress: 312.8666666666667/1000.0 = 31.3% done in 68.1s, 149.5s to go
# Meep progress: 331.5/1000.0 = 33.1% done in 72.1s, 145.3s to go
# Meep progress: 350.1333333333333/1000.0 = 35.0% done in 76.1s, 141.2s to go
# Meep progress: 368.1666666666667/1000.0 = 36.8% done in 80.1s, 137.4s to go
# Meep progress: 386.96666666666664/1000.0 = 38.7% done in 84.1s, 133.2s to go
# Meep progress: 405.6666666666667/1000.0 = 40.6% done in 88.1s, 129.1s to go
# Meep progress: 424.4/1000.0 = 42.4% done in 92.1s, 124.9s to go
# Meep progress: 442.46666666666664/1000.0 = 44.2% done in 96.1s, 121.1s to go
# Meep progress: 461.1666666666667/1000.0 = 46.1% done in 100.1s, 117.0s to go
# Meep progress: 479.93333333333334/1000.0 = 48.0% done in 104.1s, 112.8s to go
# Meep progress: 498.6333333333333/1000.0 = 49.9% done in 108.1s, 108.7s to go
# Meep progress: 516.7333333333333/1000.0 = 51.7% done in 112.1s, 104.9s to go
# Meep progress: 535.4333333333333/1000.0 = 53.5% done in 116.1s, 100.8s to go
# Meep progress: 554.2/1000.0 = 55.4% done in 120.1s, 96.6s to go
# Meep progress: 572.5666666666666/1000.0 = 57.3% done in 124.1s, 92.7s to go
# Meep progress: 590.6/1000.0 = 59.1% done in 128.1s, 88.8s to go
# Meep progress: 609.3333333333334/1000.0 = 60.9% done in 132.1s, 84.7s to go
# Meep progress: 628.0/1000.0 = 62.8% done in 136.1s, 80.6s to go
# Meep progress: 646.6333333333333/1000.0 = 64.7% done in 140.1s, 76.6s to go
# Meep progress: 664.7/1000.0 = 66.5% done in 144.1s, 72.7s to go
# Meep progress: 683.3/1000.0 = 68.3% done in 148.2s, 68.7s to go
# Meep progress: 701.7333333333333/1000.0 = 70.2% done in 152.2s, 64.7s to go
# Meep progress: 720.2333333333333/1000.0 = 72.0% done in 156.2s, 60.7s to go
# Meep progress: 738.0/1000.0 = 73.8% done in 160.2s, 56.9s to go
# Meep progress: 756.2333333333333/1000.0 = 75.6% done in 164.2s, 52.9s to go
# Meep progress: 775.0/1000.0 = 77.5% done in 168.2s, 48.8s to go
# Meep progress: 793.6666666666666/1000.0 = 79.4% done in 172.2s, 44.8s to go
# Meep progress: 811.5666666666666/1000.0 = 81.2% done in 176.2s, 40.9s to go
# Meep progress: 830.3333333333334/1000.0 = 83.0% done in 180.2s, 36.8s to go
# Meep progress: 848.6/1000.0 = 84.9% done in 184.2s, 32.9s to go
# Meep progress: 867.1/1000.0 = 86.7% done in 188.2s, 28.8s to go
# Meep progress: 884.7666666666667/1000.0 = 88.5% done in 192.2s, 25.0s to go
# Meep progress: 903.2666666666667/1000.0 = 90.3% done in 196.2s, 21.0s to go
# Meep progress: 921.8333333333334/1000.0 = 92.2% done in 200.2s, 17.0s to go
# Meep progress: 940.0666666666666/1000.0 = 94.0% done in 204.2s, 13.0s to go
# Meep progress: 957.9666666666667/1000.0 = 95.8% done in 208.2s, 9.1s to go
# Meep progress: 976.6/1000.0 = 97.7% done in 212.2s, 5.1s to go
# Meep progress: 995.2333333333333/1000.0 = 99.5% done in 216.2s, 1.0s to go
# run 0 finished at t = 1000.0 (30000 timesteps)
# -----------
# Initializing structure...
# Meep: using complex fields.
# Meep progress: 17.433333333333334/1000.0 = 1.7% done in 4.0s, 225.6s to go
# Meep progress: 36.0/1000.0 = 3.6% done in 8.0s, 214.4s to go
# Meep progress: 54.699999999999996/1000.0 = 5.5% done in 12.0s, 207.6s to go
# Meep progress: 73.46666666666667/1000.0 = 7.3% done in 16.0s, 202.0s to go
# Meep progress: 91.7/1000.0 = 9.2% done in 20.0s, 198.3s to go
# Meep progress: 109.83333333333333/1000.0 = 11.0% done in 24.0s, 194.7s to go
# Meep progress: 128.4/1000.0 = 12.8% done in 28.0s, 190.3s to go
# Meep progress: 147.26666666666665/1000.0 = 14.7% done in 32.0s, 185.5s to go
# Meep progress: 165.26666666666665/1000.0 = 16.5% done in 36.0s, 182.0s to go
# Meep progress: 183.83333333333334/1000.0 = 18.4% done in 40.0s, 177.8s to go
# Meep progress: 202.66666666666666/1000.0 = 20.3% done in 44.0s, 173.3s to go
# Meep progress: 221.46666666666667/1000.0 = 22.1% done in 48.0s, 168.9s to go
# Meep progress: 239.6/1000.0 = 24.0% done in 52.0s, 165.2s to go
# Meep progress: 258.1666666666667/1000.0 = 25.8% done in 56.1s, 161.1s to go
# Meep progress: 276.9/1000.0 = 27.7% done in 60.1s, 156.8s to go
# Meep progress: 295.6333333333333/1000.0 = 29.6% done in 64.1s, 152.6s to go
# Meep progress: 313.6/1000.0 = 31.4% done in 68.1s, 149.0s to go
# Meep progress: 332.23333333333335/1000.0 = 33.2% done in 72.1s, 144.9s to go
# Meep progress: 351.0333333333333/1000.0 = 35.1% done in 76.1s, 140.6s to go
# Meep progress: 369.9/1000.0 = 37.0% done in 80.1s, 136.4s to go
# Meep progress: 387.46666666666664/1000.0 = 38.7% done in 84.1s, 132.9s to go
# Meep progress: 405.8333333333333/1000.0 = 40.6% done in 88.1s, 129.0s to go
# Meep progress: 424.46666666666664/1000.0 = 42.4% done in 92.1s, 124.9s to go
# Meep progress: 442.8666666666667/1000.0 = 44.3% done in 96.1s, 120.9s to go
# Meep progress: 461.09999999999997/1000.0 = 46.1% done in 100.1s, 117.0s to go
# Meep progress: 479.8333333333333/1000.0 = 48.0% done in 104.1s, 112.8s to go
# Meep progress: 498.6333333333333/1000.0 = 49.9% done in 108.1s, 108.7s to go
# Meep progress: 517.5/1000.0 = 51.8% done in 112.1s, 104.5s to go
# Meep progress: 535.7/1000.0 = 53.6% done in 116.1s, 100.6s to go
# Meep progress: 554.5/1000.0 = 55.5% done in 120.1s, 96.5s to go
# Meep progress: 573.3333333333334/1000.0 = 57.3% done in 124.1s, 92.4s to go
# Meep progress: 592.3666666666667/1000.0 = 59.2% done in 128.1s, 88.2s to go
# Meep progress: 610.6333333333333/1000.0 = 61.1% done in 132.1s, 84.2s to go
# Meep progress: 629.3666666666667/1000.0 = 62.9% done in 136.1s, 80.2s to go
# Meep progress: 648.1666666666666/1000.0 = 64.8% done in 140.1s, 76.1s to go
# Meep progress: 667.0666666666666/1000.0 = 66.7% done in 144.1s, 71.9s to go
# Meep progress: 685.3/1000.0 = 68.5% done in 148.1s, 68.0s to go
# Meep progress: 703.6333333333333/1000.0 = 70.4% done in 152.1s, 64.1s to go
# Meep progress: 722.4333333333333/1000.0 = 72.2% done in 156.2s, 60.0s to go
# Meep progress: 741.3666666666667/1000.0 = 74.1% done in 160.2s, 55.9s to go
# Meep progress: 759.5666666666666/1000.0 = 76.0% done in 164.2s, 52.0s to go
# Meep progress: 778.3333333333334/1000.0 = 77.8% done in 168.2s, 47.9s to go
# Meep progress: 797.0333333333333/1000.0 = 79.7% done in 172.2s, 43.8s to go
# Meep progress: 815.8333333333334/1000.0 = 81.6% done in 176.2s, 39.8s to go
# Meep progress: 834.1/1000.0 = 83.4% done in 180.2s, 35.8s to go
# Meep progress: 852.8333333333334/1000.0 = 85.3% done in 184.2s, 31.8s to go
# Meep progress: 871.6/1000.0 = 87.2% done in 188.2s, 27.7s to go
# Meep progress: 890.4666666666667/1000.0 = 89.0% done in 192.2s, 23.6s to go
# Meep progress: 908.7333333333333/1000.0 = 90.9% done in 196.2s, 19.7s to go
# Meep progress: 927.6333333333333/1000.0 = 92.8% done in 200.2s, 15.6s to go
# Meep progress: 946.3333333333334/1000.0 = 94.6% done in 204.2s, 11.6s to go
# Meep progress: 964.8333333333334/1000.0 = 96.5% done in 208.2s, 7.6s to go
# Meep progress: 983.1/1000.0 = 98.3% done in 212.2s, 3.6s to go
# run 0 finished at t = 1000.0 (30000 timesteps)
# -----------
# Initializing structure...
# Meep: using complex fields.
# Meep progress: 18.0/1000.0 = 1.8% done in 4.0s, 218.5s to go
# Meep progress: 36.666666666666664/1000.0 = 3.7% done in 8.0s, 210.3s to go
# Meep progress: 54.6/1000.0 = 5.5% done in 12.0s, 208.0s to go
# Meep progress: 73.43333333333334/1000.0 = 7.3% done in 16.0s, 202.1s to go
# Meep progress: 92.06666666666666/1000.0 = 9.2% done in 20.0s, 197.4s to go
# Meep progress: 111.0/1000.0 = 11.1% done in 24.0s, 192.3s to go
# Meep progress: 129.16666666666666/1000.0 = 12.9% done in 28.0s, 188.9s to go
# Meep progress: 147.83333333333334/1000.0 = 14.8% done in 32.0s, 184.6s to go
# Meep progress: 166.53333333333333/1000.0 = 16.7% done in 36.0s, 180.3s to go
# Meep progress: 185.33333333333334/1000.0 = 18.5% done in 40.0s, 175.9s to go
# Meep progress: 203.46666666666667/1000.0 = 20.3% done in 44.0s, 172.4s to go
# Meep progress: 222.23333333333332/1000.0 = 22.2% done in 48.0s, 168.1s to go
# Meep progress: 241.1/1000.0 = 24.1% done in 52.0s, 163.8s to go
# Meep progress: 260.1333333333333/1000.0 = 26.0% done in 56.0s, 159.4s to go
# Meep progress: 278.26666666666665/1000.0 = 27.8% done in 60.0s, 155.7s to go
# Meep progress: 297.0/1000.0 = 29.7% done in 64.0s, 151.6s to go
# Meep progress: 315.76666666666665/1000.0 = 31.6% done in 68.0s, 147.4s to go
# Meep progress: 334.6/1000.0 = 33.5% done in 72.1s, 143.3s to go
# Meep progress: 352.73333333333335/1000.0 = 35.3% done in 76.1s, 139.6s to go
# Meep progress: 371.5333333333333/1000.0 = 37.2% done in 80.1s, 135.4s to go
# Meep progress: 390.3666666666667/1000.0 = 39.0% done in 84.1s, 131.3s to go
# Meep progress: 409.1333333333333/1000.0 = 40.9% done in 88.1s, 127.2s to go
# Meep progress: 427.1666666666667/1000.0 = 42.7% done in 92.1s, 123.5s to go
# Meep progress: 445.96666666666664/1000.0 = 44.6% done in 96.1s, 119.3s to go
# Meep progress: 464.76666666666665/1000.0 = 46.5% done in 100.1s, 115.2s to go
# Meep progress: 483.56666666666666/1000.0 = 48.4% done in 104.1s, 111.1s to go
# Meep progress: 501.8333333333333/1000.0 = 50.2% done in 108.1s, 107.3s to go
# Meep progress: 520.4/1000.0 = 52.0% done in 112.1s, 103.3s to go
# Meep progress: 539.1/1000.0 = 53.9% done in 116.1s, 99.2s to go
# Meep progress: 557.8666666666667/1000.0 = 55.8% done in 120.1s, 95.2s to go
# Meep progress: 576.0/1000.0 = 57.6% done in 124.1s, 91.3s to go
# Meep progress: 594.7/1000.0 = 59.5% done in 128.1s, 87.3s to go
# Meep progress: 613.4333333333333/1000.0 = 61.3% done in 132.1s, 83.2s to go
# Meep progress: 632.1/1000.0 = 63.2% done in 136.1s, 79.2s to go
# Meep progress: 650.2666666666667/1000.0 = 65.0% done in 140.1s, 75.4s to go
# Meep progress: 669.1333333333333/1000.0 = 66.9% done in 144.1s, 71.3s to go
# Meep progress: 687.8/1000.0 = 68.8% done in 148.1s, 67.2s to go
# Meep progress: 706.4/1000.0 = 70.6% done in 152.1s, 63.2s to go
# Meep progress: 724.6666666666666/1000.0 = 72.5% done in 156.1s, 59.3s to go
# Meep progress: 743.4/1000.0 = 74.3% done in 160.1s, 55.3s to go
# Meep progress: 762.0666666666666/1000.0 = 76.2% done in 164.1s, 51.2s to go
# Meep progress: 780.4333333333333/1000.0 = 78.0% done in 168.1s, 47.3s to go
# Meep progress: 798.3/1000.0 = 79.8% done in 172.1s, 43.5s to go
# Meep progress: 817.4333333333333/1000.0 = 81.7% done in 176.1s, 39.3s to go
# Meep progress: 836.0333333333333/1000.0 = 83.6% done in 180.1s, 35.3s to go
# Meep progress: 854.9666666666667/1000.0 = 85.5% done in 184.1s, 31.2s to go
# Meep progress: 873.3/1000.0 = 87.3% done in 188.2s, 27.3s to go
# Meep progress: 892.3/1000.0 = 89.2% done in 192.2s, 23.2s to go
# Meep progress: 910.8333333333334/1000.0 = 91.1% done in 196.2s, 19.2s to go
# Meep progress: 929.8/1000.0 = 93.0% done in 200.2s, 15.1s to go
# Meep progress: 947.9333333333333/1000.0 = 94.8% done in 204.2s, 11.2s to go
# Meep progress: 966.8333333333334/1000.0 = 96.7% done in 208.2s, 7.1s to go
# Meep progress: 985.5/1000.0 = 98.5% done in 212.2s, 3.1s to go
# run 0 finished at t = 1000.0 (30000 timesteps)
# -----------
# Initializing structure...
# Meep: using complex fields.
# Meep progress: 17.566666666666666/1000.0 = 1.8% done in 4.0s, 223.7s to go
# Meep progress: 36.266666666666666/1000.0 = 3.6% done in 8.0s, 212.8s to go
# Meep progress: 55.43333333333333/1000.0 = 5.5% done in 12.0s, 204.7s to go
# Meep progress: 74.16666666666667/1000.0 = 7.4% done in 16.0s, 199.9s to go
# Meep progress: 92.66666666666667/1000.0 = 9.3% done in 20.0s, 196.0s to go
# Meep progress: 111.39999999999999/1000.0 = 11.1% done in 24.0s, 191.6s to go
# Meep progress: 130.2/1000.0 = 13.0% done in 28.0s, 187.2s to go
# Meep progress: 149.2/1000.0 = 14.9% done in 32.0s, 182.6s to go
# Meep progress: 167.6/1000.0 = 16.8% done in 36.0s, 179.0s to go
# Meep progress: 186.53333333333333/1000.0 = 18.7% done in 40.0s, 174.6s to go
# Meep progress: 205.46666666666667/1000.0 = 20.5% done in 44.0s, 170.3s to go
# Meep progress: 224.56666666666666/1000.0 = 22.5% done in 48.0s, 165.9s to go
# Meep progress: 242.86666666666667/1000.0 = 24.3% done in 52.0s, 162.3s to go
# Meep progress: 261.8/1000.0 = 26.2% done in 56.1s, 158.0s to go
# Meep progress: 280.56666666666666/1000.0 = 28.1% done in 60.1s, 154.0s to go
# Meep progress: 299.5/1000.0 = 29.9% done in 64.1s, 149.8s to go
# Meep progress: 317.76666666666665/1000.0 = 31.8% done in 68.1s, 146.1s to go
# Meep progress: 336.3333333333333/1000.0 = 33.6% done in 72.1s, 142.2s to go
# Meep progress: 355.1333333333333/1000.0 = 35.5% done in 76.1s, 138.1s to go
# Meep progress: 374.1666666666667/1000.0 = 37.4% done in 80.1s, 133.9s to go
# Meep progress: 392.3333333333333/1000.0 = 39.2% done in 84.1s, 130.2s to go
# Meep progress: 411.23333333333335/1000.0 = 41.1% done in 88.1s, 126.1s to go
# Meep progress: 430.26666666666665/1000.0 = 43.0% done in 92.1s, 121.9s to go
# Meep progress: 449.09999999999997/1000.0 = 44.9% done in 96.1s, 117.9s to go
# Meep progress: 467.0/1000.0 = 46.7% done in 100.1s, 114.2s to go
# Meep progress: 485.06666666666666/1000.0 = 48.5% done in 104.1s, 110.5s to go
# Meep progress: 504.0/1000.0 = 50.4% done in 108.1s, 106.4s to go
# Meep progress: 523.0666666666666/1000.0 = 52.3% done in 112.1s, 102.2s to go
# Meep progress: 541.5333333333333/1000.0 = 54.2% done in 116.1s, 98.3s to go
# Meep progress: 560.3666666666667/1000.0 = 56.0% done in 120.1s, 94.2s to go
# Meep progress: 579.6/1000.0 = 58.0% done in 124.1s, 90.0s to go
# Meep progress: 598.3666666666667/1000.0 = 59.8% done in 128.1s, 86.0s to go
# Meep progress: 616.7/1000.0 = 61.7% done in 132.1s, 82.1s to go
# Meep progress: 635.5/1000.0 = 63.5% done in 136.1s, 78.1s to go
# Meep progress: 654.2/1000.0 = 65.4% done in 140.1s, 74.1s to go
# Meep progress: 673.1666666666666/1000.0 = 67.3% done in 144.1s, 70.0s to go
# Meep progress: 691.5666666666666/1000.0 = 69.2% done in 148.1s, 66.1s to go
# Meep progress: 710.3/1000.0 = 71.0% done in 152.1s, 62.0s to go
# Meep progress: 729.3/1000.0 = 72.9% done in 156.1s, 58.0s to go
# Meep progress: 748.0666666666666/1000.0 = 74.8% done in 160.1s, 53.9s to go
# Meep progress: 766.4333333333333/1000.0 = 76.6% done in 164.1s, 50.0s to go
# Meep progress: 785.3666666666667/1000.0 = 78.5% done in 168.1s, 46.0s to go
# Meep progress: 804.2/1000.0 = 80.4% done in 172.1s, 41.9s to go
# Meep progress: 823.3/1000.0 = 82.3% done in 176.1s, 37.8s to go
# Meep progress: 841.5/1000.0 = 84.2% done in 180.1s, 33.9s to go
# Meep progress: 860.4333333333333/1000.0 = 86.0% done in 184.2s, 29.9s to go
# Meep progress: 879.3/1000.0 = 87.9% done in 188.2s, 25.8s to go
# Meep progress: 898.1/1000.0 = 89.8% done in 192.2s, 21.8s to go
# Meep progress: 916.5333333333333/1000.0 = 91.7% done in 196.2s, 17.9s to go
# Meep progress: 935.3/1000.0 = 93.5% done in 200.2s, 13.8s to go
# Meep progress: 954.1666666666666/1000.0 = 95.4% done in 204.2s, 9.8s to go
# Meep progress: 973.3333333333334/1000.0 = 97.3% done in 208.2s, 5.7s to go
# Meep progress: 991.4666666666667/1000.0 = 99.1% done in 212.2s, 1.8s to go
# run 0 finished at t = 1000.0 (30000 timesteps)
# -----------
# Initializing structure...
# Meep: using complex fields.
# Meep progress: 17.766666666666666/1000.0 = 1.8% done in 4.0s, 221.3s to go
# Meep progress: 36.96666666666667/1000.0 = 3.7% done in 8.0s, 208.5s to go
# Meep progress: 55.4/1000.0 = 5.5% done in 12.0s, 204.8s to go
# Meep progress: 73.4/1000.0 = 7.3% done in 16.0s, 202.1s to go
# Meep progress: 92.13333333333333/1000.0 = 9.2% done in 20.0s, 197.2s to go
# Meep progress: 111.0/1000.0 = 11.1% done in 24.0s, 192.3s to go
# Meep progress: 129.96666666666667/1000.0 = 13.0% done in 28.0s, 187.6s to go
# Meep progress: 148.06666666666666/1000.0 = 14.8% done in 32.0s, 184.3s to go
# Meep progress: 166.96666666666667/1000.0 = 16.7% done in 36.0s, 179.7s to go
# Meep progress: 185.36666666666667/1000.0 = 18.5% done in 40.0s, 175.9s to go
# Meep progress: 204.16666666666666/1000.0 = 20.4% done in 44.0s, 171.6s to go
# Meep progress: 222.46666666666667/1000.0 = 22.2% done in 48.0s, 167.9s to go
# Meep progress: 241.33333333333334/1000.0 = 24.1% done in 52.0s, 163.6s to go
# Meep progress: 260.5/1000.0 = 26.1% done in 56.0s, 159.1s to go
# Meep progress: 279.1/1000.0 = 27.9% done in 60.0s, 155.1s to go
# Meep progress: 297.3333333333333/1000.0 = 29.7% done in 64.1s, 151.4s to go
# Meep progress: 316.1333333333333/1000.0 = 31.6% done in 68.1s, 147.2s to go
# Meep progress: 334.73333333333335/1000.0 = 33.5% done in 72.1s, 143.2s to go
# Meep progress: 353.8/1000.0 = 35.4% done in 76.1s, 138.9s to go
# Meep progress: 371.8333333333333/1000.0 = 37.2% done in 80.1s, 135.3s to go
# Meep progress: 390.73333333333335/1000.0 = 39.1% done in 84.1s, 131.1s to go
# Meep progress: 409.73333333333335/1000.0 = 41.0% done in 88.1s, 126.9s to go
# Meep progress: 428.4/1000.0 = 42.8% done in 92.1s, 122.9s to go
# Meep progress: 446.59999999999997/1000.0 = 44.7% done in 96.1s, 119.1s to go
# Meep progress: 465.43333333333334/1000.0 = 46.5% done in 100.1s, 115.0s to go
# Meep progress: 484.26666666666665/1000.0 = 48.4% done in 104.1s, 110.9s to go
# Meep progress: 503.06666666666666/1000.0 = 50.3% done in 108.1s, 106.8s to go
# Meep progress: 521.2333333333333/1000.0 = 52.1% done in 112.1s, 103.0s to go
# Meep progress: 540.1/1000.0 = 54.0% done in 116.1s, 98.9s to go
# Meep progress: 558.9/1000.0 = 55.9% done in 120.1s, 94.8s to go
# Meep progress: 577.3666666666667/1000.0 = 57.7% done in 124.1s, 90.8s to go
# Meep progress: 595.6666666666666/1000.0 = 59.6% done in 128.1s, 87.0s to go
# Meep progress: 614.3666666666667/1000.0 = 61.4% done in 132.1s, 82.9s to go
# Meep progress: 633.2333333333333/1000.0 = 63.3% done in 136.1s, 78.8s to go
# Meep progress: 652.2/1000.0 = 65.2% done in 140.1s, 74.7s to go
# Meep progress: 670.4333333333333/1000.0 = 67.0% done in 144.1s, 70.9s to go
# Meep progress: 689.3/1000.0 = 68.9% done in 148.1s, 66.8s to go
# Meep progress: 708.1666666666666/1000.0 = 70.8% done in 152.1s, 62.7s to go
# Meep progress: 726.8/1000.0 = 72.7% done in 156.1s, 58.7s to go
# Meep progress: 745.0/1000.0 = 74.5% done in 160.1s, 54.8s to go
# Meep progress: 763.7333333333333/1000.0 = 76.4% done in 164.2s, 50.8s to go
# Meep progress: 782.5333333333333/1000.0 = 78.3% done in 168.2s, 46.7s to go
# Meep progress: 801.3333333333334/1000.0 = 80.1% done in 172.2s, 42.7s to go
# Meep progress: 819.6666666666666/1000.0 = 82.0% done in 176.2s, 38.8s to go
# Meep progress: 838.6333333333333/1000.0 = 83.9% done in 180.2s, 34.7s to go
# Meep progress: 857.0666666666666/1000.0 = 85.7% done in 184.2s, 30.7s to go
# Meep progress: 876.1666666666666/1000.0 = 87.6% done in 188.2s, 26.6s to go
# Meep progress: 894.1999999999999/1000.0 = 89.4% done in 192.2s, 22.7s to go
# Meep progress: 912.9666666666667/1000.0 = 91.3% done in 196.2s, 18.7s to go
# Meep progress: 932.0/1000.0 = 93.2% done in 200.2s, 14.6s to go
# Meep progress: 951.0333333333333/1000.0 = 95.1% done in 204.2s, 10.5s to go
# Meep progress: 969.0333333333333/1000.0 = 96.9% done in 208.2s, 6.7s to go
# Meep progress: 988.0/1000.0 = 98.8% done in 212.2s, 2.6s to go
# run 0 finished at t = 1000.0 (30000 timesteps)
# -----------
# Initializing structure...
# Meep: using complex fields.
# Meep progress: 17.933333333333334/1000.0 = 1.8% done in 4.0s, 219.3s to go
# Meep progress: 36.36666666666667/1000.0 = 3.6% done in 8.0s, 212.3s to go
# Meep progress: 55.333333333333336/1000.0 = 5.5% done in 12.0s, 205.1s to go
# Meep progress: 74.36666666666666/1000.0 = 7.4% done in 16.0s, 199.4s to go
# Meep progress: 93.3/1000.0 = 9.3% done in 20.0s, 194.6s to go
# Meep progress: 111.8/1000.0 = 11.2% done in 24.0s, 190.9s to go
# Meep progress: 130.63333333333333/1000.0 = 13.1% done in 28.0s, 186.5s to go
# Meep progress: 149.73333333333332/1000.0 = 15.0% done in 32.0s, 181.9s to go
# Meep progress: 168.53333333333333/1000.0 = 16.9% done in 36.0s, 177.8s to go
# Meep progress: 186.8/1000.0 = 18.7% done in 40.0s, 174.3s to go
# Meep progress: 205.83333333333334/1000.0 = 20.6% done in 44.0s, 169.9s to go
# Meep progress: 224.6/1000.0 = 22.5% done in 48.0s, 165.9s to go
# Meep progress: 243.66666666666666/1000.0 = 24.4% done in 52.0s, 161.6s to go
# Meep progress: 262.0/1000.0 = 26.2% done in 56.0s, 157.9s to go
# Meep progress: 280.9/1000.0 = 28.1% done in 60.1s, 153.7s to go
# Meep progress: 299.56666666666666/1000.0 = 30.0% done in 64.1s, 149.8s to go
# Meep progress: 318.5/1000.0 = 31.9% done in 68.1s, 145.6s to go
# Meep progress: 336.76666666666665/1000.0 = 33.7% done in 72.1s, 141.9s to go
# Meep progress: 355.73333333333335/1000.0 = 35.6% done in 76.1s, 137.8s to go
# Meep progress: 374.56666666666666/1000.0 = 37.5% done in 80.1s, 133.7s to go
# Meep progress: 393.73333333333335/1000.0 = 39.4% done in 84.1s, 129.5s to go
# Meep progress: 412.2/1000.0 = 41.2% done in 88.1s, 125.6s to go
# Meep progress: 431.0/1000.0 = 43.1% done in 92.1s, 121.6s to go
# Meep progress: 449.9/1000.0 = 45.0% done in 96.1s, 117.5s to go
# Meep progress: 468.93333333333334/1000.0 = 46.9% done in 100.1s, 113.3s to go
# Meep progress: 487.2/1000.0 = 48.7% done in 104.1s, 109.6s to go
# Meep progress: 506.23333333333335/1000.0 = 50.6% done in 108.1s, 105.4s to go
# Meep progress: 525.1666666666666/1000.0 = 52.5% done in 112.1s, 101.4s to go
# Meep progress: 544.2666666666667/1000.0 = 54.4% done in 116.1s, 97.2s to go
# Meep progress: 562.3666666666667/1000.0 = 56.2% done in 120.1s, 93.5s to go
# Meep progress: 581.5/1000.0 = 58.1% done in 124.1s, 89.3s to go
# Meep progress: 600.6666666666666/1000.0 = 60.1% done in 128.1s, 85.2s to go
# Meep progress: 619.3666666666667/1000.0 = 61.9% done in 132.1s, 81.2s to go
# Meep progress: 636.3333333333334/1000.0 = 63.6% done in 136.1s, 77.8s to go
# Meep progress: 655.3666666666667/1000.0 = 65.5% done in 140.1s, 73.7s to go
# Meep progress: 674.1333333333333/1000.0 = 67.4% done in 144.1s, 69.7s to go
# Meep progress: 693.3/1000.0 = 69.3% done in 148.1s, 65.5s to go
# Meep progress: 711.5666666666666/1000.0 = 71.2% done in 152.1s, 61.7s to go
# Meep progress: 730.4666666666667/1000.0 = 73.0% done in 156.2s, 57.6s to go
# Meep progress: 749.5666666666666/1000.0 = 75.0% done in 160.2s, 53.5s to go
# Meep progress: 768.3333333333334/1000.0 = 76.8% done in 164.2s, 49.5s to go
# Meep progress: 786.9666666666667/1000.0 = 78.7% done in 168.2s, 45.5s to go
# Meep progress: 805.8/1000.0 = 80.6% done in 172.2s, 41.5s to go
# Meep progress: 824.7666666666667/1000.0 = 82.5% done in 176.2s, 37.4s to go
# Meep progress: 843.7333333333333/1000.0 = 84.4% done in 180.2s, 33.4s to go
# Meep progress: 862.0333333333333/1000.0 = 86.2% done in 184.2s, 29.5s to go
# Meep progress: 880.8333333333334/1000.0 = 88.1% done in 188.2s, 25.5s to go
# Meep progress: 899.5666666666666/1000.0 = 90.0% done in 192.2s, 21.5s to go
# Meep progress: 918.5666666666666/1000.0 = 91.9% done in 196.2s, 17.4s to go
# Meep progress: 937.0/1000.0 = 93.7% done in 200.2s, 13.5s to go
# Meep progress: 955.8333333333334/1000.0 = 95.6% done in 204.2s, 9.4s to go
# Meep progress: 974.9/1000.0 = 97.5% done in 208.2s, 5.4s to go
# Meep progress: 993.8/1000.0 = 99.4% done in 212.2s, 1.3s to go
# run 0 finished at t = 1000.0 (30000 timesteps)
# -----------
# Initializing structure...
# Meep: using complex fields.
# Meep progress: 18.0/1000.0 = 1.8% done in 4.0s, 218.4s to go
# Meep progress: 36.8/1000.0 = 3.7% done in 8.0s, 209.6s to go
# Meep progress: 55.46666666666667/1000.0 = 5.5% done in 12.0s, 204.5s to go
# Meep progress: 73.6/1000.0 = 7.4% done in 16.0s, 201.6s to go
# Meep progress: 92.53333333333333/1000.0 = 9.3% done in 20.0s, 196.3s to go
# Meep progress: 111.26666666666667/1000.0 = 11.1% done in 24.0s, 191.9s to go
# Meep progress: 129.96666666666667/1000.0 = 13.0% done in 28.0s, 187.6s to go
# Meep progress: 147.96666666666667/1000.0 = 14.8% done in 32.0s, 184.4s to go
# Meep progress: 166.8/1000.0 = 16.7% done in 36.0s, 180.0s to go
# Meep progress: 185.56666666666666/1000.0 = 18.6% done in 40.0s, 175.7s to go
# Meep progress: 204.36666666666667/1000.0 = 20.4% done in 44.0s, 171.4s to go
# Meep progress: 222.33333333333334/1000.0 = 22.2% done in 48.0s, 168.0s to go
# Meep progress: 241.23333333333332/1000.0 = 24.1% done in 52.0s, 163.7s to go
# Meep progress: 259.96666666666664/1000.0 = 26.0% done in 56.0s, 159.6s to go
# Meep progress: 278.8666666666667/1000.0 = 27.9% done in 60.1s, 155.3s to go
# Meep progress: 297.1/1000.0 = 29.7% done in 64.1s, 151.5s to go
# Meep progress: 316.0/1000.0 = 31.6% done in 68.1s, 147.3s to go
# Meep progress: 334.8333333333333/1000.0 = 33.5% done in 72.1s, 143.2s to go
# Meep progress: 353.6666666666667/1000.0 = 35.4% done in 76.1s, 139.0s to go
# Meep progress: 371.7/1000.0 = 37.2% done in 80.1s, 135.3s to go
# Meep progress: 390.73333333333335/1000.0 = 39.1% done in 84.1s, 131.1s to go
# Meep progress: 409.3333333333333/1000.0 = 40.9% done in 88.1s, 127.1s to go
# Meep progress: 428.1666666666667/1000.0 = 42.8% done in 92.1s, 123.0s to go
# Meep progress: 446.23333333333335/1000.0 = 44.6% done in 96.1s, 119.2s to go
# Meep progress: 465.0/1000.0 = 46.5% done in 100.1s, 115.2s to go
# Meep progress: 484.0333333333333/1000.0 = 48.4% done in 104.1s, 111.0s to go
# Meep progress: 502.93333333333334/1000.0 = 50.3% done in 108.1s, 106.8s to go
# Meep progress: 520.8666666666667/1000.0 = 52.1% done in 112.1s, 103.1s to go
# Meep progress: 539.7666666666667/1000.0 = 54.0% done in 116.1s, 99.0s to go
# Meep progress: 558.6333333333333/1000.0 = 55.9% done in 120.1s, 94.9s to go
# Meep progress: 577.6666666666666/1000.0 = 57.8% done in 124.1s, 90.7s to go
# Meep progress: 595.7333333333333/1000.0 = 59.6% done in 128.1s, 86.9s to go
# Meep progress: 614.5/1000.0 = 61.5% done in 132.1s, 82.9s to go
# Meep progress: 633.4/1000.0 = 63.3% done in 136.1s, 78.8s to go
# Meep progress: 652.1/1000.0 = 65.2% done in 140.1s, 74.8s to go
# Meep progress: 670.1/1000.0 = 67.0% done in 144.1s, 71.0s to go
# Meep progress: 689.0333333333333/1000.0 = 68.9% done in 148.1s, 66.9s to go
# Meep progress: 707.5666666666666/1000.0 = 70.8% done in 152.1s, 62.9s to go
# Meep progress: 726.4333333333333/1000.0 = 72.6% done in 156.1s, 58.8s to go
# Meep progress: 744.5666666666666/1000.0 = 74.5% done in 160.2s, 54.9s to go
# Meep progress: 763.4/1000.0 = 76.3% done in 164.2s, 50.9s to go
# Meep progress: 782.2333333333333/1000.0 = 78.2% done in 168.2s, 46.8s to go
# Meep progress: 801.1/1000.0 = 80.1% done in 172.2s, 42.7s to go
# Meep progress: 819.1/1000.0 = 81.9% done in 176.2s, 38.9s to go
# Meep progress: 837.7666666666667/1000.0 = 83.8% done in 180.2s, 34.9s to go
# Meep progress: 856.8666666666667/1000.0 = 85.7% done in 184.2s, 30.8s to go
# Meep progress: 875.7333333333333/1000.0 = 87.6% done in 188.2s, 26.7s to go
# Meep progress: 893.7666666666667/1000.0 = 89.4% done in 192.2s, 22.8s to go
# Meep progress: 912.6999999999999/1000.0 = 91.3% done in 196.2s, 18.8s to go
# Meep progress: 931.4/1000.0 = 93.1% done in 200.2s, 14.7s to go
# Meep progress: 950.4333333333333/1000.0 = 95.0% done in 204.2s, 10.6s to go
# Meep progress: 968.4666666666667/1000.0 = 96.8% done in 208.2s, 6.8s to go
# Meep progress: 986.9/1000.0 = 98.7% done in 212.2s, 2.8s to go
# run 0 finished at t = 1000.0 (30000 timesteps)
# -----------
# Initializing structure...
# Meep: using complex fields.
# Meep progress: 18.1/1000.0 = 1.8% done in 4.0s, 217.1s to go
# Meep progress: 36.666666666666664/1000.0 = 3.7% done in 8.0s, 210.4s to go
# Meep progress: 55.266666666666666/1000.0 = 5.5% done in 12.0s, 205.4s to go
# Meep progress: 74.26666666666667/1000.0 = 7.4% done in 16.0s, 199.7s to go
# Meep progress: 93.16666666666667/1000.0 = 9.3% done in 20.0s, 194.9s to go
# Meep progress: 111.36666666666666/1000.0 = 11.1% done in 24.0s, 191.7s to go
# Meep progress: 130.46666666666667/1000.0 = 13.0% done in 28.0s, 186.8s to go
# Meep progress: 149.53333333333333/1000.0 = 15.0% done in 32.0s, 182.2s to go
# Meep progress: 168.66666666666666/1000.0 = 16.9% done in 36.0s, 177.6s to go
# Meep progress: 186.8/1000.0 = 18.7% done in 40.0s, 174.3s to go
# Meep progress: 205.7/1000.0 = 20.6% done in 44.0s, 170.1s to go
# Meep progress: 224.73333333333332/1000.0 = 22.5% done in 48.0s, 165.8s to go
# Meep progress: 243.46666666666667/1000.0 = 24.3% done in 52.1s, 161.8s to go
# Meep progress: 261.8333333333333/1000.0 = 26.2% done in 56.1s, 158.0s to go
# Meep progress: 280.8/1000.0 = 28.1% done in 60.1s, 153.8s to go
# Meep progress: 299.8/1000.0 = 30.0% done in 64.1s, 149.6s to go
# Meep progress: 318.7/1000.0 = 31.9% done in 68.1s, 145.5s to go
# Meep progress: 336.96666666666664/1000.0 = 33.7% done in 72.1s, 141.8s to go
# Meep progress: 355.73333333333335/1000.0 = 35.6% done in 76.1s, 137.8s to go
# Meep progress: 374.76666666666665/1000.0 = 37.5% done in 80.1s, 133.6s to go
# Meep progress: 393.6666666666667/1000.0 = 39.4% done in 84.1s, 129.5s to go
# Meep progress: 411.93333333333334/1000.0 = 41.2% done in 88.1s, 125.8s to go
# Meep progress: 430.5/1000.0 = 43.0% done in 92.1s, 121.8s to go
# Meep progress: 449.76666666666665/1000.0 = 45.0% done in 96.1s, 117.6s to go
# Meep progress: 468.7/1000.0 = 46.9% done in 100.1s, 113.5s to go
# Meep progress: 487.09999999999997/1000.0 = 48.7% done in 104.1s, 109.6s to go
# Meep progress: 506.06666666666666/1000.0 = 50.6% done in 108.1s, 105.5s to go
# Meep progress: 524.3/1000.0 = 52.4% done in 112.1s, 101.7s to go
# Meep progress: 542.8333333333334/1000.0 = 54.3% done in 116.1s, 97.8s to go
# Meep progress: 561.2/1000.0 = 56.1% done in 120.1s, 93.9s to go
# Meep progress: 579.8333333333334/1000.0 = 58.0% done in 124.1s, 89.9s to go
# Meep progress: 598.7/1000.0 = 59.9% done in 128.1s, 85.9s to go
# Meep progress: 617.6333333333333/1000.0 = 61.8% done in 132.1s, 81.8s to go
# Meep progress: 635.9/1000.0 = 63.6% done in 136.1s, 78.0s to go
# Meep progress: 654.5666666666666/1000.0 = 65.5% done in 140.1s, 74.0s to go
# Meep progress: 673.4333333333333/1000.0 = 67.3% done in 144.1s, 69.9s to go
# Meep progress: 692.4/1000.0 = 69.2% done in 148.2s, 65.8s to go
# Meep progress: 710.6333333333333/1000.0 = 71.1% done in 152.2s, 62.0s to go
# Meep progress: 729.5666666666666/1000.0 = 73.0% done in 156.2s, 57.9s to go
# Meep progress: 748.5333333333333/1000.0 = 74.9% done in 160.2s, 53.8s to go
# Meep progress: 767.7/1000.0 = 76.8% done in 164.2s, 49.7s to go
# Meep progress: 786.0/1000.0 = 78.6% done in 168.2s, 45.8s to go
# Meep progress: 804.9666666666667/1000.0 = 80.5% done in 172.2s, 41.7s to go
# Meep progress: 824.0333333333333/1000.0 = 82.4% done in 176.2s, 37.6s to go
# Meep progress: 843.1999999999999/1000.0 = 84.3% done in 180.2s, 33.5s to go
# Meep progress: 861.3666666666667/1000.0 = 86.1% done in 184.2s, 29.6s to go
# Meep progress: 880.4666666666667/1000.0 = 88.0% done in 188.2s, 25.5s to go
# Meep progress: 899.3/1000.0 = 89.9% done in 192.2s, 21.5s to go
# Meep progress: 918.4333333333333/1000.0 = 91.8% done in 196.2s, 17.4s to go
# Meep progress: 936.7333333333333/1000.0 = 93.7% done in 200.2s, 13.5s to go
# Meep progress: 955.6/1000.0 = 95.6% done in 204.2s, 9.5s to go
# Meep progress: 974.6666666666666/1000.0 = 97.5% done in 208.2s, 5.4s to go
# Meep progress: 993.6333333333333/1000.0 = 99.4% done in 212.2s, 1.4s to go
# run 0 finished at t = 1000.0 (30000 timesteps)
# -----------
# Initializing structure...
# Meep: using complex fields.
# Meep progress: 18.3/1000.0 = 1.8% done in 4.0s, 214.6s to go
# Meep progress: 37.166666666666664/1000.0 = 3.7% done in 8.0s, 207.3s to go
# Meep progress: 55.93333333333333/1000.0 = 5.6% done in 12.0s, 202.7s to go
# Meep progress: 74.2/1000.0 = 7.4% done in 16.0s, 199.8s to go
# Meep progress: 92.96666666666667/1000.0 = 9.3% done in 20.0s, 195.3s to go
# Meep progress: 111.8/1000.0 = 11.2% done in 24.0s, 190.9s to go
# Meep progress: 130.7/1000.0 = 13.1% done in 28.0s, 186.4s to go
# Meep progress: 148.86666666666667/1000.0 = 14.9% done in 32.0s, 183.1s to go
# Meep progress: 167.76666666666665/1000.0 = 16.8% done in 36.0s, 178.8s to go
# Meep progress: 186.53333333333333/1000.0 = 18.7% done in 40.0s, 174.6s to go
# Meep progress: 205.33333333333334/1000.0 = 20.5% done in 44.0s, 170.5s to go
# Meep progress: 223.73333333333332/1000.0 = 22.4% done in 48.0s, 166.7s to go
# Meep progress: 242.6/1000.0 = 24.3% done in 52.0s, 162.5s to go
# Meep progress: 261.26666666666665/1000.0 = 26.1% done in 56.0s, 158.5s to go
# Meep progress: 280.1/1000.0 = 28.0% done in 60.0s, 154.3s to go
# Meep progress: 298.3333333333333/1000.0 = 29.8% done in 64.1s, 150.7s to go
# Meep progress: 317.1333333333333/1000.0 = 31.7% done in 68.1s, 146.5s to go
# Meep progress: 335.96666666666664/1000.0 = 33.6% done in 72.1s, 142.4s to go
# Meep progress: 354.96666666666664/1000.0 = 35.5% done in 76.1s, 138.2s to go
# Meep progress: 373.06666666666666/1000.0 = 37.3% done in 80.1s, 134.5s to go
# Meep progress: 392.0333333333333/1000.0 = 39.2% done in 84.1s, 130.4s to go
# Meep progress: 410.6666666666667/1000.0 = 41.1% done in 88.1s, 126.4s to go
# Meep progress: 429.6666666666667/1000.0 = 43.0% done in 92.1s, 122.2s to go
# Meep progress: 447.9/1000.0 = 44.8% done in 96.1s, 118.4s to go
# Meep progress: 466.56666666666666/1000.0 = 46.7% done in 100.1s, 114.4s to go
# Meep progress: 485.23333333333335/1000.0 = 48.5% done in 104.1s, 110.4s to go
# Meep progress: 504.43333333333334/1000.0 = 50.4% done in 108.1s, 106.2s to go
# Meep progress: 522.7333333333333/1000.0 = 52.3% done in 112.1s, 102.3s to go
# Meep progress: 541.6/1000.0 = 54.2% done in 116.1s, 98.3s to go
# Meep progress: 560.5666666666666/1000.0 = 56.1% done in 120.1s, 94.2s to go
# Meep progress: 579.2666666666667/1000.0 = 57.9% done in 124.1s, 90.1s to go
# Meep progress: 597.6/1000.0 = 59.8% done in 128.1s, 86.3s to go
# Meep progress: 616.4666666666667/1000.0 = 61.6% done in 132.1s, 82.2s to go
# Meep progress: 635.2666666666667/1000.0 = 63.5% done in 136.1s, 78.1s to go
# Meep progress: 654.0666666666666/1000.0 = 65.4% done in 140.1s, 74.1s to go
# Meep progress: 672.1333333333333/1000.0 = 67.2% done in 144.1s, 70.3s to go
# Meep progress: 690.9/1000.0 = 69.1% done in 148.1s, 66.3s to go
# Meep progress: 709.8333333333334/1000.0 = 71.0% done in 152.1s, 62.2s to go
# Meep progress: 728.9/1000.0 = 72.9% done in 156.1s, 58.1s to go
# Meep progress: 747.0666666666666/1000.0 = 74.7% done in 160.1s, 54.2s to go
# Meep progress: 765.8666666666667/1000.0 = 76.6% done in 164.1s, 50.2s to go
# Meep progress: 785.0333333333333/1000.0 = 78.5% done in 168.1s, 46.0s to go
# Meep progress: 803.6666666666666/1000.0 = 80.4% done in 172.1s, 42.1s to go
# Meep progress: 821.9/1000.0 = 82.2% done in 176.1s, 38.2s to go
# Meep progress: 840.6999999999999/1000.0 = 84.1% done in 180.1s, 34.1s to go
# Meep progress: 859.6666666666666/1000.0 = 86.0% done in 184.1s, 30.1s to go
# Meep progress: 878.3/1000.0 = 87.8% done in 188.2s, 26.1s to go
# Meep progress: 896.6/1000.0 = 89.7% done in 192.2s, 22.2s to go
# Meep progress: 915.3/1000.0 = 91.5% done in 196.2s, 18.2s to go
# Meep progress: 934.1666666666666/1000.0 = 93.4% done in 200.2s, 14.1s to go
# Meep progress: 953.1333333333333/1000.0 = 95.3% done in 204.2s, 10.0s to go
# Meep progress: 971.1333333333333/1000.0 = 97.1% done in 208.2s, 6.2s to go
# Meep progress: 990.0/1000.0 = 99.0% done in 212.2s, 2.1s to go
# run 0 finished at t = 1000.0 (30000 timesteps)
# -----------
# Initializing structure...
# Meep: using complex fields.
# Meep progress: 18.0/1000.0 = 1.8% done in 4.0s, 218.2s to go
# Meep progress: 37.03333333333333/1000.0 = 3.7% done in 8.0s, 208.2s to go
# Meep progress: 55.13333333333333/1000.0 = 5.5% done in 12.0s, 205.8s to go
# Meep progress: 74.2/1000.0 = 7.4% done in 16.0s, 199.8s to go
# Meep progress: 93.33333333333333/1000.0 = 9.3% done in 20.0s, 194.4s to go
# Meep progress: 112.03333333333333/1000.0 = 11.2% done in 24.0s, 190.3s to go
# Meep progress: 130.46666666666667/1000.0 = 13.0% done in 28.0s, 186.7s to go
# Meep progress: 149.36666666666667/1000.0 = 14.9% done in 32.0s, 182.4s to go
# Meep progress: 168.43333333333334/1000.0 = 16.8% done in 36.0s, 177.8s to go
# Meep progress: 187.33333333333334/1000.0 = 18.7% done in 40.0s, 173.6s to go
# Meep progress: 205.33333333333334/1000.0 = 20.5% done in 44.0s, 170.4s to go
# Meep progress: 224.26666666666665/1000.0 = 22.4% done in 48.0s, 166.1s to go
# Meep progress: 243.2/1000.0 = 24.3% done in 52.0s, 161.9s to go
# Meep progress: 262.26666666666665/1000.0 = 26.2% done in 56.0s, 157.6s to go
# Meep progress: 280.6/1000.0 = 28.1% done in 60.0s, 153.9s to go
# Meep progress: 299.6666666666667/1000.0 = 30.0% done in 64.1s, 149.7s to go
# Meep progress: 318.5/1000.0 = 31.9% done in 68.1s, 145.6s to go
# Meep progress: 337.43333333333334/1000.0 = 33.7% done in 72.1s, 141.5s to go
# Meep progress: 355.5333333333333/1000.0 = 35.6% done in 76.1s, 137.9s to go
# Meep progress: 374.73333333333335/1000.0 = 37.5% done in 80.1s, 133.6s to go
# Meep progress: 393.4/1000.0 = 39.3% done in 84.1s, 129.6s to go
# Meep progress: 412.43333333333334/1000.0 = 41.2% done in 88.1s, 125.5s to go
# Meep progress: 430.8/1000.0 = 43.1% done in 92.1s, 121.7s to go
# Meep progress: 449.93333333333334/1000.0 = 45.0% done in 96.1s, 117.5s to go
# Meep progress: 468.8666666666667/1000.0 = 46.9% done in 100.1s, 113.4s to go
# Meep progress: 487.6333333333333/1000.0 = 48.8% done in 104.1s, 109.4s to go
# Meep progress: 506.0333333333333/1000.0 = 50.6% done in 108.1s, 105.5s to go
# Meep progress: 524.9666666666667/1000.0 = 52.5% done in 112.1s, 101.4s to go
# Meep progress: 543.7333333333333/1000.0 = 54.4% done in 116.1s, 97.4s to go
# Meep progress: 562.7/1000.0 = 56.3% done in 120.1s, 93.3s to go
# Meep progress: 580.9/1000.0 = 58.1% done in 124.1s, 89.5s to go
# Meep progress: 599.7666666666667/1000.0 = 60.0% done in 128.1s, 85.5s to go
# Meep progress: 618.8/1000.0 = 61.9% done in 132.1s, 81.4s to go
# Meep progress: 637.6333333333333/1000.0 = 63.8% done in 136.1s, 77.4s to go
# Meep progress: 655.8/1000.0 = 65.6% done in 140.1s, 73.5s to go
# Meep progress: 674.7333333333333/1000.0 = 67.5% done in 144.1s, 69.5s to go
# Meep progress: 693.7666666666667/1000.0 = 69.4% done in 148.1s, 65.4s to go
# Meep progress: 712.8/1000.0 = 71.3% done in 152.1s, 61.3s to go
# Meep progress: 731.2333333333333/1000.0 = 73.1% done in 156.1s, 57.4s to go
# Meep progress: 750.2666666666667/1000.0 = 75.0% done in 160.1s, 53.3s to go
# Meep progress: 769.2333333333333/1000.0 = 76.9% done in 164.1s, 49.2s to go
# Meep progress: 788.3/1000.0 = 78.8% done in 168.1s, 45.2s to go
# Meep progress: 806.5/1000.0 = 80.7% done in 172.1s, 41.3s to go
# Meep progress: 825.3/1000.0 = 82.5% done in 176.1s, 37.3s to go
# Meep progress: 844.4666666666667/1000.0 = 84.4% done in 180.1s, 33.2s to go
# Meep progress: 863.4666666666667/1000.0 = 86.3% done in 184.1s, 29.1s to go
# Meep progress: 881.8666666666667/1000.0 = 88.2% done in 188.2s, 25.2s to go
# Meep progress: 900.8333333333334/1000.0 = 90.1% done in 192.2s, 21.2s to go
# Meep progress: 919.8/1000.0 = 92.0% done in 196.2s, 17.1s to go
# Meep progress: 938.7666666666667/1000.0 = 93.9% done in 200.2s, 13.1s to go
# Meep progress: 957.1/1000.0 = 95.7% done in 204.2s, 9.2s to go
# Meep progress: 976.1333333333333/1000.0 = 97.6% done in 208.2s, 5.1s to go
# Meep progress: 995.0333333333333/1000.0 = 99.5% done in 212.2s, 1.1s to go
# run 0 finished at t = 1000.0 (30000 timesteps)
# The 0th shape:
# The 1th shape:
# The 2th shape:
# The 3th shape:
# The 4th shape:
