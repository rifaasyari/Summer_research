# %%
from matplotlib import pyplot as plt
import numpy as np
shape_size = 48
def spectrum(batch, index):
    freq = np.genfromtxt('data/freq.txt')
    Ts = np.genfromtxt('data/DATA'+str(batch) +'/DATA'+str(batch)+'_sp'+str(index)+'.txt')
    #plt.ylim(0, 1.1)
    plt.plot(freq, Ts)
    plt.show()

# %%
spectrum(56, 127)

# %%
from matplotlib import pyplot as plt
import numpy as np
shape_size = 48
def spectrum(batch, index):
    for i in range(1, 3):
        freq = np.genfromtxt('data/freq.txt')
        Ts = np.genfromtxt('data/DATA'+str(batch) +'/DATA'+str(batch)+'_sp'+str(index)+'_s'+str(i)+'-3.txt')
        plt.ylim(0, 1.1)
        plt.plot(freq, Ts)
        plt.show()

# %%
spectrum(5, 4)
