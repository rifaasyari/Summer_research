# %%
from matplotlib import pyplot as plt
import numpy as np
import math
import meep as mp
import cmath

shape_size = 48

sx, sy, sz = 1, 1, 4
h = 1.25
dpml = 0.5
b_m, c_m = 1.4, 3.54
res = 15
echo = 1000
cell_size = mp.Vector3(sx,sy,sz)
fcen = 0.5
df = 0.2
theta = math.radians(0)
nfreq = 200

# k with correct length (plane of incidence: XZ) 
k = mp.Vector3(math.sin(theta),0,math.cos(theta)).scale(fcen)
def pw_amp(k, x0):
    def _pw_amp(x):
        return cmath.exp(1j * 2 * math.pi * k.dot(x + x0))
    return _pw_amp

# %%
def get_bend(vertices, hole):
    # a pdms block with a si polygon
    geometry = [mp.Block(size = cell_size, material=mp.Medium(index=b_m)),
                mp.Prism(vertices, 
                         height=h, 
                         material=mp.Medium(index=c_m),
                         center=mp.Vector3())]
    # add hole index is the same as the block
    geometry.append(mp.Prism(hole, 
                             height=h, 
                             material=mp.Medium(index=b_m),
                             center=mp.Vector3()))
    pml_layers = [mp.PML(thickness=1, direction = mp.Z, side=mp.High),
                  mp.Absorber(thickness=1,direction = mp.Z, side=mp.Low)]
    src_pos = -(sz/2 - dpml - 0.5)
    src = [mp.Source(src = mp.GaussianSource(fcen, fwidth=df),
                     component = mp.Ey,
                     center = mp.Vector3(0,0,src_pos),
                     size = mp.Vector3(sx,sy,0),
                     amp_func=pw_amp(k,mp.Vector3(0,0,src_pos)))]
    sim = mp.Simulation(resolution=res,
                        cell_size=cell_size,
                        boundary_layers=pml_layers,
                        sources=src,
                        geometry=geometry,
                        k_point=k)
    freg = mp.FluxRegion(center=mp.Vector3(0,0,-src_pos),
                         size = mp.Vector3(sx,sy,0))
    trans = sim.add_flux(fcen, df, nfreq, freg)
    sim.run(until = echo)
    bend = mp.get_fluxes(trans)
    return bend

def data_generator(batch, ran):
    # data = []
    # get shape from 'data/DATAX_sh.txt'
    coordinates = np.genfromtxt('data/DATA'+str(batch)+'_sh.txt')
    xc, yc = coordinates[:, 0], coordinates[:, 1]
    size = len(xc) // shape_size
    xc = np.reshape(xc, (size, shape_size))
    yc = np.reshape(yc, (size, shape_size))
                    
    filt = []
    for i in ran:
        # form shape
        if i in filt:
            continue
        for scale in range(1, 3):
            vertices = [mp.Vector3(xc[i][0],yc[i][0])]
            hole = [mp.Vector3(xc[i][0] * (scale/3),yc[i][0] * (scale/3))]
            for j in range(1, len(xc[i]) - 1):
                # eliminate duplicate point
                if xc[i][j] == xc[i][j - 1] and yc[i][j] == yc[i][j - 1]:
                    continue
                vertices.append(mp.Vector3(xc[i][j], yc[i][j]))
                hole.append(mp.Vector3(xc[i][j] * (scale/3),yc[i][j] * (scale/3)))
                #print(xc[i][j], yc[i][j])

            # calculate transmission
            bend = get_bend(vertices, hole)
            Ts = []
            st = np.genfromtxt('data/straight.txt')
            for j in range(nfreq):
                Ts = np.append(Ts, bend[j]/st[j])
            #data.append(Ts)      
            print('\n Batch: ' + str(batch) + ' progress: '+ str(i + 1)+'/'+str(size))
            print('Hole Scale: ' + str(scale)+'/3\n')
            np.savetxt('data/DATA'+str(batch)+'_sp'+str(i)+'_s'+str(scale)+'-3.txt', Ts)
#             freq = np.genfromtxt('data/freq.txt')
#             plt.ylim(0, 1.1)
#             plt.plot(freq,Ts)
#             plt.show()

# %%
batch = 5
ran = [x for x in range(5)]
data_generator(batch, ran)
# Out:
# -----------
# Initializing structure...
# Meep: using complex fields.
# Meep progress: 19.266666666666666/1000.0 = 1.9% done in 4.0s, 203.8s to go
# Meep progress: 38.56666666666666/1000.0 = 3.9% done in 8.0s, 199.7s to go
# Meep progress: 57.833333333333336/1000.0 = 5.8% done in 12.0s, 195.7s to go
# Meep progress: 76.93333333333334/1000.0 = 7.7% done in 16.0s, 192.2s to go
# Meep progress: 95.8/1000.0 = 9.6% done in 20.0s, 189.0s to go
# Meep progress: 112.2/1000.0 = 11.2% done in 24.0s, 190.1s to go
# Meep progress: 129.46666666666667/1000.0 = 12.9% done in 28.0s, 188.5s to go
# Meep progress: 148.9/1000.0 = 14.9% done in 32.0s, 183.1s to go
# Meep progress: 168.66666666666666/1000.0 = 16.9% done in 36.0s, 177.6s to go
# Meep progress: 188.46666666666667/1000.0 = 18.8% done in 40.0s, 172.4s to go
# Meep progress: 207.23333333333332/1000.0 = 20.7% done in 44.0s, 168.5s to go
# Meep progress: 226.13333333333333/1000.0 = 22.6% done in 48.0s, 164.4s to go
# Meep progress: 244.06666666666666/1000.0 = 24.4% done in 52.1s, 161.2s to go
# Meep progress: 262.93333333333334/1000.0 = 26.3% done in 56.1s, 157.1s to go
# Meep progress: 282.0/1000.0 = 28.2% done in 60.1s, 152.9s to go
# Meep progress: 301.7/1000.0 = 30.2% done in 64.1s, 148.3s to go
# Meep progress: 321.06666666666666/1000.0 = 32.1% done in 68.1s, 144.0s to go
# Meep progress: 340.0333333333333/1000.0 = 34.0% done in 72.1s, 139.9s to go
# Meep progress: 359.5/1000.0 = 36.0% done in 76.1s, 135.6s to go
# Meep progress: 379.46666666666664/1000.0 = 37.9% done in 80.1s, 131.0s to go
# Meep progress: 399.4/1000.0 = 39.9% done in 84.1s, 126.4s to go
# Meep progress: 418.93333333333334/1000.0 = 41.9% done in 88.1s, 122.2s to go
# Meep progress: 438.7/1000.0 = 43.9% done in 92.1s, 117.8s to go
# Meep progress: 458.7/1000.0 = 45.9% done in 96.1s, 113.4s to go
# Meep progress: 478.76666666666665/1000.0 = 47.9% done in 100.1s, 109.0s to go
# Meep progress: 498.46666666666664/1000.0 = 49.8% done in 104.1s, 104.8s to go
# Meep progress: 518.3666666666667/1000.0 = 51.8% done in 108.1s, 100.5s to go
# Meep progress: 538.4/1000.0 = 53.8% done in 112.1s, 96.1s to go
# Meep progress: 558.4333333333333/1000.0 = 55.8% done in 116.1s, 91.8s to go
# Meep progress: 578.2333333333333/1000.0 = 57.8% done in 120.1s, 87.6s to go
# Meep progress: 597.9666666666667/1000.0 = 59.8% done in 124.1s, 83.5s to go
# Meep progress: 618.0/1000.0 = 61.8% done in 128.1s, 79.2s to go
# Meep progress: 637.8/1000.0 = 63.8% done in 132.1s, 75.0s to go
# Meep progress: 657.6333333333333/1000.0 = 65.8% done in 136.1s, 70.9s to go
# Meep progress: 677.4/1000.0 = 67.7% done in 140.1s, 66.7s to go
# Meep progress: 697.4333333333333/1000.0 = 69.7% done in 144.1s, 62.5s to go
# Meep progress: 717.3333333333334/1000.0 = 71.7% done in 148.1s, 58.4s to go
# Meep progress: 737.0333333333333/1000.0 = 73.7% done in 152.2s, 54.3s to go
# Meep progress: 756.6/1000.0 = 75.7% done in 156.2s, 50.2s to go
# Meep progress: 776.6666666666666/1000.0 = 77.7% done in 160.2s, 46.1s to go
# Meep progress: 796.7/1000.0 = 79.7% done in 164.2s, 41.9s to go
# Meep progress: 816.5666666666666/1000.0 = 81.7% done in 168.2s, 37.8s to go
# Meep progress: 836.5/1000.0 = 83.7% done in 172.2s, 33.7s to go
# Meep progress: 856.5/1000.0 = 85.7% done in 176.2s, 29.5s to go
# Meep progress: 876.5/1000.0 = 87.7% done in 180.2s, 25.4s to go
# Meep progress: 896.3/1000.0 = 89.6% done in 184.2s, 21.3s to go
# Meep progress: 916.0666666666666/1000.0 = 91.6% done in 188.2s, 17.2s to go
# Meep progress: 936.1666666666666/1000.0 = 93.6% done in 192.2s, 13.1s to go
# Meep progress: 956.3/1000.0 = 95.6% done in 196.2s, 9.0s to go
# Meep progress: 975.9333333333333/1000.0 = 97.6% done in 200.2s, 4.9s to go
# Meep progress: 995.7666666666667/1000.0 = 99.6% done in 204.2s, 0.9s to go
# run 0 finished at t = 1000.0 (30000 timesteps)
#
#  Batch: 5 progress: 1/5
# Hole Scale: 1/3
#
# -----------
# Initializing structure...
# Meep: using complex fields.
# Meep progress: 19.233333333333334/1000.0 = 1.9% done in 4.0s, 204.1s to go
# Meep progress: 39.233333333333334/1000.0 = 3.9% done in 8.0s, 196.0s to go
# Meep progress: 58.86666666666667/1000.0 = 5.9% done in 12.0s, 191.9s to go
# Meep progress: 78.9/1000.0 = 7.9% done in 16.0s, 186.9s to go
# Meep progress: 98.8/1000.0 = 9.9% done in 20.0s, 182.5s to go
# Meep progress: 118.66666666666667/1000.0 = 11.9% done in 24.0s, 178.3s to go
# Meep progress: 138.3/1000.0 = 13.8% done in 28.0s, 174.6s to go
# Meep progress: 158.26666666666665/1000.0 = 15.8% done in 32.0s, 170.3s to go
# Meep progress: 178.3/1000.0 = 17.8% done in 36.0s, 166.0s to go
# Meep progress: 198.16666666666666/1000.0 = 19.8% done in 40.0s, 161.9s to go
# Meep progress: 217.63333333333333/1000.0 = 21.8% done in 44.0s, 158.3s to go
# Meep progress: 237.43333333333334/1000.0 = 23.7% done in 48.0s, 154.2s to go
# Meep progress: 257.2/1000.0 = 25.7% done in 52.0s, 150.3s to go
# Meep progress: 277.2/1000.0 = 27.7% done in 56.0s, 146.1s to go
# Meep progress: 296.8666666666667/1000.0 = 29.7% done in 60.0s, 142.2s to go
# Meep progress: 316.73333333333335/1000.0 = 31.7% done in 64.0s, 138.1s to go
# Meep progress: 336.73333333333335/1000.0 = 33.7% done in 68.0s, 134.0s to go
# Meep progress: 356.6666666666667/1000.0 = 35.7% done in 72.0s, 129.9s to go
# Meep progress: 376.3333333333333/1000.0 = 37.6% done in 76.0s, 126.0s to go
# Meep progress: 395.96666666666664/1000.0 = 39.6% done in 80.0s, 122.1s to go
# Meep progress: 415.8333333333333/1000.0 = 41.6% done in 84.1s, 118.1s to go
# Meep progress: 435.56666666666666/1000.0 = 43.6% done in 88.1s, 114.1s to go
# Meep progress: 454.6666666666667/1000.0 = 45.5% done in 92.1s, 110.4s to go
# Meep progress: 474.6333333333333/1000.0 = 47.5% done in 96.1s, 106.3s to go
# Meep progress: 494.6333333333333/1000.0 = 49.5% done in 100.1s, 102.2s to go
# Meep progress: 514.6333333333333/1000.0 = 51.5% done in 104.1s, 98.1s to go
# Meep progress: 534.0333333333333/1000.0 = 53.4% done in 108.1s, 94.3s to go
# Meep progress: 553.9666666666667/1000.0 = 55.4% done in 112.1s, 90.2s to go
# Meep progress: 573.8666666666667/1000.0 = 57.4% done in 116.1s, 86.2s to go
# Meep progress: 593.8666666666667/1000.0 = 59.4% done in 120.1s, 82.1s to go
# Meep progress: 613.5/1000.0 = 61.4% done in 124.1s, 78.2s to go
# Meep progress: 633.5333333333333/1000.0 = 63.4% done in 128.1s, 74.1s to go
# Meep progress: 653.4333333333333/1000.0 = 65.3% done in 132.1s, 70.1s to go
# Meep progress: 673.3333333333334/1000.0 = 67.3% done in 136.1s, 66.0s to go
# Meep progress: 692.9/1000.0 = 69.3% done in 140.1s, 62.1s to go
# Meep progress: 712.9666666666667/1000.0 = 71.3% done in 144.1s, 58.0s to go
# Meep progress: 732.9666666666667/1000.0 = 73.3% done in 148.1s, 54.0s to go
# Meep progress: 752.9333333333333/1000.0 = 75.3% done in 152.1s, 49.9s to go
# Meep progress: 772.4/1000.0 = 77.2% done in 156.1s, 46.0s to go
# Meep progress: 792.4/1000.0 = 79.2% done in 160.1s, 41.9s to go
# Meep progress: 812.3333333333334/1000.0 = 81.2% done in 164.1s, 37.9s to go
# Meep progress: 831.8333333333334/1000.0 = 83.2% done in 168.1s, 34.0s to go
# Meep progress: 850.0666666666666/1000.0 = 85.0% done in 172.1s, 30.4s to go
# Meep progress: 870.0333333333333/1000.0 = 87.0% done in 176.1s, 26.3s to go
# Meep progress: 889.9666666666667/1000.0 = 89.0% done in 180.1s, 22.3s to go
# Meep progress: 909.9333333333333/1000.0 = 91.0% done in 184.1s, 18.2s to go
# Meep progress: 929.1666666666666/1000.0 = 92.9% done in 188.1s, 14.3s to go
# Meep progress: 949.1/1000.0 = 94.9% done in 192.1s, 10.3s to go
# Meep progress: 968.9333333333333/1000.0 = 96.9% done in 196.1s, 6.3s to go
# Meep progress: 988.7333333333333/1000.0 = 98.9% done in 200.1s, 2.3s to go
# run 0 finished at t = 1000.0 (30000 timesteps)
#
#  Batch: 5 progress: 1/5
# Hole Scale: 2/3
#
# -----------
# Initializing structure...
# Meep: using complex fields.
# Meep progress: 19.333333333333332/1000.0 = 1.9% done in 4.0s, 203.0s to go
# Meep progress: 38.86666666666667/1000.0 = 3.9% done in 8.0s, 197.9s to go
# Meep progress: 58.8/1000.0 = 5.9% done in 12.0s, 192.2s to go
# Meep progress: 78.7/1000.0 = 7.9% done in 16.0s, 187.4s to go
# Meep progress: 98.63333333333333/1000.0 = 9.9% done in 20.0s, 182.9s to go
# Meep progress: 118.6/1000.0 = 11.9% done in 24.0s, 178.5s to go
# Meep progress: 138.8/1000.0 = 13.9% done in 28.0s, 173.8s to go
# Meep progress: 158.56666666666666/1000.0 = 15.9% done in 32.0s, 169.9s to go
# Meep progress: 178.63333333333333/1000.0 = 17.9% done in 36.0s, 165.6s to go
# Meep progress: 198.6/1000.0 = 19.9% done in 40.0s, 161.5s to go
# Meep progress: 218.86666666666667/1000.0 = 21.9% done in 44.0s, 157.1s to go
# Meep progress: 238.79999999999998/1000.0 = 23.9% done in 48.0s, 153.1s to go
# Meep progress: 259.0333333333333/1000.0 = 25.9% done in 52.0s, 148.8s to go
# Meep progress: 279.3/1000.0 = 27.9% done in 56.0s, 144.6s to go
# Meep progress: 299.5333333333333/1000.0 = 30.0% done in 60.0s, 140.4s to go
# Meep progress: 319.4/1000.0 = 31.9% done in 64.0s, 136.5s to go
# Meep progress: 339.5333333333333/1000.0 = 34.0% done in 68.0s, 132.4s to go
# Meep progress: 359.76666666666665/1000.0 = 36.0% done in 72.0s, 128.2s to go
# Meep progress: 380.0/1000.0 = 38.0% done in 76.0s, 124.1s to go
# Meep progress: 399.96666666666664/1000.0 = 40.0% done in 80.1s, 120.1s to go
# Meep progress: 420.26666666666665/1000.0 = 42.0% done in 84.1s, 116.0s to go
# Meep progress: 440.5/1000.0 = 44.0% done in 88.1s, 111.8s to go
# Meep progress: 460.73333333333335/1000.0 = 46.1% done in 92.1s, 107.8s to go
# Meep progress: 479.26666666666665/1000.0 = 47.9% done in 96.1s, 104.4s to go
# Meep progress: 498.8333333333333/1000.0 = 49.9% done in 100.1s, 100.5s to go
# Meep progress: 518.9/1000.0 = 51.9% done in 104.1s, 96.5s to go
# Meep progress: 538.6333333333333/1000.0 = 53.9% done in 108.1s, 92.6s to go
# Meep progress: 558.5/1000.0 = 55.9% done in 112.1s, 88.6s to go
# Meep progress: 578.7333333333333/1000.0 = 57.9% done in 116.1s, 84.5s to go
# Meep progress: 598.9666666666667/1000.0 = 59.9% done in 120.1s, 80.4s to go
# Meep progress: 619.1666666666666/1000.0 = 61.9% done in 124.1s, 76.3s to go
# Meep progress: 638.9333333333333/1000.0 = 63.9% done in 128.1s, 72.4s to go
# Meep progress: 659.0333333333333/1000.0 = 65.9% done in 132.1s, 68.4s to go
# Meep progress: 677.9/1000.0 = 67.8% done in 136.1s, 64.7s to go
# Meep progress: 697.0333333333333/1000.0 = 69.7% done in 140.1s, 60.9s to go
# Meep progress: 715.8/1000.0 = 71.6% done in 144.1s, 57.2s to go
# Meep progress: 734.8666666666667/1000.0 = 73.5% done in 148.1s, 53.4s to go
# Meep progress: 754.1333333333333/1000.0 = 75.4% done in 152.1s, 49.6s to go
# Meep progress: 773.9/1000.0 = 77.4% done in 156.1s, 45.6s to go
# Meep progress: 793.5/1000.0 = 79.3% done in 160.1s, 41.7s to go
# Meep progress: 813.6333333333333/1000.0 = 81.4% done in 164.1s, 37.6s to go
# Meep progress: 832.8/1000.0 = 83.3% done in 168.1s, 33.8s to go
# Meep progress: 852.8666666666667/1000.0 = 85.3% done in 172.1s, 29.7s to go
# Meep progress: 872.6333333333333/1000.0 = 87.3% done in 176.1s, 25.7s to go
# Meep progress: 892.3/1000.0 = 89.2% done in 180.2s, 21.7s to go
# Meep progress: 911.5666666666666/1000.0 = 91.2% done in 184.2s, 17.9s to go
# Meep progress: 930.5666666666666/1000.0 = 93.1% done in 188.2s, 14.0s to go
# Meep progress: 949.5666666666666/1000.0 = 95.0% done in 192.2s, 10.2s to go
# Meep progress: 969.3666666666667/1000.0 = 96.9% done in 196.2s, 6.2s to go
# Meep progress: 989.1333333333333/1000.0 = 98.9% done in 200.2s, 2.2s to go
# run 0 finished at t = 1000.0 (30000 timesteps)
#
#  Batch: 5 progress: 2/5
# Hole Scale: 1/3
#
# -----------
# Initializing structure...
# Meep: using complex fields.
# Meep progress: 17.866666666666667/1000.0 = 1.8% done in 4.0s, 220.1s to go
# Meep progress: 37.4/1000.0 = 3.7% done in 8.0s, 206.1s to go
# Meep progress: 56.43333333333333/1000.0 = 5.6% done in 12.0s, 200.8s to go
# Meep progress: 75.9/1000.0 = 7.6% done in 16.0s, 195.0s to go
# Meep progress: 95.13333333333333/1000.0 = 9.5% done in 20.0s, 190.4s to go
# Meep progress: 114.43333333333334/1000.0 = 11.4% done in 24.0s, 185.9s to go
# Meep progress: 133.9/1000.0 = 13.4% done in 28.0s, 181.3s to go
# Meep progress: 153.43333333333334/1000.0 = 15.3% done in 32.0s, 176.7s to go
# Meep progress: 172.66666666666666/1000.0 = 17.3% done in 36.0s, 172.6s to go
# Meep progress: 192.1/1000.0 = 19.2% done in 40.0s, 168.3s to go
# Meep progress: 210.86666666666667/1000.0 = 21.1% done in 44.0s, 164.8s to go
# Meep progress: 230.26666666666665/1000.0 = 23.0% done in 48.0s, 160.6s to go
# Meep progress: 249.86666666666667/1000.0 = 25.0% done in 52.0s, 156.2s to go
# Meep progress: 269.1333333333333/1000.0 = 26.9% done in 56.0s, 152.2s to go
# Meep progress: 287.6666666666667/1000.0 = 28.8% done in 60.0s, 148.7s to go
# Meep progress: 306.5333333333333/1000.0 = 30.7% done in 64.0s, 144.9s to go
# Meep progress: 325.3/1000.0 = 32.5% done in 68.1s, 141.2s to go
# Meep progress: 344.06666666666666/1000.0 = 34.4% done in 72.1s, 137.4s to go
# Meep progress: 362.76666666666665/1000.0 = 36.3% done in 76.1s, 133.6s to go
# Meep progress: 382.0333333333333/1000.0 = 38.2% done in 80.1s, 129.5s to go
# Meep progress: 401.1666666666667/1000.0 = 40.1% done in 84.1s, 125.5s to go
# Meep progress: 420.56666666666666/1000.0 = 42.1% done in 88.1s, 121.3s to go
# Meep progress: 438.5333333333333/1000.0 = 43.9% done in 92.1s, 117.9s to go
# Meep progress: 457.1666666666667/1000.0 = 45.7% done in 96.1s, 114.1s to go
# Meep progress: 476.23333333333335/1000.0 = 47.6% done in 100.1s, 110.1s to go
# Meep progress: 495.3666666666667/1000.0 = 49.5% done in 104.1s, 106.0s to go
# Meep progress: 515.3666666666667/1000.0 = 51.5% done in 108.1s, 101.7s to go
# Meep progress: 534.7333333333333/1000.0 = 53.5% done in 112.1s, 97.5s to go
# Meep progress: 552.8666666666667/1000.0 = 55.3% done in 116.1s, 93.9s to go
# Meep progress: 570.6333333333333/1000.0 = 57.1% done in 120.1s, 90.4s to go
# Meep progress: 589.3333333333334/1000.0 = 58.9% done in 124.1s, 86.5s to go
# Meep progress: 606.9666666666667/1000.0 = 60.7% done in 128.1s, 83.0s to go
# Meep progress: 625.8333333333334/1000.0 = 62.6% done in 132.1s, 79.0s to go
# Meep progress: 643.6333333333333/1000.0 = 64.4% done in 136.1s, 75.4s to go
# Meep progress: 661.3333333333334/1000.0 = 66.1% done in 140.1s, 71.8s to go
# Meep progress: 678.0666666666666/1000.0 = 67.8% done in 144.1s, 68.4s to go
# Meep progress: 694.9/1000.0 = 69.5% done in 148.1s, 65.0s to go
# Meep progress: 713.5/1000.0 = 71.3% done in 152.1s, 61.1s to go
# Meep progress: 733.4/1000.0 = 73.3% done in 156.1s, 56.8s to go
# Meep progress: 753.4/1000.0 = 75.3% done in 160.1s, 52.4s to go
# Meep progress: 772.6333333333333/1000.0 = 77.3% done in 164.1s, 48.3s to go
# Meep progress: 790.9333333333333/1000.0 = 79.1% done in 168.1s, 44.4s to go
# Meep progress: 809.9666666666667/1000.0 = 81.0% done in 172.1s, 40.4s to go
# Meep progress: 828.7666666666667/1000.0 = 82.9% done in 176.2s, 36.4s to go
# Meep progress: 846.8333333333334/1000.0 = 84.7% done in 180.2s, 32.6s to go
# Meep progress: 866.0333333333333/1000.0 = 86.6% done in 184.2s, 28.5s to go
# Meep progress: 884.2333333333333/1000.0 = 88.4% done in 188.2s, 24.6s to go
# Meep progress: 903.6666666666666/1000.0 = 90.4% done in 192.2s, 20.5s to go
# Meep progress: 922.5/1000.0 = 92.2% done in 196.2s, 16.5s to go
# Meep progress: 941.9333333333333/1000.0 = 94.2% done in 200.2s, 12.3s to go
# Meep progress: 961.2333333333333/1000.0 = 96.1% done in 204.2s, 8.2s to go
# Meep progress: 980.1333333333333/1000.0 = 98.0% done in 208.2s, 4.2s to go
# Meep progress: 997.4666666666667/1000.0 = 99.7% done in 212.2s, 0.5s to go
# run 0 finished at t = 1000.0 (30000 timesteps)
#
#  Batch: 5 progress: 2/5
# Hole Scale: 2/3
#
# -----------
# Initializing structure...
# Meep: using complex fields.
# Meep progress: 18.4/1000.0 = 1.8% done in 4.0s, 213.6s to go
# Meep progress: 35.8/1000.0 = 3.6% done in 8.0s, 215.7s to go
# Meep progress: 54.199999999999996/1000.0 = 5.4% done in 12.0s, 209.7s to go
# Meep progress: 73.16666666666667/1000.0 = 7.3% done in 16.0s, 202.9s to go
# Meep progress: 92.96666666666667/1000.0 = 9.3% done in 20.0s, 195.4s to go
# Meep progress: 112.86666666666666/1000.0 = 11.3% done in 24.0s, 188.9s to go
# Meep progress: 132.7/1000.0 = 13.3% done in 28.0s, 183.2s to go
# Meep progress: 152.13333333333333/1000.0 = 15.2% done in 32.0s, 178.5s to go
# Meep progress: 171.9/1000.0 = 17.2% done in 36.0s, 173.6s to go
# Meep progress: 192.0/1000.0 = 19.2% done in 40.0s, 168.5s to go
# Meep progress: 211.93333333333334/1000.0 = 21.2% done in 44.0s, 163.8s to go
# Meep progress: 230.83333333333334/1000.0 = 23.1% done in 48.0s, 160.1s to go
# Meep progress: 249.0/1000.0 = 24.9% done in 52.1s, 157.0s to go
# Meep progress: 267.8333333333333/1000.0 = 26.8% done in 56.1s, 153.2s to go
# Meep progress: 286.06666666666666/1000.0 = 28.6% done in 60.1s, 149.9s to go
# Meep progress: 303.8666666666667/1000.0 = 30.4% done in 64.1s, 146.7s to go
# Meep progress: 323.46666666666664/1000.0 = 32.3% done in 68.1s, 142.3s to go
# Meep progress: 342.8666666666667/1000.0 = 34.3% done in 72.1s, 138.1s to go
# Meep progress: 362.46666666666664/1000.0 = 36.2% done in 76.1s, 133.8s to go
# Meep progress: 381.73333333333335/1000.0 = 38.2% done in 80.1s, 129.7s to go
# Meep progress: 401.4/1000.0 = 40.1% done in 84.1s, 125.4s to go
# Meep progress: 421.0/1000.0 = 42.1% done in 88.1s, 121.1s to go
# Meep progress: 440.4/1000.0 = 44.0% done in 92.1s, 117.0s to go
# Meep progress: 460.06666666666666/1000.0 = 46.0% done in 96.1s, 112.8s to go
# Meep progress: 480.0333333333333/1000.0 = 48.0% done in 100.1s, 108.4s to go
# Meep progress: 500.23333333333335/1000.0 = 50.0% done in 104.1s, 104.0s to go
# Meep progress: 520.3333333333334/1000.0 = 52.0% done in 108.1s, 99.6s to go
# Meep progress: 540.0666666666666/1000.0 = 54.0% done in 112.1s, 95.5s to go
# Meep progress: 560.3/1000.0 = 56.0% done in 116.1s, 91.1s to go
# Meep progress: 580.5/1000.0 = 58.0% done in 120.1s, 86.8s to go
# Meep progress: 600.6333333333333/1000.0 = 60.1% done in 124.1s, 82.5s to go
# Meep progress: 620.4333333333333/1000.0 = 62.0% done in 128.1s, 78.4s to go
# Meep progress: 640.5666666666666/1000.0 = 64.1% done in 132.1s, 74.1s to go
# Meep progress: 660.6666666666666/1000.0 = 66.1% done in 136.1s, 69.9s to go
# Meep progress: 680.8666666666667/1000.0 = 68.1% done in 140.1s, 65.7s to go
# Meep progress: 700.7/1000.0 = 70.1% done in 144.1s, 61.6s to go
# Meep progress: 720.9/1000.0 = 72.1% done in 148.1s, 57.3s to go
# Meep progress: 740.7666666666667/1000.0 = 74.1% done in 152.1s, 53.2s to go
# Meep progress: 760.9666666666667/1000.0 = 76.1% done in 156.1s, 49.0s to go
# Meep progress: 780.7/1000.0 = 78.1% done in 160.1s, 45.0s to go
# Meep progress: 800.8/1000.0 = 80.1% done in 164.1s, 40.8s to go
# Meep progress: 820.7666666666667/1000.0 = 82.1% done in 168.1s, 36.7s to go
# Meep progress: 840.9333333333333/1000.0 = 84.1% done in 172.1s, 32.6s to go
# Meep progress: 860.7666666666667/1000.0 = 86.1% done in 176.1s, 28.5s to go
# Meep progress: 880.8333333333334/1000.0 = 88.1% done in 180.1s, 24.4s to go
# Meep progress: 900.7666666666667/1000.0 = 90.1% done in 184.1s, 20.3s to go
# Meep progress: 920.9/1000.0 = 92.1% done in 188.2s, 16.2s to go
# Meep progress: 940.2666666666667/1000.0 = 94.0% done in 192.2s, 12.2s to go
# Meep progress: 960.4333333333333/1000.0 = 96.0% done in 196.2s, 8.1s to go
# Meep progress: 980.4666666666667/1000.0 = 98.0% done in 200.2s, 4.0s to go
# run 0 finished at t = 1000.0 (30000 timesteps)
#
#  Batch: 5 progress: 3/5
# Hole Scale: 1/3
#
# -----------
# Initializing structure...
# Meep: using complex fields.
# Meep progress: 19.5/1000.0 = 1.9% done in 4.0s, 201.2s to go
# Meep progress: 39.733333333333334/1000.0 = 4.0% done in 8.0s, 193.5s to go
# Meep progress: 60.0/1000.0 = 6.0% done in 12.0s, 188.1s to go
# Meep progress: 79.8/1000.0 = 8.0% done in 16.0s, 184.6s to go
# Meep progress: 100.03333333333333/1000.0 = 10.0% done in 20.0s, 180.1s to go
# Meep progress: 120.23333333333333/1000.0 = 12.0% done in 24.0s, 175.7s to go
# Meep progress: 140.46666666666667/1000.0 = 14.0% done in 28.0s, 171.5s to go
# Meep progress: 160.4/1000.0 = 16.0% done in 32.0s, 167.6s to go
# Meep progress: 180.56666666666666/1000.0 = 18.1% done in 36.0s, 163.5s to go
# Meep progress: 200.83333333333334/1000.0 = 20.1% done in 40.0s, 159.3s to go
# Meep progress: 221.1/1000.0 = 22.1% done in 44.0s, 155.1s to go
# Meep progress: 240.96666666666667/1000.0 = 24.1% done in 48.0s, 151.3s to go
# Meep progress: 261.2/1000.0 = 26.1% done in 52.0s, 147.2s to go
# Meep progress: 281.5/1000.0 = 28.1% done in 56.0s, 143.0s to go
# Meep progress: 301.76666666666665/1000.0 = 30.2% done in 60.0s, 138.9s to go
# Meep progress: 321.6333333333333/1000.0 = 32.2% done in 64.1s, 135.1s to go
# Meep progress: 341.5333333333333/1000.0 = 34.2% done in 68.1s, 131.2s to go
# Meep progress: 361.73333333333335/1000.0 = 36.2% done in 72.1s, 127.1s to go
# Meep progress: 381.8/1000.0 = 38.2% done in 76.1s, 123.2s to go
# Meep progress: 401.6/1000.0 = 40.2% done in 80.1s, 119.3s to go
# Meep progress: 421.46666666666664/1000.0 = 42.1% done in 84.1s, 115.4s to go
# Meep progress: 441.73333333333335/1000.0 = 44.2% done in 88.1s, 111.3s to go
# Meep progress: 461.8666666666667/1000.0 = 46.2% done in 92.1s, 107.3s to go
# Meep progress: 481.59999999999997/1000.0 = 48.2% done in 96.1s, 103.4s to go
# Meep progress: 501.7/1000.0 = 50.2% done in 100.1s, 99.4s to go
# Meep progress: 521.6/1000.0 = 52.2% done in 104.1s, 95.5s to go
# Meep progress: 541.4333333333333/1000.0 = 54.1% done in 108.1s, 91.5s to go
# Meep progress: 561.1666666666666/1000.0 = 56.1% done in 112.1s, 87.7s to go
# Meep progress: 581.1/1000.0 = 58.1% done in 116.1s, 83.7s to go
# Meep progress: 601.1333333333333/1000.0 = 60.1% done in 120.1s, 79.7s to go
# Meep progress: 619.5666666666666/1000.0 = 62.0% done in 124.1s, 76.2s to go
# Meep progress: 637.2/1000.0 = 63.7% done in 128.1s, 72.9s to go
# Meep progress: 656.0333333333333/1000.0 = 65.6% done in 132.1s, 69.3s to go
# Meep progress: 674.3666666666667/1000.0 = 67.4% done in 136.1s, 65.7s to go
# Meep progress: 692.9666666666667/1000.0 = 69.3% done in 140.1s, 62.1s to go
# Meep progress: 711.7333333333333/1000.0 = 71.2% done in 144.1s, 58.4s to go
# Meep progress: 731.4666666666667/1000.0 = 73.1% done in 148.1s, 54.4s to go
# Meep progress: 751.1333333333333/1000.0 = 75.1% done in 152.1s, 50.4s to go
# Meep progress: 769.9333333333333/1000.0 = 77.0% done in 156.1s, 46.7s to go
# Meep progress: 788.3/1000.0 = 78.8% done in 160.1s, 43.0s to go
# Meep progress: 808.0333333333333/1000.0 = 80.8% done in 164.1s, 39.0s to go
# Meep progress: 828.0666666666666/1000.0 = 82.8% done in 168.1s, 34.9s to go
# Meep progress: 848.2666666666667/1000.0 = 84.8% done in 172.1s, 30.8s to go
# Meep progress: 867.9333333333333/1000.0 = 86.8% done in 176.1s, 26.8s to go
# Meep progress: 887.6999999999999/1000.0 = 88.8% done in 180.1s, 22.8s to go
# Meep progress: 907.5/1000.0 = 90.8% done in 184.1s, 18.8s to go
# Meep progress: 927.1333333333333/1000.0 = 92.7% done in 188.2s, 14.8s to go
# Meep progress: 946.1666666666666/1000.0 = 94.6% done in 192.2s, 10.9s to go
# Meep progress: 965.8333333333334/1000.0 = 96.6% done in 196.2s, 6.9s to go
# Meep progress: 983.8333333333334/1000.0 = 98.4% done in 200.2s, 3.3s to go
# run 0 finished at t = 1000.0 (30000 timesteps)
#
#  Batch: 5 progress: 3/5
# Hole Scale: 2/3
#
# -----------
# Initializing structure...
# Meep: using complex fields.
# Meep progress: 16.833333333333332/1000.0 = 1.7% done in 4.0s, 234.0s to go
# Meep progress: 34.93333333333333/1000.0 = 3.5% done in 8.0s, 221.4s to go
# Meep progress: 51.4/1000.0 = 5.1% done in 12.0s, 221.8s to go
# Meep progress: 69.53333333333333/1000.0 = 7.0% done in 16.0s, 214.4s to go
# Meep progress: 87.4/1000.0 = 8.7% done in 20.0s, 209.1s to go
# Meep progress: 105.73333333333333/1000.0 = 10.6% done in 24.0s, 203.2s to go
# Meep progress: 124.96666666666667/1000.0 = 12.5% done in 28.0s, 196.3s to go
# Meep progress: 142.86666666666667/1000.0 = 14.3% done in 32.0s, 192.2s to go
# Meep progress: 160.93333333333334/1000.0 = 16.1% done in 36.0s, 187.9s to go
# Meep progress: 180.36666666666667/1000.0 = 18.0% done in 40.0s, 182.0s to go
# Meep progress: 199.56666666666666/1000.0 = 20.0% done in 44.0s, 176.6s to go
# Meep progress: 218.53333333333333/1000.0 = 21.9% done in 48.0s, 171.8s to go
# Meep progress: 237.23333333333332/1000.0 = 23.7% done in 52.0s, 167.4s to go
# Meep progress: 256.93333333333334/1000.0 = 25.7% done in 56.1s, 162.1s to go
# Meep progress: 276.5333333333333/1000.0 = 27.7% done in 60.1s, 157.1s to go
# Meep progress: 296.4/1000.0 = 29.6% done in 64.1s, 152.1s to go
# Meep progress: 315.8666666666667/1000.0 = 31.6% done in 68.1s, 147.4s to go
# Meep progress: 335.0333333333333/1000.0 = 33.5% done in 72.1s, 143.0s to go
# Meep progress: 354.6/1000.0 = 35.5% done in 76.1s, 138.5s to go
# Meep progress: 373.7/1000.0 = 37.4% done in 80.1s, 134.2s to go
# Meep progress: 393.0333333333333/1000.0 = 39.3% done in 84.1s, 129.8s to go
# Meep progress: 412.56666666666666/1000.0 = 41.3% done in 88.1s, 125.4s to go
# Meep progress: 432.23333333333335/1000.0 = 43.2% done in 92.1s, 121.0s to go
# Meep progress: 451.6333333333333/1000.0 = 45.2% done in 96.1s, 116.7s to go
# Meep progress: 470.8333333333333/1000.0 = 47.1% done in 100.1s, 112.5s to go
# Meep progress: 490.7/1000.0 = 49.1% done in 104.1s, 108.0s to go
# Meep progress: 509.3666666666667/1000.0 = 50.9% done in 108.1s, 104.1s to go
# Meep progress: 528.5/1000.0 = 52.9% done in 112.1s, 100.0s to go
# Meep progress: 548.1333333333333/1000.0 = 54.8% done in 116.1s, 95.7s to go
# Meep progress: 568.0/1000.0 = 56.8% done in 120.1s, 91.4s to go
# Meep progress: 587.0666666666666/1000.0 = 58.7% done in 124.1s, 87.3s to go
# Meep progress: 606.0/1000.0 = 60.6% done in 128.1s, 83.3s to go
# Meep progress: 625.5666666666666/1000.0 = 62.6% done in 132.1s, 79.1s to go
# Meep progress: 645.0/1000.0 = 64.5% done in 136.1s, 74.9s to go
# Meep progress: 663.1666666666666/1000.0 = 66.3% done in 140.1s, 71.2s to go
# Meep progress: 682.5/1000.0 = 68.2% done in 144.1s, 67.0s to go
# Meep progress: 701.6666666666666/1000.0 = 70.2% done in 148.1s, 63.0s to go
# Meep progress: 721.5333333333333/1000.0 = 72.2% done in 152.1s, 58.7s to go
# Meep progress: 740.7666666666667/1000.0 = 74.1% done in 156.1s, 54.6s to go
# Meep progress: 760.0666666666666/1000.0 = 76.0% done in 160.1s, 50.6s to go
# Meep progress: 779.7333333333333/1000.0 = 78.0% done in 164.1s, 46.4s to go
# Meep progress: 799.7333333333333/1000.0 = 80.0% done in 168.1s, 42.1s to go
# Meep progress: 819.5/1000.0 = 82.0% done in 172.1s, 37.9s to go
# Meep progress: 839.2333333333333/1000.0 = 83.9% done in 176.1s, 33.7s to go
# Meep progress: 858.1/1000.0 = 85.8% done in 180.2s, 29.8s to go
# Meep progress: 877.9333333333333/1000.0 = 87.8% done in 184.2s, 25.6s to go
# Meep progress: 897.7666666666667/1000.0 = 89.8% done in 188.2s, 21.4s to go
# Meep progress: 917.4666666666667/1000.0 = 91.7% done in 192.2s, 17.3s to go
# Meep progress: 936.6666666666666/1000.0 = 93.7% done in 196.2s, 13.3s to go
# Meep progress: 956.0333333333333/1000.0 = 95.6% done in 200.2s, 9.2s to go
# Meep progress: 975.6333333333333/1000.0 = 97.6% done in 204.2s, 5.1s to go
# Meep progress: 995.2333333333333/1000.0 = 99.5% done in 208.2s, 1.0s to go
# run 0 finished at t = 1000.0 (30000 timesteps)
#
#  Batch: 5 progress: 4/5
# Hole Scale: 1/3
#
# -----------
# Initializing structure...
# Meep: using complex fields.
# Meep progress: 18.166666666666668/1000.0 = 1.8% done in 4.0s, 216.4s to go
# Meep progress: 37.06666666666666/1000.0 = 3.7% done in 8.0s, 208.0s to go
# Meep progress: 56.699999999999996/1000.0 = 5.7% done in 12.0s, 199.8s to go
# Meep progress: 76.0/1000.0 = 7.6% done in 16.0s, 194.7s to go
# Meep progress: 95.83333333333333/1000.0 = 9.6% done in 20.0s, 188.9s to go
# Meep progress: 115.16666666666667/1000.0 = 11.5% done in 24.0s, 184.6s to go
# Meep progress: 134.4/1000.0 = 13.4% done in 28.0s, 180.5s to go
# Meep progress: 153.23333333333332/1000.0 = 15.3% done in 32.0s, 177.0s to go
# Meep progress: 172.96666666666667/1000.0 = 17.3% done in 36.0s, 172.3s to go
# Meep progress: 192.33333333333334/1000.0 = 19.2% done in 40.0s, 168.1s to go
# Meep progress: 211.83333333333334/1000.0 = 21.2% done in 44.0s, 163.9s to go
# Meep progress: 230.36666666666667/1000.0 = 23.0% done in 48.0s, 160.5s to go
# Meep progress: 249.86666666666667/1000.0 = 25.0% done in 52.1s, 156.3s to go
# Meep progress: 269.2/1000.0 = 26.9% done in 56.1s, 152.2s to go
# Meep progress: 288.8/1000.0 = 28.9% done in 60.1s, 147.9s to go
# Meep progress: 308.2/1000.0 = 30.8% done in 64.1s, 143.8s to go
# Meep progress: 326.26666666666665/1000.0 = 32.6% done in 68.1s, 140.6s to go
# Meep progress: 341.0333333333333/1000.0 = 34.1% done in 72.1s, 139.3s to go
# Meep progress: 355.4/1000.0 = 35.5% done in 76.1s, 138.0s to go
# Meep progress: 369.26666666666665/1000.0 = 36.9% done in 80.1s, 136.8s to go
# Meep progress: 383.6666666666667/1000.0 = 38.4% done in 84.1s, 135.1s to go
# Meep progress: 400.56666666666666/1000.0 = 40.1% done in 88.1s, 131.8s to go
# Meep progress: 420.26666666666665/1000.0 = 42.0% done in 92.1s, 127.0s to go
# Meep progress: 440.0/1000.0 = 44.0% done in 96.1s, 122.3s to go
# Meep progress: 460.0333333333333/1000.0 = 46.0% done in 100.1s, 117.5s to go
# Meep progress: 480.23333333333335/1000.0 = 48.0% done in 104.1s, 112.7s to go
# Meep progress: 499.93333333333334/1000.0 = 50.0% done in 108.1s, 108.1s to go
# Meep progress: 518.1333333333333/1000.0 = 51.8% done in 112.1s, 104.3s to go
# Meep progress: 538.0666666666666/1000.0 = 53.8% done in 116.1s, 99.7s to go
# Meep progress: 558.2333333333333/1000.0 = 55.8% done in 120.1s, 95.0s to go
# Meep progress: 578.5/1000.0 = 57.9% done in 124.1s, 90.4s to go
# Meep progress: 597.9/1000.0 = 59.8% done in 128.1s, 86.2s to go
# Meep progress: 617.2666666666667/1000.0 = 61.7% done in 132.1s, 81.9s to go
# Meep progress: 636.4666666666667/1000.0 = 63.6% done in 136.1s, 77.7s to go
# Meep progress: 656.0666666666666/1000.0 = 65.6% done in 140.1s, 73.5s to go
# Meep progress: 675.5333333333333/1000.0 = 67.6% done in 144.1s, 69.2s to go
# Meep progress: 690.7333333333333/1000.0 = 69.1% done in 148.1s, 66.3s to go
# Meep progress: 708.2/1000.0 = 70.8% done in 152.1s, 62.7s to go
# Meep progress: 723.6333333333333/1000.0 = 72.4% done in 156.1s, 59.6s to go
# Meep progress: 740.9/1000.0 = 74.1% done in 160.2s, 56.0s to go
# Meep progress: 759.5666666666666/1000.0 = 76.0% done in 164.2s, 52.0s to go
# Meep progress: 777.7666666666667/1000.0 = 77.8% done in 168.2s, 48.0s to go
# Meep progress: 796.6/1000.0 = 79.7% done in 172.2s, 44.0s to go
# Meep progress: 814.9666666666667/1000.0 = 81.5% done in 176.2s, 40.0s to go
# Meep progress: 833.1666666666666/1000.0 = 83.3% done in 180.2s, 36.1s to go
# Meep progress: 851.6999999999999/1000.0 = 85.2% done in 184.2s, 32.1s to go
# Meep progress: 871.1333333333333/1000.0 = 87.1% done in 188.2s, 27.8s to go
# Meep progress: 890.5333333333333/1000.0 = 89.1% done in 192.2s, 23.6s to go
# Meep progress: 909.9333333333333/1000.0 = 91.0% done in 196.2s, 19.4s to go
# Meep progress: 929.6999999999999/1000.0 = 93.0% done in 200.2s, 15.1s to go
# Meep progress: 949.6333333333333/1000.0 = 95.0% done in 204.2s, 10.8s to go
# Meep progress: 969.0333333333333/1000.0 = 96.9% done in 208.2s, 6.7s to go
# Meep progress: 988.4666666666667/1000.0 = 98.8% done in 212.2s, 2.5s to go
# run 0 finished at t = 1000.0 (30000 timesteps)
#
#  Batch: 5 progress: 4/5
# Hole Scale: 2/3
#
# -----------
# Initializing structure...
# Meep: using complex fields.
# Meep progress: 19.3/1000.0 = 1.9% done in 4.0s, 203.5s to go
# Meep progress: 38.733333333333334/1000.0 = 3.9% done in 8.0s, 198.7s to go
# Meep progress: 58.96666666666667/1000.0 = 5.9% done in 12.0s, 191.7s to go
# Meep progress: 79.06666666666666/1000.0 = 7.9% done in 16.0s, 186.6s to go
# Meep progress: 96.5/1000.0 = 9.7% done in 20.0s, 187.5s to go
# Meep progress: 114.8/1000.0 = 11.5% done in 24.0s, 185.3s to go
# Meep progress: 134.66666666666666/1000.0 = 13.5% done in 28.0s, 180.2s to go
# Meep progress: 154.4/1000.0 = 15.4% done in 32.0s, 175.5s to go
# Meep progress: 174.53333333333333/1000.0 = 17.5% done in 36.0s, 170.5s to go
# Meep progress: 192.6/1000.0 = 19.3% done in 40.0s, 167.9s to go
# Meep progress: 212.2/1000.0 = 21.2% done in 44.0s, 163.5s to go
# Meep progress: 232.2/1000.0 = 23.2% done in 48.1s, 158.9s to go
# Meep progress: 252.43333333333334/1000.0 = 25.2% done in 52.1s, 154.2s to go
# Meep progress: 271.76666666666665/1000.0 = 27.2% done in 56.1s, 150.2s to go
# Meep progress: 290.76666666666665/1000.0 = 29.1% done in 60.1s, 146.5s to go
# Meep progress: 310.8/1000.0 = 31.1% done in 64.1s, 142.1s to go
# Meep progress: 330.6333333333333/1000.0 = 33.1% done in 68.1s, 137.8s to go
# Meep progress: 347.93333333333334/1000.0 = 34.8% done in 72.1s, 135.1s to go
# Meep progress: 366.5/1000.0 = 36.6% done in 76.1s, 131.5s to go
# Meep progress: 386.0333333333333/1000.0 = 38.6% done in 80.1s, 127.4s to go
# Meep progress: 405.56666666666666/1000.0 = 40.6% done in 84.1s, 123.3s to go
# Meep progress: 425.23333333333335/1000.0 = 42.5% done in 88.1s, 119.1s to go
# Meep progress: 445.1666666666667/1000.0 = 44.5% done in 92.1s, 114.8s to go
# Meep progress: 465.3333333333333/1000.0 = 46.5% done in 96.1s, 110.4s to go
# Meep progress: 485.1666666666667/1000.0 = 48.5% done in 100.1s, 106.2s to go
# Meep progress: 504.5/1000.0 = 50.5% done in 104.1s, 102.3s to go
# Meep progress: 524.1333333333333/1000.0 = 52.4% done in 108.1s, 98.2s to go
# Meep progress: 543.5666666666666/1000.0 = 54.4% done in 112.1s, 94.1s to go
# Meep progress: 563.4/1000.0 = 56.3% done in 116.1s, 90.0s to go
# Meep progress: 582.7333333333333/1000.0 = 58.3% done in 120.1s, 86.0s to go
# Meep progress: 601.8666666666667/1000.0 = 60.2% done in 124.1s, 82.1s to go
# Meep progress: 621.1/1000.0 = 62.1% done in 128.1s, 78.2s to go
# Meep progress: 638.5666666666666/1000.0 = 63.9% done in 132.1s, 74.8s to go
# Meep progress: 656.6666666666666/1000.0 = 65.7% done in 136.1s, 71.2s to go
# Meep progress: 676.2/1000.0 = 67.6% done in 140.2s, 67.1s to go
# Meep progress: 694.5333333333333/1000.0 = 69.5% done in 144.2s, 63.4s to go
# Meep progress: 713.7666666666667/1000.0 = 71.4% done in 148.2s, 59.4s to go
# Meep progress: 732.3/1000.0 = 73.2% done in 152.2s, 55.6s to go
# Meep progress: 751.3666666666667/1000.0 = 75.1% done in 156.2s, 51.7s to go
# Meep progress: 770.7333333333333/1000.0 = 77.1% done in 160.2s, 47.6s to go
# Meep progress: 789.7333333333333/1000.0 = 79.0% done in 164.2s, 43.7s to go
# Meep progress: 808.9333333333333/1000.0 = 80.9% done in 168.2s, 39.7s to go
# Meep progress: 829.0/1000.0 = 82.9% done in 172.2s, 35.5s to go
# Meep progress: 848.1333333333333/1000.0 = 84.8% done in 176.2s, 31.5s to go
# Meep progress: 866.5/1000.0 = 86.7% done in 180.2s, 27.8s to go
# Meep progress: 885.5/1000.0 = 88.5% done in 184.2s, 23.8s to go
# Meep progress: 905.1999999999999/1000.0 = 90.5% done in 188.2s, 19.7s to go
# Meep progress: 924.7333333333333/1000.0 = 92.5% done in 192.2s, 15.6s to go
# Meep progress: 944.4666666666667/1000.0 = 94.4% done in 196.2s, 11.5s to go
# Meep progress: 963.6/1000.0 = 96.4% done in 200.2s, 7.6s to go
# Meep progress: 983.1/1000.0 = 98.3% done in 204.2s, 3.5s to go
# run 0 finished at t = 1000.0 (30000 timesteps)
#
#  Batch: 5 progress: 5/5
# Hole Scale: 1/3
#
# -----------
# Initializing structure...
# Meep: using complex fields.
# Meep progress: 18.7/1000.0 = 1.9% done in 4.0s, 210.1s to go
# Meep progress: 37.4/1000.0 = 3.7% done in 8.0s, 206.1s to go
# Meep progress: 55.36666666666667/1000.0 = 5.5% done in 12.0s, 204.9s to go
# Meep progress: 74.73333333333333/1000.0 = 7.5% done in 16.0s, 198.3s to go
# Meep progress: 93.36666666666666/1000.0 = 9.3% done in 20.0s, 194.4s to go
# Meep progress: 112.86666666666666/1000.0 = 11.3% done in 24.0s, 188.8s to go
# Meep progress: 131.96666666666667/1000.0 = 13.2% done in 28.0s, 184.3s to go
# Meep progress: 150.36666666666667/1000.0 = 15.0% done in 32.0s, 180.9s to go
# Meep progress: 168.93333333333334/1000.0 = 16.9% done in 36.0s, 177.2s to go
# Meep progress: 187.16666666666666/1000.0 = 18.7% done in 40.0s, 173.8s to go
# Meep progress: 204.73333333333332/1000.0 = 20.5% done in 44.0s, 171.1s to go
# Meep progress: 224.2/1000.0 = 22.4% done in 48.0s, 166.2s to go
# Meep progress: 243.73333333333332/1000.0 = 24.4% done in 52.0s, 161.5s to go
# Meep progress: 263.9/1000.0 = 26.4% done in 56.0s, 156.3s to go
# Meep progress: 283.8666666666667/1000.0 = 28.4% done in 60.0s, 151.5s to go
# Meep progress: 303.76666666666665/1000.0 = 30.4% done in 64.0s, 146.8s to go
# Meep progress: 323.3666666666667/1000.0 = 32.3% done in 68.1s, 142.4s to go
# Meep progress: 343.26666666666665/1000.0 = 34.3% done in 72.1s, 137.9s to go
# Meep progress: 363.26666666666665/1000.0 = 36.3% done in 76.1s, 133.3s to go
# Meep progress: 383.3/1000.0 = 38.3% done in 80.1s, 128.8s to go
# Meep progress: 402.1333333333333/1000.0 = 40.2% done in 84.1s, 125.0s to go
# Meep progress: 421.5/1000.0 = 42.1% done in 88.1s, 120.9s to go
# Meep progress: 440.5/1000.0 = 44.0% done in 92.1s, 116.9s to go
# Meep progress: 459.4/1000.0 = 45.9% done in 96.1s, 113.0s to go
# Meep progress: 478.3333333333333/1000.0 = 47.8% done in 100.1s, 109.1s to go
# Meep progress: 497.6666666666667/1000.0 = 49.8% done in 104.1s, 105.0s to go
# Meep progress: 516.9333333333333/1000.0 = 51.7% done in 108.1s, 101.0s to go
# Meep progress: 536.1333333333333/1000.0 = 53.6% done in 112.1s, 97.0s to go
# Meep progress: 555.1666666666666/1000.0 = 55.5% done in 116.1s, 93.0s to go
# Meep progress: 574.3/1000.0 = 57.4% done in 120.1s, 89.0s to go
# Meep progress: 593.3666666666667/1000.0 = 59.3% done in 124.1s, 85.0s to go
# Meep progress: 613.0/1000.0 = 61.3% done in 128.1s, 80.9s to go
# Meep progress: 632.2333333333333/1000.0 = 63.2% done in 132.1s, 76.8s to go
# Meep progress: 651.8/1000.0 = 65.2% done in 136.1s, 72.7s to go
# Meep progress: 670.8/1000.0 = 67.1% done in 140.1s, 68.8s to go
# Meep progress: 688.0333333333333/1000.0 = 68.8% done in 144.1s, 65.3s to go
# Meep progress: 706.0/1000.0 = 70.6% done in 148.1s, 61.7s to go
# Meep progress: 724.5333333333333/1000.0 = 72.5% done in 152.1s, 57.8s to go
# Meep progress: 743.8333333333334/1000.0 = 74.4% done in 156.1s, 53.8s to go
# Meep progress: 763.0333333333333/1000.0 = 76.3% done in 160.1s, 49.7s to go
# Meep progress: 782.5/1000.0 = 78.2% done in 164.1s, 45.6s to go
# Meep progress: 802.3/1000.0 = 80.2% done in 168.1s, 41.4s to go
# Meep progress: 821.3/1000.0 = 82.1% done in 172.1s, 37.5s to go
# Meep progress: 840.4/1000.0 = 84.0% done in 176.1s, 33.4s to go
# Meep progress: 858.3/1000.0 = 85.8% done in 180.1s, 29.7s to go
# Meep progress: 877.4/1000.0 = 87.7% done in 184.1s, 25.7s to go
# Meep progress: 896.2333333333333/1000.0 = 89.6% done in 188.1s, 21.8s to go
# Meep progress: 914.0333333333333/1000.0 = 91.4% done in 192.1s, 18.1s to go
# Meep progress: 928.6999999999999/1000.0 = 92.9% done in 196.1s, 15.1s to go
# Meep progress: 947.0333333333333/1000.0 = 94.7% done in 200.2s, 11.2s to go
# Meep progress: 966.1666666666666/1000.0 = 96.6% done in 204.2s, 7.1s to go
# Meep progress: 984.9666666666667/1000.0 = 98.5% done in 208.2s, 3.2s to go
# run 0 finished at t = 1000.0 (30000 timesteps)
#
#  Batch: 5 progress: 5/5
# Hole Scale: 2/3
