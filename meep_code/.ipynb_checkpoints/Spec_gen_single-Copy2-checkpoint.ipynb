# %%
from matplotlib import pyplot as plt
import numpy as np
import meep as mp
import math
import cmath

shape_size = 48
sx, sy, sz = 1, 1, 4
h = 1.25
dpml = 0.5
b_m, c_m = 1.4, 3.54
res = 17
echo = 1000
cell_size = mp.Vector3(sx,sy,sz)
fcen = 0.5
df = 0.2
theta = math.radians(0)
nfreq = 200

# k with correct length (plane of incidence: XZ) 
k = mp.Vector3(math.sin(theta),0,math.cos(theta)).scale(fcen)
def pw_amp(k, x0):
    def _pw_amp(x):
        return cmath.exp(1j * 2 * math.pi * k.dot(x + x0))
    return _pw_amp

def get_spec():  
    for r in np.arange(0.05, 0.3, 0.05):
        hole = mp.Cylinder(radius= r,height=h, material=mp.Medium(index = c_m))
#         bend = get_bend()
#         Ts = []
#         st = np.genfromtxt('data/straight.txt')
#         freq = np.genfromtxt('data/freq.txt')
#         for j in range(nfreq):
#             Ts = np.append(Ts, bend[j]/st[j])
#         print('Cylinder radius of 0.3 without holes')         
#         plt.plot(freq,Ts)
#         plt.show()  
        bend = get_bend(hole)
        Ts = []
        st = np.genfromtxt('data/straight.txt')
        freq = np.genfromtxt('data/freq.txt')
        for j in range(nfreq):
            Ts = np.append(Ts, bend[j]/st[j])
        print('Cylinder radius of 0.3 with holes of radius '+str(r))         
        plt.plot(freq,Ts)
        plt.show()  
                    
def get_bend(hole = None):
    geometry = [mp.Block(size = cell_size, material=mp.Medium(index=b_m)),
                mp.Cylinder(radius= 0.3,height=h, material=mp.Medium(index = c_m)
#                 mp.Prism(vertices, 
#                          height=h, 
#                          material=mp.Medium(index=c_m),
#                          center=mp.Vector3()
                        )]
    if hole is not None:
        geometry.append(hole)
    pml_layers = [mp.PML(thickness=1, direction = mp.Z, side=mp.High),
                  mp.Absorber(thickness=1,direction = mp.Z, side=mp.Low)]
    src_pos = -(sz/2 - dpml - 0.5)
    src = [mp.Source(src = mp.GaussianSource(fcen, fwidth=df),
                     component = mp.Ey,
                     center = mp.Vector3(0,0,src_pos),
                     size = mp.Vector3(sx,sy,0),
                     amp_func=pw_amp(k,mp.Vector3(0,0,src_pos)))]
    sim = mp.Simulation(resolution=res,
                        cell_size=cell_size,
                        boundary_layers=pml_layers,
                        sources=src,
                        geometry=geometry,
                        k_point=k)
    freg = mp.FluxRegion(center=mp.Vector3(0,0,-src_pos),
                         size = mp.Vector3(sx,sy,0))
    trans = sim.add_flux(fcen, df, nfreq, freg)
    sim.run(until = echo)
    bend = mp.get_fluxes(trans)
    return bend

# %%
get_spec()
# Out:
# -----------
# Initializing structure...
# Meep: using complex fields.
# Meep progress: 12.941176470588236/1000.0 = 1.3% done in 4.0s, 305.4s to go
# Meep progress: 25.970588235294116/1000.0 = 2.6% done in 8.0s, 300.5s to go
# Meep progress: 39.205882352941174/1000.0 = 3.9% done in 12.0s, 294.4s to go
# Meep progress: 52.76470588235294/1000.0 = 5.3% done in 16.0s, 287.5s to go
# Meep progress: 66.47058823529412/1000.0 = 6.6% done in 20.0s, 281.1s to go
# Meep progress: 80.1470588235294/1000.0 = 8.0% done in 24.0s, 275.7s to go
# Meep progress: 93.97058823529412/1000.0 = 9.4% done in 28.0s, 270.2s to go
# Meep progress: 107.52941176470588/1000.0 = 10.8% done in 32.0s, 265.9s to go
# Meep progress: 121.26470588235294/1000.0 = 12.1% done in 36.0s, 261.1s to go
# Meep progress: 135.05882352941177/1000.0 = 13.5% done in 40.0s, 256.4s to go
# Meep progress: 148.88235294117646/1000.0 = 14.9% done in 44.0s, 251.8s to go
# Meep progress: 162.23529411764704/1000.0 = 16.2% done in 48.0s, 248.1s to go
# Meep progress: 176.05882352941177/1000.0 = 17.6% done in 52.1s, 243.6s to go
# Meep progress: 189.8235294117647/1000.0 = 19.0% done in 56.1s, 239.2s to go
# Meep progress: 203.64705882352942/1000.0 = 20.4% done in 60.1s, 234.8s to go
# Meep progress: 217.26470588235293/1000.0 = 21.7% done in 64.1s, 230.8s to go
# Meep progress: 231.05882352941177/1000.0 = 23.1% done in 68.1s, 226.5s to go
# Meep progress: 244.76470588235293/1000.0 = 24.5% done in 72.1s, 222.4s to go
# Meep progress: 258.5882352941176/1000.0 = 25.9% done in 76.1s, 218.1s to go
# Meep progress: 272.2352941176471/1000.0 = 27.2% done in 80.1s, 214.1s to go
# Meep progress: 285.9705882352941/1000.0 = 28.6% done in 84.1s, 209.9s to go
# Meep progress: 299.79411764705884/1000.0 = 30.0% done in 88.1s, 205.7s to go
# Meep progress: 313.61764705882354/1000.0 = 31.4% done in 92.1s, 201.5s to go
# Meep progress: 327.20588235294116/1000.0 = 32.7% done in 96.1s, 197.6s to go
# Meep progress: 341.0/1000.0 = 34.1% done in 100.1s, 193.4s to go
# Meep progress: 354.8529411764706/1000.0 = 35.5% done in 104.1s, 189.3s to go
# Meep progress: 368.6764705882353/1000.0 = 36.9% done in 108.1s, 185.1s to go
# Meep progress: 382.29411764705884/1000.0 = 38.2% done in 112.1s, 181.1s to go
# Meep progress: 396.05882352941177/1000.0 = 39.6% done in 116.1s, 177.1s to go
# Meep progress: 409.70588235294116/1000.0 = 41.0% done in 120.1s, 173.1s to go
# Meep progress: 422.8529411764706/1000.0 = 42.3% done in 124.1s, 169.4s to go
# Meep progress: 436.3235294117647/1000.0 = 43.6% done in 128.1s, 165.5s to go
# Meep progress: 450.02941176470586/1000.0 = 45.0% done in 132.1s, 161.5s to go
# Meep progress: 463.8529411764706/1000.0 = 46.4% done in 136.1s, 157.4s to go
# Meep progress: 477.6764705882353/1000.0 = 47.8% done in 140.1s, 153.2s to go
# Meep progress: 491.3235294117647/1000.0 = 49.1% done in 144.1s, 149.2s to go
# Meep progress: 505.11764705882354/1000.0 = 50.5% done in 148.2s, 145.2s to go
# Meep progress: 518.9411764705882/1000.0 = 51.9% done in 152.2s, 141.1s to go
# Meep progress: 532.7941176470588/1000.0 = 53.3% done in 156.2s, 136.9s to go
# Meep progress: 546.4411764705882/1000.0 = 54.6% done in 160.2s, 132.9s to go
# Meep progress: 560.2647058823529/1000.0 = 56.0% done in 164.2s, 128.9s to go
# Meep progress: 574.0588235294117/1000.0 = 57.4% done in 168.2s, 124.8s to go
# Meep progress: 587.8823529411765/1000.0 = 58.8% done in 172.2s, 120.7s to go
# Meep progress: 601.5/1000.0 = 60.1% done in 176.2s, 116.7s to go
# Meep progress: 615.2352941176471/1000.0 = 61.5% done in 180.2s, 112.7s to go
# Meep progress: 629.0882352941177/1000.0 = 62.9% done in 184.2s, 108.6s to go
# Meep progress: 642.9117647058823/1000.0 = 64.3% done in 188.2s, 104.5s to go
# Meep progress: 656.2941176470588/1000.0 = 65.6% done in 192.2s, 100.7s to go
# Meep progress: 670.1176470588235/1000.0 = 67.0% done in 196.2s, 96.6s to go
# Meep progress: 683.9705882352941/1000.0 = 68.4% done in 200.2s, 92.5s to go
# Meep progress: 697.7058823529412/1000.0 = 69.8% done in 204.2s, 88.5s to go
# Meep progress: 711.3529411764706/1000.0 = 71.1% done in 208.2s, 84.5s to go
# Meep progress: 725.1470588235294/1000.0 = 72.5% done in 212.2s, 80.4s to go
# Meep progress: 738.8529411764706/1000.0 = 73.9% done in 216.2s, 76.4s to go
# Meep progress: 752.3823529411765/1000.0 = 75.2% done in 220.3s, 72.5s to go
# Meep progress: 766.0/1000.0 = 76.6% done in 224.3s, 68.5s to go
# Meep progress: 779.8235294117646/1000.0 = 78.0% done in 228.3s, 64.4s to go
# Meep progress: 793.6176470588235/1000.0 = 79.4% done in 232.3s, 60.4s to go
# Meep progress: 807.3529411764706/1000.0 = 80.7% done in 236.3s, 56.4s to go
# Meep progress: 821.0294117647059/1000.0 = 82.1% done in 240.3s, 52.4s to go
# Meep progress: 834.8235294117646/1000.0 = 83.5% done in 244.3s, 48.3s to go
# Meep progress: 848.6764705882352/1000.0 = 84.9% done in 248.3s, 44.3s to go
# Meep progress: 862.3823529411765/1000.0 = 86.2% done in 252.3s, 40.3s to go
# Meep progress: 876.0/1000.0 = 87.6% done in 256.3s, 36.3s to go
# Meep progress: 889.8235294117646/1000.0 = 89.0% done in 260.3s, 32.2s to go
# Meep progress: 903.4117647058823/1000.0 = 90.3% done in 264.3s, 28.3s to go
# Meep progress: 917.2352941176471/1000.0 = 91.7% done in 268.3s, 24.2s to go
# Meep progress: 930.6764705882352/1000.0 = 93.1% done in 272.3s, 20.3s to go
# Meep progress: 944.5/1000.0 = 94.5% done in 276.3s, 16.2s to go
# Meep progress: 958.3529411764706/1000.0 = 95.8% done in 280.3s, 12.2s to go
# Meep progress: 972.0294117647059/1000.0 = 97.2% done in 284.3s, 8.2s to go
# Meep progress: 985.6764705882352/1000.0 = 98.6% done in 288.3s, 4.2s to go
# Meep progress: 999.4705882352941/1000.0 = 99.9% done in 292.3s, 0.2s to go
# run 0 finished at t = 1000.0 (34000 timesteps)
# Cylinder radius of 0.3 with holes of radius 0.05
# -----------
# Initializing structure...
# Meep: using complex fields.
# Meep progress: 13.205882352941176/1000.0 = 1.3% done in 4.0s, 299.1s to go
# Meep progress: 27.02941176470588/1000.0 = 2.7% done in 8.0s, 288.2s to go
# Meep progress: 40.61764705882353/1000.0 = 4.1% done in 12.0s, 283.6s to go
# Meep progress: 54.44117647058823/1000.0 = 5.4% done in 16.0s, 278.2s to go
# Meep progress: 68.0/1000.0 = 6.8% done in 20.0s, 274.4s to go
# Meep progress: 81.79411764705883/1000.0 = 8.2% done in 24.0s, 269.7s to go
# Meep progress: 95.23529411764706/1000.0 = 9.5% done in 28.0s, 266.3s to go
# Meep progress: 109.08823529411765/1000.0 = 10.9% done in 32.0s, 261.7s to go
# Meep progress: 122.91176470588235/1000.0 = 12.3% done in 36.0s, 257.2s to go
# Meep progress: 136.52941176470588/1000.0 = 13.7% done in 40.1s, 253.3s to go
# Meep progress: 150.14705882352942/1000.0 = 15.0% done in 44.1s, 249.4s to go
# Meep progress: 164.0/1000.0 = 16.4% done in 48.1s, 245.0s to go
# Meep progress: 177.7941176470588/1000.0 = 17.8% done in 52.1s, 240.8s to go
# Meep progress: 191.64705882352942/1000.0 = 19.2% done in 56.1s, 236.5s to go
# Meep progress: 205.38235294117646/1000.0 = 20.5% done in 60.1s, 232.4s to go
# Meep progress: 219.23529411764704/1000.0 = 21.9% done in 64.1s, 228.2s to go
# Meep progress: 233.05882352941177/1000.0 = 23.3% done in 68.1s, 224.0s to go
# Meep progress: 246.85294117647058/1000.0 = 24.7% done in 72.1s, 219.9s to go
# Meep progress: 260.4705882352941/1000.0 = 26.0% done in 76.1s, 216.0s to go
# Meep progress: 274.20588235294116/1000.0 = 27.4% done in 80.1s, 212.0s to go
# Meep progress: 287.88235294117646/1000.0 = 28.8% done in 84.1s, 208.0s to go
# Meep progress: 301.44117647058823/1000.0 = 30.1% done in 88.1s, 204.2s to go
# Meep progress: 315.0/1000.0 = 31.5% done in 92.1s, 200.3s to go
# Meep progress: 328.8529411764706/1000.0 = 32.9% done in 96.1s, 196.2s to go
# Meep progress: 342.6764705882353/1000.0 = 34.3% done in 100.1s, 192.1s to go
# Meep progress: 356.52941176470586/1000.0 = 35.7% done in 104.1s, 187.9s to go
# Meep progress: 370.11764705882354/1000.0 = 37.0% done in 108.1s, 184.0s to go
# Meep progress: 383.9705882352941/1000.0 = 38.4% done in 112.1s, 179.9s to go
# Meep progress: 397.79411764705884/1000.0 = 39.8% done in 116.1s, 175.8s to go
# Meep progress: 411.6470588235294/1000.0 = 41.2% done in 120.1s, 171.7s to go
# Meep progress: 425.2352941176471/1000.0 = 42.5% done in 124.1s, 167.8s to go
# Meep progress: 438.94117647058823/1000.0 = 43.9% done in 128.1s, 163.8s to go
# Meep progress: 452.7647058823529/1000.0 = 45.3% done in 132.1s, 159.7s to go
# Meep progress: 465.4705882352941/1000.0 = 46.5% done in 136.2s, 156.4s to go
# Meep progress: 478.0882352941176/1000.0 = 47.8% done in 140.2s, 153.0s to go
# Meep progress: 491.52941176470586/1000.0 = 49.2% done in 144.2s, 149.1s to go
# Meep progress: 505.1764705882353/1000.0 = 50.5% done in 148.2s, 145.1s to go
# Meep progress: 518.8529411764706/1000.0 = 51.9% done in 152.2s, 141.1s to go
# Meep progress: 532.4411764705882/1000.0 = 53.2% done in 156.2s, 137.1s to go
# Meep progress: 546.2941176470588/1000.0 = 54.6% done in 160.2s, 133.0s to go
# Meep progress: 560.1470588235294/1000.0 = 56.0% done in 164.2s, 128.9s to go
# Meep progress: 573.9411764705882/1000.0 = 57.4% done in 168.2s, 124.8s to go
# Meep progress: 587.5882352941177/1000.0 = 58.8% done in 172.2s, 120.8s to go
# Meep progress: 601.4411764705882/1000.0 = 60.1% done in 176.2s, 116.8s to go
# Meep progress: 614.8823529411765/1000.0 = 61.5% done in 180.2s, 112.9s to go
# Meep progress: 628.7058823529412/1000.0 = 62.9% done in 184.2s, 108.8s to go
# Meep progress: 642.3529411764706/1000.0 = 64.2% done in 188.2s, 104.8s to go
# Meep progress: 656.2352941176471/1000.0 = 65.6% done in 192.2s, 100.7s to go
# Meep progress: 670.0588235294117/1000.0 = 67.0% done in 196.2s, 96.6s to go
# Meep progress: 683.9117647058823/1000.0 = 68.4% done in 200.2s, 92.5s to go
# Meep progress: 697.4705882352941/1000.0 = 69.7% done in 204.2s, 88.6s to go
# Meep progress: 711.3529411764706/1000.0 = 71.1% done in 208.2s, 84.5s to go
# Meep progress: 725.0/1000.0 = 72.5% done in 212.2s, 80.5s to go
# Meep progress: 738.8823529411765/1000.0 = 73.9% done in 216.2s, 76.4s to go
# Meep progress: 752.6470588235294/1000.0 = 75.3% done in 220.2s, 72.4s to go
# Meep progress: 766.5/1000.0 = 76.7% done in 224.2s, 68.3s to go
# Meep progress: 780.2941176470588/1000.0 = 78.0% done in 228.2s, 64.3s to go
# Meep progress: 794.0588235294117/1000.0 = 79.4% done in 232.2s, 60.2s to go
# Meep progress: 807.5588235294117/1000.0 = 80.8% done in 236.2s, 56.3s to go
# Meep progress: 821.3235294117646/1000.0 = 82.1% done in 240.2s, 52.3s to go
# Meep progress: 834.9411764705882/1000.0 = 83.5% done in 244.3s, 48.3s to go
# Meep progress: 848.5882352941177/1000.0 = 84.9% done in 248.3s, 44.3s to go
# Meep progress: 862.2352941176471/1000.0 = 86.2% done in 252.3s, 40.3s to go
# Meep progress: 876.0882352941177/1000.0 = 87.6% done in 256.3s, 36.2s to go
# Meep progress: 889.9411764705882/1000.0 = 89.0% done in 260.3s, 32.2s to go
# Meep progress: 903.7941176470588/1000.0 = 90.4% done in 264.3s, 28.1s to go
# Meep progress: 917.4117647058823/1000.0 = 91.7% done in 268.3s, 24.2s to go
# Meep progress: 931.1176470588235/1000.0 = 93.1% done in 272.3s, 20.1s to go
# Meep progress: 944.9705882352941/1000.0 = 94.5% done in 276.3s, 16.1s to go
# Meep progress: 958.7352941176471/1000.0 = 95.9% done in 280.3s, 12.1s to go
# Meep progress: 972.3235294117646/1000.0 = 97.2% done in 284.3s, 8.1s to go
# Meep progress: 986.1470588235294/1000.0 = 98.6% done in 288.3s, 4.0s to go
# Meep progress: 999.8529411764706/1000.0 = 100.0% done in 292.3s, 0.0s to go
# run 0 finished at t = 1000.0 (34000 timesteps)
# Cylinder radius of 0.3 with holes of radius 0.1
# -----------
# Initializing structure...
# Meep: using complex fields.
# Meep progress: 12.882352941176471/1000.0 = 1.3% done in 4.0s, 307.2s to go
# Meep progress: 26.647058823529413/1000.0 = 2.7% done in 8.0s, 292.6s to go
# Meep progress: 40.470588235294116/1000.0 = 4.0% done in 12.0s, 284.8s to go
# Meep progress: 54.26470588235294/1000.0 = 5.4% done in 16.0s, 279.1s to go
# Meep progress: 67.91176470588235/1000.0 = 6.8% done in 20.0s, 274.8s to go
# Meep progress: 81.73529411764706/1000.0 = 8.2% done in 24.0s, 270.0s to go
# Meep progress: 95.32352941176471/1000.0 = 9.5% done in 28.0s, 266.1s to go
# Meep progress: 109.08823529411765/1000.0 = 10.9% done in 32.0s, 261.7s to go
# Meep progress: 122.67647058823529/1000.0 = 12.3% done in 36.0s, 257.7s to go
# Meep progress: 136.44117647058823/1000.0 = 13.6% done in 40.0s, 253.5s to go
# Meep progress: 150.2058823529412/1000.0 = 15.0% done in 44.0s, 249.2s to go
# Meep progress: 163.85294117647058/1000.0 = 16.4% done in 48.1s, 245.2s to go
# Meep progress: 177.47058823529412/1000.0 = 17.7% done in 52.1s, 241.3s to go
# Meep progress: 191.1764705882353/1000.0 = 19.1% done in 56.1s, 237.2s to go
# Meep progress: 205.02941176470588/1000.0 = 20.5% done in 60.1s, 232.9s to go
# Meep progress: 218.91176470588235/1000.0 = 21.9% done in 64.1s, 228.6s to go
# Meep progress: 232.55882352941177/1000.0 = 23.3% done in 68.1s, 224.6s to go
# Meep progress: 246.44117647058823/1000.0 = 24.6% done in 72.1s, 220.4s to go
# Meep progress: 260.3235294117647/1000.0 = 26.0% done in 76.1s, 216.2s to go
# Meep progress: 274.1764705882353/1000.0 = 27.4% done in 80.1s, 212.0s to go
# Meep progress: 287.5882352941176/1000.0 = 28.8% done in 84.1s, 208.3s to go
# Meep progress: 301.4117647058824/1000.0 = 30.1% done in 88.1s, 204.2s to go
# Meep progress: 315.1470588235294/1000.0 = 31.5% done in 92.1s, 200.1s to go
# Meep progress: 327.88235294117646/1000.0 = 32.8% done in 96.1s, 197.0s to go
# Meep progress: 340.6764705882353/1000.0 = 34.1% done in 100.1s, 193.8s to go
# Meep progress: 354.52941176470586/1000.0 = 35.5% done in 104.1s, 189.6s to go
# Meep progress: 367.3235294117647/1000.0 = 36.7% done in 108.1s, 186.2s to go
# Meep progress: 380.2647058823529/1000.0 = 38.0% done in 112.1s, 182.7s to go
# Meep progress: 392.0882352941176/1000.0 = 39.2% done in 116.1s, 180.0s to go
# Meep progress: 405.05882352941177/1000.0 = 40.5% done in 120.1s, 176.4s to go
# Meep progress: 418.05882352941177/1000.0 = 41.8% done in 124.1s, 172.8s to go
# Meep progress: 430.6470588235294/1000.0 = 43.1% done in 128.1s, 169.4s to go
# Meep progress: 443.5/1000.0 = 44.4% done in 132.1s, 165.8s to go
# Meep progress: 456.5/1000.0 = 45.6% done in 136.1s, 162.1s to go
# Meep progress: 469.5882352941176/1000.0 = 47.0% done in 140.1s, 158.3s to go
# Meep progress: 482.29411764705884/1000.0 = 48.2% done in 144.2s, 154.7s to go
# Meep progress: 495.2352941176471/1000.0 = 49.5% done in 148.2s, 151.0s to go
# Meep progress: 507.79411764705884/1000.0 = 50.8% done in 152.2s, 147.5s to go
# Meep progress: 521.0/1000.0 = 52.1% done in 156.2s, 143.6s to go
# Meep progress: 533.8823529411765/1000.0 = 53.4% done in 160.2s, 139.8s to go
# Meep progress: 546.3529411764706/1000.0 = 54.6% done in 164.2s, 136.3s to go
# Meep progress: 559.0/1000.0 = 55.9% done in 168.2s, 132.7s to go
# Meep progress: 571.9705882352941/1000.0 = 57.2% done in 172.2s, 128.8s to go
# Meep progress: 585.3823529411765/1000.0 = 58.5% done in 176.2s, 124.8s to go
# Meep progress: 598.3529411764706/1000.0 = 59.8% done in 180.2s, 120.9s to go
# Meep progress: 611.6470588235294/1000.0 = 61.2% done in 184.2s, 116.9s to go
# Meep progress: 624.8823529411765/1000.0 = 62.5% done in 188.2s, 113.0s to go
# Meep progress: 637.6176470588235/1000.0 = 63.8% done in 192.2s, 109.2s to go
# Meep progress: 650.4705882352941/1000.0 = 65.0% done in 196.2s, 105.4s to go
# Meep progress: 663.8823529411765/1000.0 = 66.4% done in 200.2s, 101.4s to go
# Meep progress: 677.4411764705882/1000.0 = 67.7% done in 204.2s, 97.2s to go
# Meep progress: 691.0/1000.0 = 69.1% done in 208.2s, 93.1s to go
# Meep progress: 703.3529411764706/1000.0 = 70.3% done in 212.2s, 89.5s to go
# Meep progress: 715.3823529411765/1000.0 = 71.5% done in 216.2s, 86.0s to go
# Meep progress: 728.4705882352941/1000.0 = 72.8% done in 220.2s, 82.1s to go
# Meep progress: 742.0/1000.0 = 74.2% done in 224.2s, 78.0s to go
# Meep progress: 755.5588235294117/1000.0 = 75.6% done in 228.2s, 73.8s to go
# Meep progress: 769.4117647058823/1000.0 = 76.9% done in 232.2s, 69.6s to go
# Meep progress: 782.9411764705882/1000.0 = 78.3% done in 236.2s, 65.5s to go
# Meep progress: 796.0/1000.0 = 79.6% done in 240.2s, 61.6s to go
# Meep progress: 808.5588235294117/1000.0 = 80.9% done in 244.3s, 57.8s to go
# Meep progress: 821.8235294117646/1000.0 = 82.2% done in 248.3s, 53.8s to go
# Meep progress: 834.7941176470588/1000.0 = 83.5% done in 252.3s, 49.9s to go
# Meep progress: 847.5588235294117/1000.0 = 84.8% done in 256.3s, 46.1s to go
# Meep progress: 860.2647058823529/1000.0 = 86.0% done in 260.3s, 42.3s to go
# Meep progress: 872.6176470588235/1000.0 = 87.3% done in 264.3s, 38.6s to go
# Meep progress: 885.0294117647059/1000.0 = 88.5% done in 268.3s, 34.9s to go
# Meep progress: 898.1176470588235/1000.0 = 89.8% done in 272.3s, 30.9s to go
# Meep progress: 910.7352941176471/1000.0 = 91.1% done in 276.3s, 27.1s to go
# Meep progress: 923.4411764705882/1000.0 = 92.3% done in 280.3s, 23.2s to go
# Meep progress: 935.5588235294117/1000.0 = 93.6% done in 284.3s, 19.6s to go
# Meep progress: 948.6764705882352/1000.0 = 94.9% done in 288.3s, 15.6s to go
# Meep progress: 962.2058823529412/1000.0 = 96.2% done in 292.3s, 11.5s to go
# Meep progress: 975.2058823529412/1000.0 = 97.5% done in 296.3s, 7.5s to go
# Meep progress: 988.2941176470588/1000.0 = 98.8% done in 300.3s, 3.6s to go
# run 0 finished at t = 1000.0 (34000 timesteps)
# Cylinder radius of 0.3 with holes of radius 0.15000000000000002
# -----------
# Initializing structure...
# Meep: using complex fields.
# Meep progress: 12.794117647058822/1000.0 = 1.3% done in 4.0s, 309.0s to go
# Meep progress: 25.5/1000.0 = 2.5% done in 8.0s, 306.1s to go
# Meep progress: 39.029411764705884/1000.0 = 3.9% done in 12.0s, 295.7s to go
# Meep progress: 52.88235294117647/1000.0 = 5.3% done in 16.0s, 286.8s to go
# Meep progress: 66.17647058823529/1000.0 = 6.6% done in 20.0s, 282.5s to go
# Meep progress: 79.17647058823529/1000.0 = 7.9% done in 24.0s, 279.4s to go
# Meep progress: 92.17647058823529/1000.0 = 9.2% done in 28.0s, 276.1s to go
# Meep progress: 105.23529411764706/1000.0 = 10.5% done in 32.0s, 272.3s to go
# Meep progress: 117.97058823529412/1000.0 = 11.8% done in 36.0s, 269.4s to go
# Meep progress: 130.55882352941177/1000.0 = 13.1% done in 40.0s, 266.6s to go
# Meep progress: 143.11764705882354/1000.0 = 14.3% done in 44.0s, 263.7s to go
# Meep progress: 156.02941176470588/1000.0 = 15.6% done in 48.0s, 259.9s to go
# Meep progress: 168.02941176470588/1000.0 = 16.8% done in 52.1s, 257.7s to go
# Meep progress: 180.55882352941177/1000.0 = 18.1% done in 56.1s, 254.4s to go
# Meep progress: 193.1764705882353/1000.0 = 19.3% done in 60.1s, 250.9s to go
# Meep progress: 206.11764705882354/1000.0 = 20.6% done in 64.1s, 246.8s to go
# Meep progress: 218.7941176470588/1000.0 = 21.9% done in 68.1s, 243.0s to go
# Meep progress: 229.91176470588235/1000.0 = 23.0% done in 72.1s, 241.4s to go
# Meep progress: 241.2941176470588/1000.0 = 24.1% done in 76.1s, 239.2s to go
# Meep progress: 252.88235294117646/1000.0 = 25.3% done in 80.1s, 236.6s to go
# Meep progress: 264.1764705882353/1000.0 = 26.4% done in 84.1s, 234.2s to go
# Meep progress: 275.61764705882354/1000.0 = 27.6% done in 88.1s, 231.5s to go
# Meep progress: 287.20588235294116/1000.0 = 28.7% done in 92.1s, 228.6s to go
# Meep progress: 298.8235294117647/1000.0 = 29.9% done in 96.1s, 225.5s to go
# Meep progress: 309.7647058823529/1000.0 = 31.0% done in 100.1s, 223.1s to go
# Meep progress: 320.9117647058824/1000.0 = 32.1% done in 104.1s, 220.3s to go
# Meep progress: 332.05882352941177/1000.0 = 33.2% done in 108.1s, 217.5s to go
# Meep progress: 342.6764705882353/1000.0 = 34.3% done in 112.1s, 215.1s to go
# Meep progress: 352.79411764705884/1000.0 = 35.3% done in 116.1s, 213.1s to go
# Meep progress: 364.29411764705884/1000.0 = 36.4% done in 120.2s, 209.7s to go
# Meep progress: 375.55882352941177/1000.0 = 37.6% done in 124.2s, 206.5s to go
# Meep progress: 386.8529411764706/1000.0 = 38.7% done in 128.2s, 203.2s to go
# Meep progress: 397.79411764705884/1000.0 = 39.8% done in 132.2s, 200.1s to go
# Meep progress: 408.9705882352941/1000.0 = 40.9% done in 136.2s, 196.8s to go
# Meep progress: 420.02941176470586/1000.0 = 42.0% done in 140.2s, 193.6s to go
# Meep progress: 431.29411764705884/1000.0 = 43.1% done in 144.2s, 190.1s to go
# Meep progress: 442.6764705882353/1000.0 = 44.3% done in 148.2s, 186.6s to go
# Meep progress: 454.1470588235294/1000.0 = 45.4% done in 152.2s, 182.9s to go
# Meep progress: 465.38235294117646/1000.0 = 46.5% done in 156.2s, 179.5s to go
# Meep progress: 476.8529411764706/1000.0 = 47.7% done in 160.2s, 175.8s to go
# Meep progress: 487.70588235294116/1000.0 = 48.8% done in 164.2s, 172.5s to go
# Meep progress: 498.7647058823529/1000.0 = 49.9% done in 168.2s, 169.1s to go
# Meep progress: 509.44117647058823/1000.0 = 50.9% done in 172.2s, 165.9s to go
# Meep progress: 520.5294117647059/1000.0 = 52.1% done in 176.3s, 162.3s to go
# Meep progress: 531.0588235294117/1000.0 = 53.1% done in 180.3s, 159.2s to go
# Meep progress: 541.5294117647059/1000.0 = 54.2% done in 184.3s, 156.0s to go
# Meep progress: 553.0294117647059/1000.0 = 55.3% done in 188.3s, 152.2s to go
# Meep progress: 565.7647058823529/1000.0 = 56.6% done in 192.3s, 147.6s to go
# Meep progress: 579.0294117647059/1000.0 = 57.9% done in 196.3s, 142.7s to go
# Meep progress: 592.1470588235294/1000.0 = 59.2% done in 200.3s, 137.9s to go
# Meep progress: 604.9411764705882/1000.0 = 60.5% done in 204.3s, 133.4s to go
# Meep progress: 617.7941176470588/1000.0 = 61.8% done in 208.3s, 128.9s to go
# Meep progress: 630.5294117647059/1000.0 = 63.1% done in 212.3s, 124.4s to go
# Meep progress: 643.5294117647059/1000.0 = 64.4% done in 216.3s, 119.8s to go
# Meep progress: 656.3529411764706/1000.0 = 65.6% done in 220.3s, 115.3s to go
# Meep progress: 669.5882352941177/1000.0 = 67.0% done in 224.3s, 110.7s to go
# Meep progress: 682.5588235294117/1000.0 = 68.3% done in 228.3s, 106.2s to go
# Meep progress: 696.2058823529412/1000.0 = 69.6% done in 232.3s, 101.4s to go
# Meep progress: 709.7647058823529/1000.0 = 71.0% done in 236.3s, 96.6s to go
# Meep progress: 723.0/1000.0 = 72.3% done in 240.3s, 92.1s to go
# Meep progress: 736.3235294117646/1000.0 = 73.6% done in 244.3s, 87.5s to go
# Meep progress: 749.6470588235294/1000.0 = 75.0% done in 248.3s, 82.9s to go
# Meep progress: 762.9117647058823/1000.0 = 76.3% done in 252.3s, 78.4s to go
# Meep progress: 776.2941176470588/1000.0 = 77.6% done in 256.3s, 73.9s to go
# Meep progress: 789.5588235294117/1000.0 = 79.0% done in 260.3s, 69.4s to go
# Meep progress: 802.4705882352941/1000.0 = 80.2% done in 264.3s, 65.1s to go
# Meep progress: 815.7058823529412/1000.0 = 81.6% done in 268.4s, 60.6s to go
# Meep progress: 829.4117647058823/1000.0 = 82.9% done in 272.4s, 56.0s to go
# Meep progress: 842.7647058823529/1000.0 = 84.3% done in 276.4s, 51.6s to go
# Meep progress: 856.0588235294117/1000.0 = 85.6% done in 280.4s, 47.1s to go
# Meep progress: 869.5588235294117/1000.0 = 87.0% done in 284.4s, 42.7s to go
# Meep progress: 882.7352941176471/1000.0 = 88.3% done in 288.4s, 38.3s to go
# Meep progress: 896.1176470588235/1000.0 = 89.6% done in 292.4s, 33.9s to go
# Meep progress: 908.9117647058823/1000.0 = 90.9% done in 296.4s, 29.7s to go
# Meep progress: 921.4411764705882/1000.0 = 92.1% done in 300.4s, 25.6s to go
# Meep progress: 933.7352941176471/1000.0 = 93.4% done in 304.4s, 21.6s to go
# Meep progress: 946.5882352941177/1000.0 = 94.7% done in 308.4s, 17.4s to go
# Meep progress: 959.2647058823529/1000.0 = 95.9% done in 312.4s, 13.3s to go
# Meep progress: 972.5882352941177/1000.0 = 97.3% done in 316.4s, 8.9s to go
# Meep progress: 986.0294117647059/1000.0 = 98.6% done in 320.4s, 4.5s to go
# Meep progress: 999.0/1000.0 = 99.9% done in 324.4s, 0.3s to go
# run 0 finished at t = 1000.0 (34000 timesteps)
# Cylinder radius of 0.3 with holes of radius 0.2
# -----------
# Initializing structure...
# Meep: using complex fields.
# Meep progress: 12.5/1000.0 = 1.2% done in 4.0s, 316.2s to go
# Meep progress: 25.823529411764707/1000.0 = 2.6% done in 8.0s, 302.1s to go
# Meep progress: 39.529411764705884/1000.0 = 4.0% done in 12.0s, 291.9s to go
# Meep progress: 53.14705882352941/1000.0 = 5.3% done in 16.0s, 285.4s to go
# Meep progress: 66.44117647058823/1000.0 = 6.6% done in 20.0s, 281.4s to go
# Meep progress: 79.3529411764706/1000.0 = 7.9% done in 24.0s, 278.7s to go
# Meep progress: 92.82352941176471/1000.0 = 9.3% done in 28.0s, 274.0s to go
# Meep progress: 106.0/1000.0 = 10.6% done in 32.0s, 270.2s to go
# Meep progress: 119.67647058823529/1000.0 = 12.0% done in 36.0s, 265.1s to go
# Meep progress: 133.0/1000.0 = 13.3% done in 40.0s, 261.0s to go
# Meep progress: 146.44117647058823/1000.0 = 14.6% done in 44.0s, 256.7s to go
# Meep progress: 159.76470588235293/1000.0 = 16.0% done in 48.0s, 252.7s to go
# Meep progress: 173.64705882352942/1000.0 = 17.4% done in 52.0s, 247.7s to go
# Meep progress: 187.44117647058823/1000.0 = 18.7% done in 56.1s, 243.0s to go
# Meep progress: 200.41176470588235/1000.0 = 20.0% done in 60.1s, 239.6s to go
# Meep progress: 213.41176470588235/1000.0 = 21.3% done in 64.1s, 236.1s to go
# Meep progress: 226.73529411764704/1000.0 = 22.7% done in 68.1s, 232.1s to go
# Meep progress: 240.14705882352942/1000.0 = 24.0% done in 72.1s, 228.0s to go
# Meep progress: 253.23529411764704/1000.0 = 25.3% done in 76.1s, 224.3s to go
# Meep progress: 265.8235294117647/1000.0 = 26.6% done in 80.1s, 221.2s to go
# Meep progress: 278.61764705882354/1000.0 = 27.9% done in 84.1s, 217.7s to go
# Meep progress: 292.05882352941177/1000.0 = 29.2% done in 88.1s, 213.5s to go
# Meep progress: 305.6764705882353/1000.0 = 30.6% done in 92.1s, 209.2s to go
# Meep progress: 317.55882352941177/1000.0 = 31.8% done in 96.1s, 206.5s to go
# Meep progress: 330.3529411764706/1000.0 = 33.0% done in 100.1s, 202.9s to go
# Meep progress: 343.5882352941176/1000.0 = 34.4% done in 104.1s, 198.9s to go
# Meep progress: 355.9705882352941/1000.0 = 35.6% done in 108.1s, 195.6s to go
# Meep progress: 368.3235294117647/1000.0 = 36.8% done in 112.1s, 192.3s to go
# Meep progress: 380.5/1000.0 = 38.0% done in 116.1s, 189.0s to go
# Meep progress: 393.0/1000.0 = 39.3% done in 120.1s, 185.5s to go
# Meep progress: 405.3529411764706/1000.0 = 40.5% done in 124.1s, 182.1s to go
# Meep progress: 417.8529411764706/1000.0 = 41.8% done in 128.1s, 178.5s to go
# Meep progress: 430.2352941176471/1000.0 = 43.0% done in 132.1s, 175.0s to go
# Meep progress: 443.1470588235294/1000.0 = 44.3% done in 136.1s, 171.1s to go
# Meep progress: 456.70588235294116/1000.0 = 45.7% done in 140.1s, 166.7s to go
# Meep progress: 470.2647058823529/1000.0 = 47.0% done in 144.2s, 162.4s to go
# Meep progress: 483.6764705882353/1000.0 = 48.4% done in 148.2s, 158.2s to go
# Meep progress: 497.4117647058823/1000.0 = 49.7% done in 152.2s, 153.7s to go
# Meep progress: 511.20588235294116/1000.0 = 51.1% done in 156.2s, 149.3s to go
# Meep progress: 524.5294117647059/1000.0 = 52.5% done in 160.2s, 145.2s to go
# Meep progress: 536.7058823529412/1000.0 = 53.7% done in 164.2s, 141.7s to go
# Meep progress: 549.0882352941177/1000.0 = 54.9% done in 168.2s, 138.1s to go
# Meep progress: 561.2941176470588/1000.0 = 56.1% done in 172.2s, 134.6s to go
# Meep progress: 573.4705882352941/1000.0 = 57.3% done in 176.2s, 131.0s to go
# Meep progress: 586.8529411764706/1000.0 = 58.7% done in 180.2s, 126.9s to go
# Meep progress: 599.5882352941177/1000.0 = 60.0% done in 184.2s, 123.0s to go
# Meep progress: 612.1176470588235/1000.0 = 61.2% done in 188.2s, 119.3s to go
# Meep progress: 624.4705882352941/1000.0 = 62.4% done in 192.2s, 115.6s to go
# Meep progress: 637.5588235294117/1000.0 = 63.8% done in 196.2s, 111.5s to go
# Meep progress: 650.6764705882352/1000.0 = 65.1% done in 200.2s, 107.5s to go
# Meep progress: 663.0882352941177/1000.0 = 66.3% done in 204.2s, 103.8s to go
# Meep progress: 675.6764705882352/1000.0 = 67.6% done in 208.2s, 99.9s to go
# Meep progress: 689.0294117647059/1000.0 = 68.9% done in 212.2s, 95.8s to go
# Meep progress: 702.4411764705882/1000.0 = 70.2% done in 216.2s, 91.6s to go
# Meep progress: 715.1176470588235/1000.0 = 71.5% done in 220.2s, 87.7s to go
# Meep progress: 727.8235294117646/1000.0 = 72.8% done in 224.2s, 83.9s to go
# Meep progress: 740.8823529411765/1000.0 = 74.1% done in 228.2s, 79.8s to go
# Meep progress: 753.3823529411765/1000.0 = 75.3% done in 232.2s, 76.0s to go
# Meep progress: 766.0294117647059/1000.0 = 76.6% done in 236.3s, 72.2s to go
# Meep progress: 778.2058823529412/1000.0 = 77.8% done in 240.3s, 68.5s to go
# Meep progress: 791.5588235294117/1000.0 = 79.2% done in 244.3s, 64.3s to go
# Meep progress: 804.9705882352941/1000.0 = 80.5% done in 248.3s, 60.2s to go
# Meep progress: 818.3529411764706/1000.0 = 81.8% done in 252.3s, 56.0s to go
# Meep progress: 831.2058823529412/1000.0 = 83.1% done in 256.3s, 52.0s to go
# Meep progress: 843.9411764705882/1000.0 = 84.4% done in 260.3s, 48.1s to go
# Meep progress: 856.5882352941177/1000.0 = 85.7% done in 264.3s, 44.2s to go
# Meep progress: 868.8529411764706/1000.0 = 86.9% done in 268.3s, 40.5s to go
# Meep progress: 881.0/1000.0 = 88.1% done in 272.3s, 36.8s to go
# Meep progress: 893.7352941176471/1000.0 = 89.4% done in 276.3s, 32.9s to go
# Meep progress: 906.5882352941177/1000.0 = 90.7% done in 280.3s, 28.9s to go
# Meep progress: 919.5/1000.0 = 92.0% done in 284.3s, 24.9s to go
# Meep progress: 932.8235294117646/1000.0 = 93.3% done in 288.3s, 20.8s to go
# Meep progress: 946.3529411764706/1000.0 = 94.6% done in 292.3s, 16.6s to go
# Meep progress: 960.0882352941177/1000.0 = 96.0% done in 296.3s, 12.3s to go
# Meep progress: 973.7647058823529/1000.0 = 97.4% done in 300.3s, 8.1s to go
# Meep progress: 987.2647058823529/1000.0 = 98.7% done in 304.3s, 3.9s to go
# run 0 finished at t = 1000.0 (34000 timesteps)
# Cylinder radius of 0.3 with holes of radius 0.25

# %% [markdown]
# Cylinder radius of 0.3 with holes of radius 0.05![image.png](attachment:image.png)

# %% [markdown]
# Cylinder radius of 0.3 with holes of radius 0.1![image.png](attachment:image.png)

# %% [markdown]
# Cylinder radius of 0.3 with holes of radius 0.15000000000000002![image.png](attachment:image.png)

# %% [markdown]
# Cylinder radius of 0.3 with holes of radius 0.2![image.png](attachment:image.png)

# %% [markdown]
# Cylinder radius of 0.3 with holes of radius 0.25![image.png](attachment:image.png)
